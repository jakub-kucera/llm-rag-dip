# %%
old_prompt = """You are given a Czech court decision (“rozhodnutí Nejvyššího správního soudu”):

[DOCUMENT CONTENTS START]
{DOCUMENT_CONTENTS}
[DOCUMENT CONTENTS END]

Your task is to analyze the provided document and generate multiple question–answer pairs about it. The document text is in Czech, but the instructions here are in English.

**Requirements for your output:**
1. **Language:** The questions and answers you produce must be **in Czech**.
2. **Number of QA pairs:** Please produce 5–10 question–answer pairs (depending on the document’s length and complexity).
3. **Question categories:** Each question must correspond to exactly one of these categories (use whichever are relevant, but try to diversify the final set):
   - **Factual (factual)**: Basic factual details, e.g. key dates, numbers, direct quotations.
   - **Reasoning about legal argumentation (reasoning)**: How the court reasoned, references to specific paragraphs, justifications for a particular conclusion.
   - **Interpretation of law (legal_interpretation)**: Questions focusing on how the court applied or interpreted specific statutes, directives, or legal principles.
   - **Credibility / witness or party consistency (credibility)**: Questions about contradictory statements, analysis of witness credibility, or factual inconsistencies identified by the court.
   - **Process aspects (procedure)**: Chronology of steps, who decided what, whether it was an appeal, cassation complaint, etc.
   - **Summary or context (summary)**: A broader summary question about the core issues or overarching legal context.
   - **Practical consequences (practical)**: Questions focusing on the real-world effects of the ruling or instructions for further proceedings.
4. **Structure:** Output a **JSON object** with a top-level key `"qa_pairs"`, containing an **array** of objects. Each object must have these fields:
   - `"question"`: A single question in Czech.
   - `"golden_answer"`: A concise and precise answer in Czech, reflecting the correct or ideal response based on the text.
   - `"questions_type"`: One of the categories above (factual, reasoning, legal_interpretation, credibility, procedure, summary, practical).

**Example JSON output format** (do not produce ellipses "…" in the final output; this is only illustrative):
```
{{
  "qa_pairs": [
    {{
      "question": "V jakém roce podal stěžovatel první žalobu k Městskému soudu v Praze?",
      "golden_answer": "Podal ji v roce 2021.",
      "questions_type": "factual"
    }},
    {{
      "question": "Proč soud odmítl prolomit § 75 odst. 1 s. ř. s. v tomto řízení?",
      "golden_answer": "Protože stěžovatel stále mohl podat novou žádost o azyl, a tím byla zajištěna ochrana non-refoulement.",
      "questions_type": "reasoning"
    }}
  ]
}}

```

**Important**:
- Stay strictly within this JSON structure.
- **Do not** include any additional commentary, markdown formatting, or explanations outside of the JSON.
- Ensure each `"golden_answer"` is factually correct and concise, pulled from or supported by the text.

**Now**:
1. Read carefully the entire Czech court decision above (`{DOCUMENT_CONTENTS}`).
2. Produce a set of **5–10 question–answer pairs** in Czech.
3. Output only the JSON with the specified structure and fields.

Begin.
"""

# %%
prompt = """
You are given a Czech court decision (“rozhodnutí Nejvyššího správního soudu”):

[DOCUMENT CONTENTS START]
{DOCUMENT_CONTENTS}
[DOCUMENT CONTENTS END]

Your task is to analyze the provided document and generate multiple question–answer pairs about it. The document text is in Czech, but the instructions here are in English.

**Important context:**
- We have thousands of such decisions in a large corpus.
- Each question must reference at least one **unique or specific detail** from the text (such as the spisová značka, date of the decision, or distinctive phrases or facts) so that we can retrieve the correct document among many.

**Requirements for your output:**
1. **Language:** The questions and answers you produce must be **in Czech**.
2. **Number of QA pairs:** Please produce 5–10 question–answer pairs (depending on the document’s length and complexity).
3. **Question categories:** Each question must correspond to exactly one of these categories (use whichever are relevant, but try to diversify the final set):
   - **Factual (factual)**: Basic factual details, e.g. key dates, numbers, direct quotations.
   - **Reasoning about legal argumentation (reasoning)**: How the court reasoned, references to specific paragraphs, justifications for a particular conclusion.
   - **Interpretation of law (legal_interpretation)**: Questions focusing on how the court applied or interpreted specific statutes, directives, or legal principles.
   - **Credibility / witness or party consistency (credibility)**: Questions about contradictory statements, analysis of witness credibility, or factual inconsistencies identified by the court.
   - **Process aspects (procedure)**: Chronology of steps, who decided what, whether it was an appeal, cassation complaint, etc.
   - **Summary or context (summary)**: A broader summary question about the core issues or overarching legal context.
   - **Practical consequences (practical)**: Questions focusing on the real-world effects of the ruling or instructions for further proceedings.
4. **Structure:** Output a **JSON object** with a top-level key `"qa_pairs"`, containing an **array** of objects. Each object must have these fields:
   - `"question"`: A single question in Czech. **Incorporate at least one unique detail from the decision** (e.g., the specific date, spisová značka, or other distinctive text) so that it is clear you are referencing *this* document.
   - `"golden_answer"`: A concise and precise answer in Czech, reflecting the correct or ideal response based on the text.
   - `"questions_type"`: One of the categories above (factual, reasoning, legal_interpretation, credibility, procedure, summary, practical).

**Example JSON output format** (for illustration only):

{{ "qa_pairs": [ {{ "question": "V jakém roce podal stěžovatel první žalobu k Městskému soudu v Praze v rozhodnutí ze dne 10. 5. 2022, sp. zn. 1 Azs 123/2022-45?", "golden_answer": "Podal ji v roce 2021.", "questions_type": "factual" }}, {{ "question": "Proč soud ve spisu 1 Azs 123/2022-45 z 10. 5. 2022 odmítl prolomit § 75 odst. 1 s. ř. s. v tomto řízení?", "golden_answer": "Protože stěžovatel stále mohl podat novou žádost o azyl, a tím byla zajištěna ochrana non-refoulement.", "questions_type": "reasoning" }} ] }}



**Important**:
- Stay strictly within this JSON structure.
- **Do not** include any additional commentary, markdown formatting, or explanations outside of the JSON.
- Each question must clearly reference a **unique detail** from the text.
- Ensure each `"golden_answer"` is factually correct and concise, pulled from or supported by the text.

**Now**:
1. Read carefully the entire Czech court decision above (between [DOCUMENT CONTENTS START] and [DOCUMENT CONTENTS END]).
2. Produce a set of **5–10 question–answer pairs** in Czech, referencing unique details so we can identify the correct decision among many.
3. Output only the JSON with the specified structure and fields.

Begin.
"""

# %%
# ! pip install langchain-google-genai

# %%
import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    # model="gemini-2.5-pro-exp-03-25",
    temperature=0.5,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
documents = os.listdir("files")

# %%
documents = [doc for doc in documents if doc.endswith(".txt")]

# %%
questions = []

# %%
# get random 100 documents
import random
documents_subset = random.sample(documents, 100)

# %%
from tqdm import tqdm

for doc in tqdm(documents_subset[1:]):
    with open(os.path.join("files", doc), "r", encoding="utf-8") as f:
        text = f.read()
    prompt_text = prompt.format(DOCUMENT_CONTENTS=text)
    response = llm.invoke(prompt_text)
    questions.append(response)
# Out:
#  66%|██████▌   | 65/99 [08:03<04:13,  7.44s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 7
#       5     text = f.read()
#       6 prompt_text = prompt.format(DOCUMENT_CONTENTS=text)
# ----> 7 response = llm.invoke(prompt_text)
#       8 questions.append(response)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:307, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     296 def invoke(
#     297     self,
#     298     input: LanguageModelInput,
#    (...)
#     302     **kwargs: Any,
#     303 ) -> BaseMessage:
#     304     config = ensure_config(config)
#     305     return cast(
#     306         ChatGeneration,
# --> 307         self.generate_prompt(
#     308             [self._convert_input(input)],
#     309             stop=stop,
#     310             callbacks=config.get("callbacks"),
#     311             tags=config.get("tags"),
#     312             metadata=config.get("metadata"),
#     313             run_name=config.get("run_name"),
#     314             run_id=config.pop("run_id", None),
#     315             **kwargs,
#     316         ).generations[0][0],
#     317     ).message
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:843, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     835 def generate_prompt(
#     836     self,
#     837     prompts: list[PromptValue],
#    (...)
#     840     **kwargs: Any,
#     841 ) -> LLMResult:
#     842     prompt_messages = [p.to_messages() for p in prompts]
# --> 843     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:683, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     680 for i, m in enumerate(messages):
#     681     try:
#     682         results.append(
# --> 683             self._generate_with_cache(
#     684                 m,
#     685                 stop=stop,
#     686                 run_manager=run_managers[i] if run_managers else None,
#     687                 **kwargs,
#     688             )
#     689         )
#     690     except BaseException as e:
#     691         if run_managers:
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:908, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     906 else:
#     907     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 908         result = self._generate(
#     909             messages, stop=stop, run_manager=run_manager, **kwargs
#     910         )
#     911     else:
#     912         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:989, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#     963 def _generate(
#     964     self,
#     965     messages: List[BaseMessage],
#    (...)
#     976     **kwargs: Any,
#     977 ) -> ChatResult:
#     978     request = self._prepare_request(
#     979         messages,
#     980         stop=stop,
#    (...)
#     987         tool_choice=tool_choice,
#     988     )
# --> 989     response: GenerateContentResponse = _chat_with_retry(
#     990         request=request,
#     991         **kwargs,
#     992         generation_method=self.client.generate_content,
#     993         metadata=self.default_metadata,
#     994     )
#     995     return _response_to_result(response)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:207, in _chat_with_retry(generation_method, **kwargs)
#     204     except Exception as e:
#     205         raise e
# --> 207 return _chat_with_retry(**kwargs)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/tenacity/__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/tenacity/__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:189, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     186 @retry_decorator
#     187 def _chat_with_retry(**kwargs: Any) -> Any:
#     188     try:
# --> 189         return generation_method(**kwargs)
#     190     # Do not retry for these errors.
#     191     except google.api_core.exceptions.FailedPrecondition as exc:
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:867, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     864 self._validate_universe_domain()
#     866 # Send the request.
# --> 867 response = rpc(
#     868     request,
#     869     retry=retry,
#     870     timeout=timeout,
#     871     metadata=metadata,
#     872 )
#     874 # Done; return the response.
#     875 return response
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/grpc/_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/grpc.py:79, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)
#      76         },
#      77     )
# ---> 79 response = continuation(client_call_details, request)
#      80 if logging_enabled:  # pragma: NO COVER
#      81     response_metadata = response.trailing_metadata()
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/grpc/_channel.py:1195, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1183 def with_call(
#    1184     self,
#    1185     request: Any,
#    (...)
#    1190     compression: Optional[grpc.Compression] = None,
#    1191 ) -> Tuple[Any, grpc.Call]:
#    1192     (
#    1193         state,
#    1194         call,
# -> 1195     ) = self._blocking(
#    1196         request, timeout, metadata, credentials, wait_for_ready, compression
#    1197     )
#    1198     return _end_unary_response_blocking(state, call, True, None)
#
# File ~/Documents/diplomka/llm-rag-dip/.venv/lib/python3.11/site-packages/grpc/_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
import json

txt = str(response.content)
try:
    json_response = json.loads(txt)
except json.decoder.JSONDecodeError:
    if "```json" in txt:
        txt = txt.split("```json")[1].split("```")[0]
        json_response = json.loads(txt)
    else:
        raise ValueError(f"Could not parse JSON response: {txt}")
json_response
# Out:
# {'qa_pairs': [{'question': 'Jaké dvě platební výměry vyměřil Finanční úřad v Šumperku žalobci v souvislosti s nadměrným odpočtem DPH?',
#    'golden_answer': 'Dvě platební výměry ze dne 20. 5. 2003 a 5. 8. 2003.',
#    'questions_type': 'factual'},
#   {'question': 'Na základě jaké smlouvy umožňoval žalobce v rozhodném období užívání hokejového stadionu občanskému sdružení H.?',
#    'golden_answer': 'Na základě smlouvy o bezplatné výpůjčce.',
#    'questions_type': 'factual'},
#   {'question': 'Proč Krajský soud v Ostravě zamítl žalobu Josefa P. proti rozhodnutí Finančního ředitelství v Ostravě?',
#    'golden_answer': 'Protože dospěl k názoru, že žalobce zastřel charakter skutečně poskytnutého zdanitelného plnění smlouvou o výpůjčce.',
#    'questions_type': 'reasoning'},
#   {'question': 'Jaké ustanovení občanského zákoníku definuje výpůjčku, na kterou se odvolával Krajský soud v Ostravě?',
#    'golden_answer': 'Ustanovení § 659 občanského zákoníku.',
#    'questions_type': 'legal_interpretation'},
#   {'question': 'Do jaké podpoložky zatřídil Český statistický úřad činnost stěžovatele na žádost žalovaného ze dne 23. 10. 2003?',
#    'golden_answer': 'Do podpoložky 92.61.10 – provoz sportovních areálů a stadionů.',
#    'questions_type': 'factual'},
#   {'question': 'Jak Nejvyšší správní soud rozhodl o rozsudku Krajského soudu v Ostravě v případu sp. zn. 9 Afs 5/2007-70?',
#    'golden_answer': 'Nejvyšší správní soud rozhodnutí Krajského soudu v Ostravě zrušil a věc mu vrátil k dalšímu řízení.',
#    'questions_type': 'procedure'},
#   {'question': 'Jaký je klíčový rozdíl mezi nájmem a výpůjčkou, který Nejvyšší správní soud zdůrazňuje v odůvodnění?',
#    'golden_answer': 'Nájem je vždy pojmově úplatný, zatímco výpůjčka je naopak pojmově bezúplatná.',
#    'questions_type': 'legal_interpretation'},
#   {'question': 'Jakou otázku musí Krajský soud zodpovědět v dalším řízení, aby správně aplikoval daň z přidané hodnoty?',
#    'golden_answer': 'Zda stěžovatelem poskytované plnění je skutečně pasivním přenecháním nemovitého majetku k užívání, či zda je součástí jiné služby.',
#    'questions_type': 'practical'},
#   {'question': 'Který nález Ústavního soudu je uveden jako prejudikatura v souvislosti s prozařováním komunitárního práva do českého právního řádu?',
#    'golden_answer': 'Nález Ústavního soudu č. 410/2001 Sb.',
#    'questions_type': 'legal_interpretation'},
#   {'question': 'Jaký článek šesté směrnice umožňuje členskému státu uplatňovat zdanění určitých typů pronájmu nemovitého majetku?',
#    'golden_answer': 'Čl. 13 (B) (b) šesté směrnice.',
#    'questions_type': 'legal_interpretation'}]}

# %%
extracted_questions = []
for response in questions:
    try:
        json_response = json.loads(str(response.content))
    except json.decoder.JSONDecodeError:
        if "```json" in str(response.content):
            txt = str(response.content).split("```json")[1].split("```")[0]
            json_response = json.loads(txt)
        else:
            raise ValueError(f"Could not parse JSON response: {response.content}")
    extracted_questions.append(json_response)

# %%
extracted_questions
# Out:
# [{'qa_pairs': [{'question': 'Jakého přestupku se měl žalobce dopustit podle rozhodnutí Magistrátu města Plzně?',
#     'golden_answer': 'Přestupku proti bezpečnosti a plynulosti provozu na pozemních komunikacích dle § 22 odst. 1 písm. d) zákona č. 200/1990 Sb., o přestupcích, v souvislosti s porušením § 5 odst. 1 písm. f) zákona o silničním provozu.',
#     'questions_type': 'factual'},
#    {'question': 'Jaká povinnost je uložena řidiči podle § 5 odst. 1 písm. f) zákona o silničním provozu?',
#     'golden_answer': 'Podrobit se na výzvu policisty, příslušníka Vojenské policie, zaměstnavatele, ošetřujícího lékaře nebo strážníka obecní policie vyšetření podle zvláštního právního předpisu ke zjištění, zda není ovlivněn alkoholem.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Co tvrdil žalobce ve své žalobě ohledně výkladu práva ze strany žalovaného?',
#     'golden_answer': 'Žalobce tvrdil, že žalovaný provedl extenzivní výklad práva v jeho neprospěch.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké druhy biologického materiálu jsou uvedeny v § 2 písm. q) zákona č. 379/2005 Sb.?',
#     'golden_answer': 'Žilní krev, moč, sliny, vlasy nebo stěr z kůže či sliznic.',
#     'questions_type': 'factual'},
#    {'question': 'Jak Krajský soud v Plzni rozhodl o žalobě?',
#     'golden_answer': 'Krajský soud v Plzni žalobu zamítl.',
#     'questions_type': 'procedure'},
#    {'question': 'Co je odborné lékařské vyšetření podle § 2 písm. p) zákona č. 379/2005 Sb.?',
#     'golden_answer': 'Cílené klinické vyšetření lékařem a podle jeho ordinace provedení dechové zkoušky nebo odběru vzorků biologického materiálu.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaké byly důsledky odmítnutí odběru krve žalobcem, i když poskytl vzorek moči?',
#     'golden_answer': 'Podle soudu se jednalo o naplnění skutkové podstaty přestupku podle § 22 odst. 1 písm. d) zákona o přestupcích.',
#     'questions_type': 'practical'},
#    {'question': 'Kdy byl žalobce zastaven a kontrolován policií?',
#     'golden_answer': 'Dne 28. 2. 2011 v době okolo 13:10 hodin.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký typ vozidla řídil žalobce při silniční kontrole?',
#     'golden_answer': 'Motorové vozidlo tov. zn. Citroën Xsara.',
#     'questions_type': 'factual'}]},
#  {'qa_pairs': [{'question': 'Co je předmětem rozhodnutí Nejvyššího správního soudu?',
#     'golden_answer': 'Předkládání dokladů potřebných pro provedení kontroly Českou obchodní inspekcí.',
#     'questions_type': 'summary'},
#    {'question': 'Které zákony a paragrafy jsou v rozhodnutí zmíněny v souvislosti s Českou obchodní inspekcí?',
#     'golden_answer': '§ 4 odst. 1 písm. c) a § 9 odst. 1 písm. e) zákona č. 64/1986 Sb., o České obchodní inspekci.',
#     'questions_type': 'factual'},
#    {'question': 'Které zákony a paragrafy jsou v rozhodnutí zmíněny v souvislosti s technickými požadavky na výrobky?',
#     'golden_answer': '§ 18 odst. 1 a § 19 odst. 2 zákona č. 22/1997 Sb., o technických požadavcích na výrobky.',
#     'questions_type': 'factual'},
#    {'question': 'Jak rozhodl soud ohledně výzvy k předložení dokladů podle § 4 odst. 1 písm. c) zákona o České obchodní inspekci?',
#     'golden_answer': 'Výzva k předložení dokladů není opatřením ve smyslu § 9 odst. 1 písm. e) tohoto zákona.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jak lze postihnout nepředložení dokladů potřebných k provedení kontroly podle zákona o technických požadavcích na výrobky?',
#     'golden_answer': 'Nepředložení dokladů lze postihnout dle § 19 odst. 2 téhož zákona.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Kdy byl vydán rozsudek Městského soudu v Praze, na který se rozhodnutí odkazuje?',
#     'golden_answer': '22. 10. 2008',
#     'questions_type': 'factual'},
#    {'question': 'Jakým zákonem a kdy bylo přesunuto písmeno e) § 9 odst. 1 zákona o České obchodní inspekci do písmene d)?',
#     'golden_answer': 'Zákonem č. 155/2010 Sb. s účinností od 1. 8. 2010.',
#     'questions_type': 'factual'},
#    {'question': 'Jakým zákonem a kdy byly změněny § 18 odst. 1 a § 19 odst. 2 zákona o technických požadavcích na výrobky?',
#     'golden_answer': 'Zákonem č. 490/2009 Sb. s účinností od 1. 1. 2010.',
#     'questions_type': 'factual'},
#    {'question': 'Co bylo cílem zákona č. 155/2010 Sb., kterým se měnil zákon o České obchodní inspekci?',
#     'golden_answer': 'Zkvalitnění aplikace zákonů a snížení administrativní zátěže podnikatelů.',
#     'questions_type': 'factual'}]},
#  {'qa_pairs': [{'question': 'Co bylo nařízeno žalobci rozhodnutím Městského úřadu v Blovicích ze dne 21. 3. 2005?',
#     'golden_answer': 'Žalobci bylo nařízeno zazdění zaskleného otvoru ve štítové zdi přiléhající ke stavbě prodejny potravin.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký stavební zákon upravuje řízení o odstranění stavby podle § 88 odst. 1 písm. b)?',
#     'golden_answer': 'Jedná se o zákon č. 50/1976 Sb., o územním plánování a stavebním řádu (stavební zákon), ve znění zákona č. 83/1998 Sb.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Co je účelem řízení o odstranění stavby podle § 88 odst. 1 písm. b) stavebního zákona?',
#     'golden_answer': 'Účelem je uvedení právního a skutečného stavu do souladu, a to buď nařízením odstranění nepovolené stavby, nebo vydáním dodatečného povolení stavby.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Proč Nejvyšší správní soud zrušil rozsudek Krajského soudu v Plzni?',
#     'golden_answer': 'Protože krajský soud neměl dostatečné podklady k posouzení, zda stavba odporuje stavebnímu povolení a schválené projektové dokumentaci, a nevypořádal se s otázkou skutečného stavu v době vydání napadeného správního rozhodnutí.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jakou námitku vznesl žalobce v kasační stížnosti ohledně stavebního povolení?',
#     'golden_answer': 'Namítal, že disponoval platným a účinným stavebním povolením z 26. 10. 1999, jímž byla schválena projektová dokumentace, kterou považoval za závaznou.',
#     'questions_type': 'reasoning'},
#    {'question': 'Na co poukazoval žalobce v souvislosti s řízením vedeným pod sp. zn. 57 Cad 3/2003?',
#     'golden_answer': 'Uvedl, že toto řízení se týkalo osazení okna do otvoru ve štítové zdi, zatímco řízení o odstranění stavby se týkalo otvoru jako takového.',
#     'questions_type': 'reasoning'},
#    {'question': 'Co musí stavební úřad zkoumat v případě stavby provedené v rozporu se stavebním povolením?',
#     'golden_answer': 'Stavební úřad musí především zkoumat, zda a v jakém rozsahu stavba odporuje vlastnímu rozhodnutí o stavebním povolení a schválené projektové dokumentaci.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaké dokumenty chyběly Krajskému soudu v Plzni pro správné posouzení věci?',
#     'golden_answer': 'Předložené správní spisy obsahovaly jen část schválené dokumentace, a to pouze půdorysy dvou nadzemních podlaží.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký byl výsledek kasační stížnosti žalobce?',
#     'golden_answer': 'Nejvyšší správní soud napadený rozsudek Krajského soudu v Plzni zrušil a věc mu vrátil k dalšímu řízení.',
#     'questions_type': 'procedure'}]},
#  {'qa_pairs': [{'question': 'Jaký opravný prostředek podala žalobkyně proti usnesení Městského soudu v Praze?',
#     'golden_answer': 'Podala kasační stížnost.',
#     'questions_type': 'procedure'},
#    {'question': 'Jakou částku se správce daně snažil vymoci od žalobkyně?',
#     'golden_answer': '164 364 473 Kč.',
#     'questions_type': 'factual'},
#    {'question': 'Proč Městský soud v Praze odmítl žalobu?',
#     'golden_answer': 'Protože žalobkyně nevyčerpala řádné opravné prostředky, konkrétně nepodala námitku proti exekučnímu příkazu.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké jsou řádné opravné prostředky podle § 108 odst. 1 daňového řádu z roku 2009?',
#     'golden_answer': 'Odvolání nebo rozklad.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jak Nejvyšší správní soud posoudil závěr Městského soudu, že námitky jsou opravným prostředkem sui generis?',
#     'golden_answer': 'Nejvyšší správní soud konstatoval, že tento závěr nemá oporu v platné právní úpravě.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký je závěr Nejvyššího správního soudu ohledně přípustnosti žaloby ve správním soudnictví proti exekučnímu příkazu správce daně?',
#     'golden_answer': 'Žaloba je přípustná i když daňový subjekt námitku proti exekučnímu příkazu správce daně před podáním správní žaloby neuplatnil.',
#     'questions_type': 'summary'},
#    {'question': 'Podle kterého ustanovení daňového řádu z roku 2009 se doručuje exekuční příkaz a nelze proti němu uplatnit opravné prostředky?',
#     'golden_answer': 'Podle § 178 odst. 4 daňového řádu z roku 2009.',
#     'questions_type': 'factual'},
#    {'question': 'Co je nezbytnou náležitostí rozhodnutí správce daně podle § 102 odst. 1 písm. f) daňového řádu z roku 2009?',
#     'golden_answer': 'Poučení, zda je možné proti rozhodnutí podat odvolání, v jaké lhůtě je tak možno učinit, u kterého správce daně se odvolání podává, spolu s upozorněním na případné vyloučení odkladného účinku.',
#     'questions_type': 'legal_interpretation'}]},
#  {'qa_pairs': [{'question': 'Kdy Nejvyšší správní soud rozhodl o kasační stížnosti žalobkyň?',
#     'golden_answer': 'Nejvyšší správní soud rozhodl o kasační stížnosti žalobkyň dne 23. 5. 2013.',
#     'questions_type': 'factual'},
#    {'question': 'Na základě jakého ustanovení zákona o Ústavním soudu poskytl žalovaný Ústavnímu soudu vyjádření?',
#     'golden_answer': 'Žalovaný poskytl Ústavnímu soudu vyjádření na základě § 48 odst. 2 zákona o Ústavním soudu.',
#     'questions_type': 'factual'},
#    {'question': 'Proč Nejvyšší správní soud zrušil rozsudek Krajského soudu v Brně?',
#     'golden_answer': 'Nejvyšší správní soud zrušil rozsudek Krajského soudu v Brně, protože shledal, že žaloba byla podána opožděně a měla být odmítnuta již krajským soudem.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký je závěr Nejvyššího správního soudu ohledně včasnosti podání žaloby stěžovatelkami?',
#     'golden_answer': 'Nejvyšší správní soud dospěl k závěru, že žaloba byla podána po uplynutí zákonné dvouměsíční lhůty ve smyslu § 84 odst. 1 s. ř. s., a tedy opožděně.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký právní názor zaujal Nejvyšší správní soud ohledně vyjádření správního orgánu podaného Ústavnímu soudu?',
#     'golden_answer': 'Nejvyšší správní soud zaujal právní názor, že vyjádření správního orgánu podle § 48 odst. 2 zákona o Ústavním soudu nemůže být zásahem ve smyslu § 82 s. ř. s., a tedy ani zásahem nezákonným.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'V čem spočívala neudržitelnost konstrukce Krajského soudu v Brně, jak uvádí Nejvyšší správní soud?',
#     'golden_answer': 'Neudržitelnost spočívala v tom, že Krajský soud hodnotil vyjádření žalovaného jako zásah podle § 82 s. ř. s., ale zároveň dospěl k závěru, že tento zásah nemůže být nikdy nezákonný, neboť má základ v zákoně.',
#     'questions_type': 'reasoning'},
#    {'question': 'Co tvrdily žalobkyně ohledně data, kdy se dozvěděly o vyjádření žalovaného?',
#     'golden_answer': 'Žalobkyně tvrdily, že se o vyjádření žalovaného dozvěděly až dne 17. 1. 2013 ze znaleckého posudku.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký právní předpis upravuje lhůtu pro podání žaloby o ochraně před nezákonným zásahem?',
#     'golden_answer': 'Lhůtu pro podání žaloby o ochraně před nezákonným zásahem upravuje § 84 odst. 1 soudního řádu správního.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaký byl předmět řízení před Ústavním soudem, pro které žalovaný poskytl vyjádření?',
#     'golden_answer': 'Předmětem řízení před Ústavním soudem byl návrh na zrušení některých ustanovení zákonů v souvislosti se zavedením odvodů a zdanění elektřiny z fotovoltaických elektráren.',
#     'questions_type': 'summary'}]},
#  {'qa_pairs': [{'question': 'Jakou pokutu uložil Úřad práce v Semilech žalobci a za jaké porušení?',
#     'golden_answer': 'Úřad práce v Semilech uložil žalobci pokutu 150 000 Kč za porušení § 2 odst. 2 zákona č. 1/1991 Sb., o zaměstnanosti.',
#     'questions_type': 'factual'},
#    {'question': 'Proč Nejvyšší správní soud zrušil rozhodnutí žalovaného?',
#     'golden_answer': 'Nejvyšší správní soud zrušil rozhodnutí žalovaného pro vady řízení, protože skutkový stav, který vzal správní orgán za základ napadeného rozhodnutí, neměl oporu ve spise a vyžadoval zásadní doplnění.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké konkrétní kroky měl správní orgán I. stupně učinit podle Nejvyššího správního soudu pro zjištění skutečného zaměstnavatele cizinců?',
#     'golden_answer': 'Správní orgán I. stupně měl vyslechnout zejména tyto cizince, zjistit, kdo je přijímal do pracovního poměru, kdo jim vyplácí mzdu atd.',
#     'questions_type': 'practical'},
#    {'question': 'Jaké argumenty uváděl žalobce ohledně pětidenní lhůty pro podání námitek k protokolu?',
#     'golden_answer': 'Žalobce tvrdil, že pětidenní lhůta je nepřiměřená a že se řídil poučením v protokolu, kde je uvedeno, že může podat námitky do 5 dnů od seznámení se s protokolem.',
#     'questions_type': 'factual'},
#    {'question': 'Na základě čeho žalovaný usuzoval, že smlouvy o dílo měly pouze zastřít jiný právní vztah?',
#     'golden_answer': 'Žalovaný usuzoval na základě kontrolního zjištění ze dne 8. 4. 1999, kdy bylo zjištěno, že pracovník žalobce rozděluje cizince do směn, přiděluje jim práci a tu také kontroluje.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké paragrafy správního řádu namítal žalobce, že byly porušeny?',
#     'golden_answer': 'Žalobce namítal porušení § 3 odst. 1, 2, 3, 4 a § 32 odst. 1 správního řádu.',
#     'questions_type': 'factual'},
#    {'question': 'Jaké společnosti figurovaly v případu kromě žalobce a Ministerstva práce a sociálních věcí?',
#     'golden_answer': 'V případu figurovaly společnosti K., s. r. o., a I., v. o. s.',
#     'questions_type': 'factual'},
#    {'question': 'Jak Nejvyšší správní soud zdůvodnil, proč nezrušil i rozhodnutí správního orgánu I. stupně?',
#     'golden_answer': 'Soud neshledal důvod k současnému zrušení rozhodnutí vydaného v I. stupni, neboť žalovaný se jím bude znovu zabývat v řízení odvolacím.',
#     'questions_type': 'reasoning'}]},
#  {'qa_pairs': [{'question': 'Který správní orgán vydal územní rozhodnutí na základě žádosti obce Orlické Záhoří?',
#     'golden_answer': 'Městský úřad Rychnov nad Kněžnou, odbor výstavby a životního prostředí.',
#     'questions_type': 'factual'},
#    {'question': 'Jaké argumenty použila žalobkyně proti postupu žalovaného v přezkumném řízení?',
#     'golden_answer': 'Žalobkyně tvrdila, že jí nebyla přiznána práva účastníka v přezkumném řízení a že Závěr č. 79, na který se žalovaný odvolával, není právním předpisem a nemění zákon.',
#     'questions_type': 'reasoning'},
#    {'question': 'Na jaký právní předpis se odvolával žalovaný, když tvrdil, že žalobkyně nemohla být účastníkem přezkumného řízení?',
#     'golden_answer': 'Žalovaný se odvolával na § 95 odst. 4 správního řádu.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jak Městský soud v Praze rozhodl o žalobě obce Orlické Záhoří?',
#     'golden_answer': 'Městský soud v Praze zrušil rozhodnutí ministryně pro místní rozvoj a rozhodnutí Ministerstva pro místní rozvoj a věc vrátil k dalšímu řízení.',
#     'questions_type': 'procedure'},
#    {'question': 'Jaké rozhodnutí bylo předmětem zkráceného přezkumného řízení?',
#     'golden_answer': 'Předmětem zkráceného přezkumného řízení byla rozhodnutí krajského úřadu o zamítnutí odvolání osob zúčastněných na řízení proti rozhodnutím stavebního úřadu o žádostech žalobkyně.',
#     'questions_type': 'factual'},
#    {'question': 'Proč soud nesouhlasil s argumentací žalovaného, že přezkumné řízení se nedotýká práv žadatele o vydání územního rozhodnutí?',
#     'golden_answer': 'Soud uvedl, že znovuotevření odvolacího řízení v důsledku využití mimořádných opravných prostředků se zřetelně dotýká práv žadatele, pro něhož byla vydaná pravomocná rozhodnutí důležitým aspektem pro navazující stavební činnost.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký je stěžejní právní názor soudu v této věci?',
#     'golden_answer': 'Soud sdílí právní názor žalobkyně, že měla být účastníkem jak přezkumného řízení, tak řízení o rozkladu.',
#     'questions_type': 'summary'},
#    {'question': 'Co musí správní orgány důkladně zvažovat v přezkumném řízení podle § 94 odst. 4 a 5 správního řádu?',
#     'golden_answer': 'Správní orgány musí důkladně zvažovat, zda zásahem do již pravomocného správního rozhodnutí jeho změnou či zrušením nebude jinému účastníkovi řízení či veřejnému zájmu způsobena zjevně nepřiměřená újma.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaké konkrétní územní rozhodnutí bylo vydáno na základě žádosti obce Orlické Záhoří?',
#     'golden_answer': 'Bylo vydáno rozhodnutí o umístění stavby Skiareál „Jadrná“ a rozhodnutí o změně využití území Skiareál „Jadrná“.',
#     'questions_type': 'factual'}]},
#  {'qa_pairs': [{'question': 'Který zákon upravuje udělování výjimek ze zákazů u zvláště chráněných rostlin a živočichů?',
#     'golden_answer': 'Zákon č. 114/1992 Sb., o ochraně přírody a krajiny, ve znění zákona č. 218/2004 Sb.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Co bylo předmětem sporu v dané věci?',
#     'golden_answer': 'Povolení výjimky ze zákazu u zvláště chráněných rostlin a živočichů za účelem realizace protipovodňových opatření.',
#     'questions_type': 'summary'},
#    {'question': 'Jaký byl argument žalobce proti rozhodnutí Krajského úřadu Moravskoslezského kraje?',
#     'golden_answer': 'Žalobce tvrdil, že těžba štěrků není potřebná pro zajištění protipovodňové ochrany.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jak Městský soud v Praze zdůvodnil zrušení rozhodnutí žalovaného?',
#     'golden_answer': 'Městský soud uvedl, že se žalovaný nevypořádal s odborným vyjádřením, podle kterého štěrky neovlivňují průtočnou kapacitu řeky.',
#     'questions_type': 'reasoning'},
#    {'question': 'Co namítal žalovaný (stěžovatel) v kasační stížnosti?',
#     'golden_answer': 'Namítal, že městský soud nerozlišoval správní řízení podle § 4 odst. 2 a § 56 zákona o ochraně přírody a krajiny.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jak Nejvyšší správní soud rozhodl o kasační stížnosti?',
#     'golden_answer': 'Nejvyšší správní soud kasační stížnost zamítl.',
#     'questions_type': 'procedure'},
#    {'question': 'Kdy Krajský úřad Moravskoslezského kraje vydal rozhodnutí o udělení výjimky?',
#     'golden_answer': 'Dne 4. 2. 2005.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký veřejný zájem byl zvažován v souvislosti s udělením výjimky?',
#     'golden_answer': 'Ochrana před povodněmi.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Co musí být doloženo, aby bylo možné dovodit, že zájem ochrany před povodněmi výrazně převažuje nad zájmem ochrany přírody?',
#     'golden_answer': 'Musí být doloženo, že uvažovaný zásah je potřebný a že neexistuje jiné uspokojivé řešení.',
#     'questions_type': 'legal_interpretation'}]},
#  {'qa_pairs': [{'question': 'Jakou právní otázku tento případ nastolil?',
#     'golden_answer': 'Otázku rozsahu a podmínek ručení podle § 141a zákona o zaměstnanosti za úhradu pokuty uložené subdodavateli ručitele za umožnění výkonu nelegální práce.',
#     'questions_type': 'summary'},
#    {'question': 'Podle kterého ustanovení zákona o zaměstnanosti ručí právnická nebo fyzická osoba za úhradu pokuty?',
#     'golden_answer': 'Podle § 141a zákona o zaměstnanosti.',
#     'questions_type': 'factual'},
#    {'question': 'Jaké tři přestupky spáchala společnost Minaki property, s. r. o., v likvidaci?',
#     'golden_answer': 'Umožnění výkonu nelegální práce podle § 5 písm. e) bodů 1 a 2, umožnění výkonu nelegální práce podle § 5 písm. e) bodu 3 a zastřené zprostředkování zaměstnání podle § 5 písm. g) zákona o zaměstnanosti.',
#     'questions_type': 'factual'},
#    {'question': 'V jaké výši byla uložena úhrnná pokuta společnosti Minaki za spáchané přestupky?',
#     'golden_answer': 'Úhrnná pokuta byla uložena ve výši 7 600 000 Kč.',
#     'questions_type': 'factual'},
#    {'question': 'Co namítala žalobkyně ve správní žalobě?',
#     'golden_answer': 'Namítala nemožnost rozhodnout o ručení za úhradu úhrnné pokuty uložené za více přestupků, absenci prokázání její vědomosti o umožnění výkonu nelegální práce společností Minaki a právo vznést námitky i vůči zbylým částem rozhodnutí o přestupku.',
#     'questions_type': 'factual'},
#    {'question': 'Jak Nejvyšší správní soud korigoval závazný právní názor krajského soudu?',
#     'golden_answer': 'Nejvyšší správní soud korigoval závazný právní názor krajského soudu tak, že institut ručení lze uplatnit i na úhradu úhrnné pokuty, ale správní orgán musí rozsah ručení omezit tak, aby odpovídal pouze sankci za přestupek dle § 139 odst. 1 písm. f) nebo § 140 odst. 1 písm. e) zákona o zaměstnanosti, a poměrům ručitele.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké tři kroky má správní orgán učinit při rozhodování o rozsahu ručení dle Nejvyššího správního soudu?',
#     'golden_answer': 'Stanovit maximální přípustný rozsah ručení, provést úvahu o výši pokuty za přestupek dle § 139 odst. 1 písm. f) nebo § 140 odst. 1 písm. e) bez souběhu, a zohlednit přiměřenost výše ručení majetkovým poměrům ručitele.',
#     'questions_type': 'practical'},
#    {'question': 'Proč Nejvyšší správní soud zamítl kasační stížnost?',
#     'golden_answer': 'Protože rozsudek krajského soudu ve výroku a v rozhodné míře odůvodnění obstojí, ale vyslovený závazný právní názor krajského soudu je zapotřebí částečně korigovat.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké námitky může ručitel uplatnit v řízení podle § 141a zákona o zaměstnanosti?',
#     'golden_answer': 'Ručitel může uplatnit veškeré námitky, které mohla vznést osoba obviněná z přestupku.',
#     'questions_type': 'legal_interpretation'}]},
#  {'qa_pairs': [{'question': 'Kdy vydal Obvodní báňský úřad v Mostě rozhodnutí o stanovení chráněného ložiskového území Počaply?',
#     'golden_answer': '9. dubna 1990.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký právní předpis stanoví, že nerostné bohatství v České republice je ve vlastnictví státu?',
#     'golden_answer': '§ 5 horního zákona (zákona č. 44/1988 Sb.).',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Proč Nejvyšší správní soud zamítl kasační stížnost?',
#     'golden_answer': 'Protože neshledal kasační stížnost důvodnou, stěžovatelé měli možnost se seznámit s plánem sanace a rekultivace a vyjádřit se k němu.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké společnosti se týkal převod dobývacího prostoru Nučničky I.?',
#     'golden_answer': 'Společností Procházka, spol. s r.o. a Gravel, spol. s r.o.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký byl plošný rozsah dobývacího prostoru Nučničky I. podle aktualizovaného návrhu?',
#     'golden_answer': '0,2975345 km2.',
#     'questions_type': 'factual'},
#    {'question': 'Co bylo předmětem smlouvy o převodu dobývacího prostoru Nučničky I. ze dne 22. 4. 2002?',
#     'golden_answer': 'Úplatný převod dobývacího prostoru Nučničky I. ze spol. Procházka, spol. s r. o. na spol. Gravel, spol. s r. o.',
#     'questions_type': 'factual'},
#    {'question': 'Proč nebyla stěžovateli V. K. umožněno nahlédnout do smlouvy o převodu dobývacího prostoru?',
#     'golden_answer': 'Protože společnost Gravel, spol. s r.o. považovala tuto smlouvu za obchodní tajemství.',
#     'questions_type': 'factual'},
#    {'question': 'Jaké námitky vznesli stěžovatelé v kasační stížnosti?',
#     'golden_answer': 'Namítli, že jim nebyla dána možnost seznámit se s podklady rozhodnutí týkajícími se plánu sanace a rekultivace dobývacího prostoru Nučničky I. a vyjádřit se k němu.',
#     'questions_type': 'procedure'},
#    {'question': 'Podle jakého paragrafu horního zákona byl stanoven dobývací prostor Nučničky I.?',
#     'golden_answer': 'Podle § 27 odst. 1 horního zákona (zákona č. 44/1988 Sb.).',
#     'questions_type': 'legal_interpretation'}]},
#  {'qa_pairs': [{'question': 'Jaké daně se týkal spor mezi SULKOM, s. r. o., a Odvolacím finančním ředitelstvím?',
#     'golden_answer': 'Spor se týkal daně z příjmů právnických osob.',
#     'questions_type': 'factual'},
#    {'question': 'V jaké výši doměřil Finanční úřad pro Jihomoravský kraj žalobkyni daň z příjmů právnických osob za zdaňovací období 2014?',
#     'golden_answer': 'Finanční úřad doměřil žalobkyni daň z příjmů právnických osob ve výši 1 080 340 Kč za zdaňovací období 2014.',
#     'questions_type': 'factual'},
#    {'question': 'Jak Nejvyšší správní soud rozhodl o kasační stížnosti ve vztahu k rozhodnutí žalovaného ze dne 17. 10. 2018, čj. 46008/18/5200-11432-709409?',
#     'golden_answer': 'Nejvyšší správní soud kasační stížnost v tomto ohledu zamítl jako nedůvodnou.',
#     'questions_type': 'procedure'},
#    {'question': 'Jaké ustanovení advokátního tarifu se použije při spojení dvou a více věcí, pro něž spojení ke společnému projednání není stanoveno jiným právním předpisem?',
#     'golden_answer': 'Použije se § 12 odst. 3 advokátního tarifu.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Na základě čeho dospěl Nejvyšší správní soud k závěru, že je možné zrušit rozsudek krajského soudu pouze ve vztahu k jednomu z napadených rozhodnutí?',
#     'golden_answer': 'Nejvyšší správní soud dospěl k tomuto závěru s ohledem na obecnější závěry plynoucí z usnesení rozšířeného senátu Nejvyššího správního soudu ze dne 9. 6. 2022, čj. 2 As 347/2019-81, č. 4368/2022Sb. NSS, bodu 32.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké náklady řízení tvoří společné náklady stěžovatelky v řízení o žalobě?',
#     'golden_answer': 'Společné náklady tvoří odměna zástupce (daňového poradce).',
#     'questions_type': 'factual'},
#    {'question': 'Proč soud nepřiznal žalovanému náhradu nákladů řízení ve vztahu k rozhodnutí týkajícímu se zdaňovacího období 2014?',
#     'golden_answer': 'Protože žalovanému v řízení nevznikly žádné náklady nad rámec jeho běžné úřední činnosti.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký byl celkový výsledek řízení před Nejvyšším správním soudem?',
#     'golden_answer': 'Nejvyšší správní soud zrušil rozhodnutí žalovaného za zdaňovací období 2013 a vrátil věc žalovanému k dalšímu řízení. Ve zbytku kasační stížnost zamítl.',
#     'questions_type': 'summary'},
#    {'question': 'Jaká částka byla stěžovatelce přiznána jako náhrada nákladů řízení a do kdy ji má žalovaný zaplatit?',
#     'golden_answer': 'Stěžovatelce byla přiznána náhrada nákladů ve výši 18 568 Kč, kterou má žalovaný zaplatit k rukám jejího zástupce do 30 dnů od právní moci rozsudku.',
#     'questions_type': 'factual'}]},
#  {'qa_pairs': [{'question': 'Jak Nejvyšší správní soud rozhodl o kasačních stížnostech žalobce?',
#     'golden_answer': 'Nejvyšší správní soud kasační stížnosti zamítl.',
#     'questions_type': 'factual'},
#    {'question': 'Které soudce tvořili senát Nejvyššího správního soudu v této věci?',
#     'golden_answer': 'Senát tvořili JUDr. Petr Příhoda, JUDr. Michal Mazanec a JUDr. Jan Passer.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký právní předpis upravuje postup v řízení ve věcech upravených zákonem o silniční dopravě?',
#     'golden_answer': 'Podle § 39 zákona o silniční dopravě se postupuje podle obecných předpisů o správním řízení, pokud jednotlivá ustanovení tohoto zákona nestanoví jinak.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Proč Nejvyšší správní soud nepřisvědčil stěžovateli v jeho námitce, že městský soud pochybil, když se nezabýval pouze otázkou účastenství?',
#     'golden_answer': 'Protože městský soud se řádně vypořádal se všemi žalobními námitkami. Stěžovatel naopak v žalobách vznesl otázky, jejichž řešení má být předmětem řízení o udělení licence.',
#     'questions_type': 'reasoning'},
#    {'question': 'Podle kterého ustanovení správního řádu jsou účastníky řízení o žádosti?',
#     'golden_answer': 'Podle § 27 správního řádu jsou účastníky řízení o žádosti žadatel a další dotčené osoby.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jak Nejvyšší správní soud zdůvodnil, proč se nezabýval argumentací v kasační stížnosti, kterou stěžovatel přiložil k podání ze dne 29. 12. 2008?',
#     'golden_answer': 'Protože věc, jejíž připojení stěžovatel navrhl, nebyla městským soudem Nejvyššímu správnímu soudu dosud předložena a bylo by to v rozporu s principem ekonomie řízení.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký byl předmět sporu v posuzovaných věcech?',
#     'golden_answer': 'Předmětem sporu bylo účastenství v řízeních o udělení licence na provozování veřejné linkové osobní dopravy vnitrostátní.',
#     'questions_type': 'summary'},
#    {'question': 'Jaký je závěr Nejvyššího správního soudu ohledně účastenství v řízení o udělení licence na linky vnitrostátní přepravy z pohledu práva Společenství?',
#     'golden_answer': 'Nejvyšší správní soud uzavírá, že účastenství v řízení o udělení licence na linky vnitrostátní přepravy není právem Společenství založeno.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Co namítal stěžovatel ohledně podjatosti úředníků krajského úřadu?',
#     'golden_answer': 'Stěžovatel namítal, že oprávněné úřední osoby rozhodující za krajský úřad byly přímo vyloučeny z řízení.',
#     'questions_type': 'factual'}]},
#  {'qa_pairs': [{'question': 'Jakou pokutu uložila ČIŽP žalobkyni a za co?',
#     'golden_answer': 'ČIŽP uložila žalobkyni pokutu ve výši 125 000 Kč za porušení povinnosti nakládat s odpady pouze v zařízeních, která jsou k tomu určena, dle § 12 odst. 2 zákona o odpadech.',
#     'questions_type': 'factual'},
#    {'question': 'Na základě jakého ustanovení zákona o odpadech ČIŽP uložila pokutu?',
#     'golden_answer': 'ČIŽP uložila pokutu podle § 66 odst. 4 písm. b) zákona o odpadech.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký byl hlavní argument žalobkyně proti uložení pokuty?',
#     'golden_answer': 'Žalobkyně tvrdila, že vlastní souhlas k provozování mobilní recyklační linky, který pokrývá celé území Jihomoravského kraje, a proto nepotřebuje další souhlas pro stacionární zařízení v Oblekovicích.',
#     'questions_type': 'reasoning'},
#    {'question': 'Proč Městský soud v Praze zamítl žalobu?',
#     'golden_answer': 'Městský soud v Praze zamítl žalobu, protože se ztotožnil s názorem, že souhlas k provozování mobilní recyklační linky neopravňuje žalobkyni k provozování stacionárního zařízení.',
#     'questions_type': 'reasoning'},
#    {'question': 'Co je podle § 14 odst. 1 zákona o odpadech nutné pro provozování zařízení ke sběru, výkupu, využívání nebo odstraňování odpadů?',
#     'golden_answer': 'Podle § 14 odst. 1 zákona o odpadech je pro provozování takového zařízení nutné rozhodnutí krajského úřadu, kterým je udělen souhlas k provozování tohoto zařízení a s jeho provozním řádem.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaké argumenty použil žalovaný k zamítnutí odvolání žalobkyně?',
#     'golden_answer': 'Žalovaný argumentoval tím, že souhlas k mobilní recyklační lince se nevztahuje na stacionární zařízení a že každé zařízení vyžaduje individuální podmínky provozu a samostatný provozní řád.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký souhlas měla žalobkyně udělený Krajským úřadem Jihomoravského kraje ze dne 17. 9. 2009?',
#     'golden_answer': 'Žalobkyně měla udělený souhlas k provozování mobilní recyklační linky na zpracování stavebních a demoličních odpadů s působností pro Jihomoravský kraj.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký správní delikt se žalobkyně dopustila podle názoru žalovaného?',
#     'golden_answer': 'Žalobkyně se dopustila správního deliktu dle § 66 odst. 4 písm. b) zákona o odpadech, protože neplnila povinnost uvedenou v § 12 odst. 2 zákona o odpadech.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jak Městský soud v Praze interpretoval podmínku č. 5 rozhodnutí Krajského úřadu Jihomoravského kraje ze dne 17. 9. 2009?',
#     'golden_answer': 'Městský soud v Praze interpretoval tuto podmínku tak, že se týká výlučně odpadů přijatých do mobilní recyklační linky, nikoliv do stacionárního zařízení v Oblekovicích.',
#     'questions_type': 'legal_interpretation'}]},
#  {'qa_pairs': [{'question': 'Jaký zákon upravuje problematiku, o kterou se v tomto případě jedná?',
#     'golden_answer': 'Zákon č. 182/2006 Sb., o úpadku a způsobech jeho řešení (insolvenční zákon), ve znění zákona č. 399/2012 Sb.',
#     'questions_type': 'factual'},
#    {'question': 'O jaké pohledávky se v daném případě jedná?',
#     'golden_answer': 'O pohledávky z mimosmluvních sankcí postihujících majetek dlužníka dle § 170 písm. d) insolvenčního zákona.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký byl závěr Nejvyššího správního soudu ohledně možnosti stanovit zánik mimosmluvních sankcí v reorganizačním plánu?',
#     'golden_answer': 'Nejvyšší správní soud rozhodl, že § 359 insolvenčního zákona neumožňuje stanovit v reorganizačním plánu zánik pohledávek z mimosmluvních sankcí postihujících majetek dlužníka dle § 170 písm. d) téhož zákona.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jak Nejvyšší správní soud odůvodnil zamítnutí argumentu stěžovatelky o aplikaci druhé věty § 359 insolvenčního zákona na mimosmluvní sankce?',
#     'golden_answer': 'Nejvyšší správní soud uvedl, že druhá věta § 359 hovoří o odchylné úpravě pohledávek podle věty první, a výslovně odkazuje pouze na druhý typ pohledávek, které nezanikají, jestliže tak stanoví reorganizační plán. Navíc, ve výčtu možných odchylných ustanovení se neuvádí zánik pohledávky.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jakou povinnost uložila Všeobecná zdravotní pojišťovna České republiky žalobkyni?',
#     'golden_answer': 'Uložila jí povinnost zaplatit penále ve výši 2 106 810 Kč podle § 18 odst. 1 zákona o pojistném na veřejné zdravotní pojištění.',
#     'questions_type': 'factual'},
#    {'question': 'Proč Městský soud v Praze nejprve zamítl žalobu a poté byl jeho rozsudek zrušen Nejvyšším správním soudem?',
#     'golden_answer': 'Původní rozsudek Městského soudu byl zrušen, protože se nevypořádal s námitkou zániku pohledávek z mimosmluvních sankcí na základě reorganizačního plánu a argumentoval již zrušeným zákonem o konkursu a vyrovnání.',
#     'questions_type': 'procedure'},
#    {'question': 'Jaký argument použila stěžovatelka pro tvrzení, že pohledávky z mimosmluvních sankcí zanikly?',
#     'golden_answer': 'Stěžovatelka tvrdila, že v reorganizačním plánu stanovila, že pohledávky z mimosmluvních sankcí zanikají, a že reorganizační plán nabyl účinnosti dne 4. 9. 2012.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký je podle Nejvyššího správního soudu důvod pro odlišný režim mimosmluvních sankcí oproti jiným pohledávkám dle § 170 insolvenčního zákona?',
#     'golden_answer': 'Mimosmluvní sankce jsou trestem za protiprávní jednání dlužníka a jejich trvání i po přijetí reorganizačního plánu vyjadřuje veřejný zájem na dodržování právních předpisů.',
#     'questions_type': 'reasoning'},
#    {'question': 'Co je předmětem kasační stížnosti dle odůvodnění Nejvyššího správního soudu?',
#     'golden_answer': 'Předmětem kasační stížnosti je otázka, zda lze § 359 insolvenčního zákona vykládat tak, že lze stanovit zánik mimosmluvních sankcí postihujících majetek dlužníka v reorganizačním plánu.',
#     'questions_type': 'summary'}]},
#  {'qa_pairs': [{'question': 'Co je předmětem tohoto rozhodnutí Nejvyššího správního soudu?',
#     'golden_answer': 'Předmětem je povolení obnovy daňového řízení a kasační stížnost žalobce.',
#     'questions_type': 'summary'},
#    {'question': 'Na základě jakého ustanovení daňového řádu se řeší obnova řízení v tomto případě?',
#     'golden_answer': 'Řeší se podle § 56a odst. 2 zákona ČNR č. 337/1992 Sb., o správě daní a poplatků.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký byl závěr rozšířeného senátu ohledně použití obnovy řízení, pokud bylo správní rozhodnutí již dříve přezkoumáno soudem?',
#     'golden_answer': 'Rozšířený senát rozhodl, že použití obnovy řízení nebrání předchozímu přezkoumání správního rozhodnutí soudem, pokud je obnova řízení odůvodněna novými skutečnostmi nebo důkazy, které nemohly být bez zavinění daňového subjektu nebo správce daně uplatněny v původním řízení a nebyly ani předmětem tohoto zkoumání soudem.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Proč stěžovatel (žalobce) požádal o obnovu řízení?',
#     'golden_answer': 'Žalobce požádal o obnovu řízení z důvodů zjištění nových skutečností, které se dozvěděl z trestního spisu vedeného u Vrchního soudu v Olomouci.',
#     'questions_type': 'factual'},
#    {'question': 'Jak Městský soud v Praze odůvodnil zamítnutí žaloby?',
#     'golden_answer': 'Městský soud v Praze zamítl žalobu s odůvodněním, že obnově řízení brání zákonná překážka ve smyslu § 56a odst. 2 d. ř., neboť rozhodnutí celního orgánu, vůči němuž měla obnova řízení směřovat, bylo již přezkoumáno soudem.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký argument uvedl stěžovatel v kasační stížnosti ohledně § 56a odst. 2 d. ř.?',
#     'golden_answer': 'Stěžovatel uvedl, že městský soud aplikací § 56a odst. 2 d. ř. porušil jeho ústavní právo na spravedlivý proces, neboť vylučuje možnost přezkoumat evidentně nesprávná rozhodnutí po objevení se nových skutečností.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jak se liší obnova řízení od jiných mimořádných opravných prostředků podle odůvodnění?',
#     'golden_answer': 'Obnova řízení se liší tím, že orgán, který původně rozhodoval, neměl objektivně v době svého rozhodování k dispozici všechny existující skutečnosti či důkazy.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaký princip je třeba respektovat, aby nedocházelo ke svévolnému omezení základních práv a svobod?',
#     'golden_answer': 'Je třeba respektovat princip proporcionality.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Co je třeba zkoumat pro zjištění, zda je dána výluka obnovy řízení založená § 56a odst. 2 d. ř.?',
#     'golden_answer': 'Je třeba zkoumat průběh a výsledek správního i soudního řízení a skutečnosti či důkazy, které v něm byly nebo měly být zkoumány.',
#     'questions_type': 'procedure'}]},
#  {'qa_pairs': [{'question': 'Jakou pokutu uložila Rada pro rozhlasové a televizní vysílání České televizi?',
#     'golden_answer': 'Rada uložila České televizi pokutu ve výši 500 000 Kč.',
#     'questions_type': 'factual'},
#    {'question': 'Za co byla Česká televize pokutována podle rozhodnutí Rady pro rozhlasové a televizní vysílání?',
#     'golden_answer': 'Za neplnění povinností stanovených v § 31 odst. 2 a 3 zákona o vysílání.',
#     'questions_type': 'factual'},
#    {'question': 'Proč Městský soud v Praze zrušil rozhodnutí Rady pro rozhlasové a televizní vysílání?',
#     'golden_answer': 'Protože rozhodnutí Rady neobsahovalo konkrétní skutková zjištění a dostatečné odůvodnění, zejména ohledně povahy pořadu "H." a porušení zásad objektivity a vyváženosti.',
#     'questions_type': 'reasoning'},
#    {'question': 'Co bylo stěžejní pro uložení pokuty podle § 60 odst. 1 písm. b) zákona o vysílání?',
#     'golden_answer': 'Stěžejní bylo, zda se jednalo o zpravodajský nebo politicko-publicistický pořad.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaký argument použila Rada pro rozhlasové a televizní vysílání v kasační stížnosti?',
#     'golden_answer': 'Rada namítala, že Městský soud v Praze nesprávně posoudil právní otázku a že má právo samostatně posoudit pořad.',
#     'questions_type': 'procedure'},
#    {'question': 'Jak Nejvyšší správní soud rozhodl o kasační stížnosti Rady pro rozhlasové a televizní vysílání?',
#     'golden_answer': 'Nejvyšší správní soud kasační stížnost zamítl.',
#     'questions_type': 'factual'},
#    {'question': 'Co Nejvyšší správní soud vytkl Radě pro rozhlasové a televizní vysílání v souvislosti s pořadem "H."?',
#     'golden_answer': 'Nejvyšší správní soud vytkl Radě, že nevěcně definovala, co se rozumí pořadem zpravodajským, resp. politicko-publicistickým, a nezdůvodnila, proč pořad "H." těmto znakům odpovídá.',
#     'questions_type': 'reasoning'},
#    {'question': 'Co je podle § 31 odst. 3 zákona o vysílání zakázáno ve zpravodajských a politicko-publicistických pořadech?',
#     'golden_answer': 'Je zakázáno jednostranně zvýhodňovat žádnou politickou stranu nebo hnutí, popřípadě jejich názory nebo názory jednotlivých skupin veřejnosti.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Proč bylo rozhodnutí Rady pro rozhlasové a televizní vysílání shledáno nepřezkoumatelným?',
#     'golden_answer': 'Protože nebylo jasné, zda se jednalo o pořad, na který lze uplatnit požadavky obsažené v § 31 odst. 2 a 3 zákona o vysílání.',
#     'questions_type': 'reasoning'}]},
#  {'qa_pairs': [{'question': 'Co bylo předmětem sporu v dané věci?',
#     'golden_answer': 'Spor se týkal zrušení Sdělení Ministerstva práce a sociálních věcí o rozšíření závaznosti kolektivní smlouvy vyššího stupně.',
#     'questions_type': 'summary'},
#    {'question': 'Který soud rozhodoval o návrhu navrhovatelky v prvním stupni?',
#     'golden_answer': 'Městský soud v Praze.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký právní předpis upravuje kolektivní vyjednávání?',
#     'golden_answer': 'Zákon č. 2/1991 Sb., o kolektivním vyjednávání.',
#     'questions_type': 'factual'},
#    {'question': 'Proč Nejvyšší správní soud zamítl kasační stížnost navrhovatelky?',
#     'golden_answer': 'Nejvyšší správní soud dospěl k závěru, že procesní vada neměla vliv na zákonnost vydaného sdělení a obsah přezkoumávaného sdělení byl vyprázdněn.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké základní zásady činnosti správních orgánů se uplatňují i v procesu rozšíření závaznosti kolektivní smlouvy?',
#     'golden_answer': 'Základní zásady činnosti správních orgánů formulované v § 2–8 správního řádu.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Co Nejvyšší správní soud vytkl Ministerstvu práce a sociálních věcí v souvislosti s uplatňováním § 4 správního řádu?',
#     'golden_answer': 'Nevytkl mu postup podle části šesté správního řádu, ale porušení zásad podle § 2-8 správního řádu, konkrétně neuveřejnění návrhu na rozšíření závaznosti kolektivní smlouvy.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jakým způsobem mělo Ministerstvo práce a sociálních věcí postupovat, aby vyhovělo požadavku plynoucímu z § 4 správního řádu?',
#     'golden_answer': 'Například vyvěšením oznámení na úřední desce správního orgánu, že bylo navrženo rozšíření předmětné kolektivní smlouvy na dané odvětví zaměstnavatelů s možností vyjádření dotčených osob v určené lhůtě.',
#     'questions_type': 'practical'},
#    {'question': 'Na které roky se vztahovala kolektivní smlouva, jejíž rozšíření závaznosti bylo předmětem přezkumu?',
#     'golden_answer': 'Na roky 2015 a 2016.',
#     'questions_type': 'factual'},
#    {'question': 'Proč se na proces rozšíření kolektivní smlouvy nepoužije část šestá správního řádu?',
#     'golden_answer': 'Protože zákon o kolektivním vyjednávání, konkrétně § 7, celý proces vydání sdělení komplexně upravuje.',
#     'questions_type': 'reasoning'}]},
#  {'qa_pairs': [{'question': 'Jaký právní předpis upravuje osobní účast daňového subjektu v daňovém řízení?',
#     'golden_answer': 'Osobní účast daňového subjektu v daňovém řízení upravuje § 10 odst. 4 zákona č. 337/1992 Sb., o správě daní a poplatků.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Co bylo předmětem přezkumu Nejvyššího správního soudu v dané věci?',
#     'golden_answer': 'Předmětem přezkumu byla povaha úkonu správce daně spočívajícího v předvolání k ústnímu jednání daňového subjektu, který si zvolil zástupce.',
#     'questions_type': 'summary'},
#    {'question': 'Proč Nejvyšší správní soud zrušil rozsudek Krajského soudu v Českých Budějovicích?',
#     'golden_answer': 'Nejvyšší správní soud zrušil rozsudek Krajského soudu v Českých Budějovicích, protože krajský soud nesprávně interpretoval § 10 odst. 4 d. ř. a jeho aplikaci na daný případ.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký názor zaujal Krajský soud v Českých Budějovicích na předvolání žalobce k osobní účasti?',
#     'golden_answer': 'Krajský soud žalobu zamítl a považoval předvolání finančního úřadu k osobní účasti žalobce za zákonné.',
#     'questions_type': 'factual'},
#    {'question': 'Na co poukazoval stěžovatel v kasační stížnosti?',
#     'golden_answer': 'Stěžovatel poukazoval na to, že argumentací krajského soudu by bylo možno odůvodnit nutnost osobní účasti daňového subjektu vždy a že daňový subjekt má právo odpovědět na otázky správce daně písemně.',
#     'questions_type': 'reasoning'},
#    {'question': 'Co je podle Nejvyššího správního soudu nutné pro posouzení, zda je opakované předvolávání daňového subjektu nezákonným zásahem?',
#     'golden_answer': 'Podle Nejvyššího správního soudu, opakované předvolávání daňového subjektu správcem daně může být nezákonným zásahem, bude-li provázeno hrozbou předvedení.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jak se zástupce žalobce vyjádřil ohledně svých znalostí o podnikání klienta?',
#     'golden_answer': 'Zástupce žalobce se písemně vyjádřil, že není o podnikání svého klienta prakticky vůbec informován.',
#     'questions_type': 'factual'},
#    {'question': 'Jaké důsledky může mít pro daňový subjekt neunesení důkazního břemene?',
#     'golden_answer': 'Neunesení důkazního břemene může vést k tomu, že správce daně stanoví daň za použití pomůcek, což může vést k méně přesnému a pro daňový subjekt nevýhodnějšímu stanovení daňové povinnosti.',
#     'questions_type': 'practical'},
#    {'question': 'Kdy byl žalobce poprvé předvolán k ústnímu jednání?',
#     'golden_answer': 'Žalobce byl poprvé předvolán k ústnímu jednání na 23. 6. 2009.',
#     'questions_type': 'factual'}]},
#  {'qa_pairs': [{'question': 'O co se jednalo ve věci Mgr. Jana P. proti České správě sociálního zabezpečení?',
#     'golden_answer': 'Jednalo se o vrácení přeplatku na starobním důchodu.',
#     'questions_type': 'summary'},
#    {'question': 'Kdy vznikl žalobci nárok na starobní důchod?',
#     'golden_answer': 'Dne 10. 1. 2005.',
#     'questions_type': 'factual'},
#    {'question': 'Proč žalovaná rozhodla, že žalobci nenáleží výplata starobního důchodu podle § 37 zákona č. 155/1995 Sb.?',
#     'golden_answer': 'Protože v období od 10. 1. 2005 do 31. 12. 2005 byl zaměstnán v pracovněprávním vztahu sjednaném na dobu neurčitou.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jak Nejvyšší správní soud rozhodl o kasační stížnosti žalobce?',
#     'golden_answer': 'Nejvyšší správní soud kasační stížnost zamítl.',
#     'questions_type': 'procedure'},
#    {'question': 'Podle kterého paragrafu školského zákona byl stěžovatel jmenován zřizovatelem do funkce ředitele školy s účinností od 1. 1. 2006 do 30. 6. 2006?',
#     'golden_answer': 'Podle § 166 školského zákona.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký právní názor zaujal Nejvyšší správní soud ohledně změny pracovního poměru u jmenovaných zaměstnanců?',
#     'golden_answer': 'U jmenovaných zaměstnanců, kteří jsou již u svého zaměstnavatele zaměstnáni v pracovním poměru, dochází k přeměně existujícího pracovního poměru na pracovní poměr založený jmenováním.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Kdy byl žalobce poprvé jmenován do funkce ředitele školy?',
#     'golden_answer': 'S účinností od 1. 1. 1995.',
#     'questions_type': 'factual'},
#    {'question': 'Jaké ustanovení zákoníku práce upravuje výkon funkcí obsazovaných jmenováním?',
# ...
#     'golden_answer': 'Tvrdila, že úřad práce informovala o skutečnosti, že studuje, již 14. 4. 2010, tedy v den podání žádosti o zprostředkování zaměstnání.',
#     'questions_type': 'credibility'},
#    {'question': 'Jak Městský soud v Praze zdůvodnil zamítnutí žaloby?',
#     'golden_answer': 'Uvedl, že skutečnost, že žalobkyni byl povolen individuální studijní plán, nemění nic na tom, že studuje v denní formě studia, a tudíž se jedná o soustavnou přípravu na budoucí povolání.',
#     'questions_type': 'reasoning'},
#    {'question': 'Co je podle § 25 odst. 2 písm. a) školského zákona denní forma vzdělávání?',
#     'golden_answer': 'Výuka organizovaná pravidelně každý den v pětidenním vyučovacím týdnu v průběhu školního roku.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaké formy studia, kromě denní, uvádí školský zákon?',
#     'golden_answer': 'Večerní, dálková, distanční a kombinovaná.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký byl hlavní argument žalobkyně v kasační stížnosti?',
#     'golden_answer': 'Že její studium postrádá prvek soustavnosti požadovaný v § 25 odst. 1 písm. r) zákona o zaměstnanosti, protože školu téměř nenavštěvuje.',
#     'questions_type': 'reasoning'}]},
#  {'qa_pairs': [{'question': 'Kdy byla doručena žaloba Nejvyššímu správnímu soudu?',
#     'golden_answer': 'Žaloba byla doručena Nejvyššímu správnímu soudu dne 24. 4. 2003.',
#     'questions_type': 'factual'},
#    {'question': 'Co bylo předmětem žaloby?',
#     'golden_answer': 'Žalobce se domáhal vyslovení toho, že Zeměměřický a katastrální inspektorát je kompetentní k rozhodnutí o odvolání žalobce proti zamítavému rozhodnutí Katastrálního úřadu Praha-město o žalobcově návrhu na vklad vlastnického práva k nemovitosti.',
#     'questions_type': 'factual'},
#    {'question': 'Proč Nejvyšší správní soud žalobu odmítl?',
#     'golden_answer': 'Nejvyšší správní soud žalobu odmítl jako podanou osobou k tomu zjevně neoprávněnou.',
#     'questions_type': 'reasoning'},
#    {'question': 'Na základě jakého ustanovení soudního řádu správního byla žaloba odmítnuta?',
#     'golden_answer': 'Soud žalobu odmítl podle § 46 odst. 1 písm. c) s. ř. s.',
#     'questions_type': 'factual'},
#    {'question': 'Kdo byl účastníkem řízení o zamítnutí návrhu na vklad vlastnického práva do katastru nemovitostí?',
#     'golden_answer': 'Účastníky řízení byli Stavební bytové družstvo v Praze 8 a Vít N.',
#     'questions_type': 'factual'},
#    {'question': 'Jak Nejvyšší správní soud zdůvodnil, proč zmocněnec není oprávněn podat žalobu o rozhodnutí kompetenčního sporu?',
#     'golden_answer': 'Zmocněnec totiž zásadně toliko jedná jménem účastníka řízení, z jeho procesních i hmotněprávních úkonů vyplývají práva a povinnosti přímo pro účastníka řízení, a nikoli pro zmocněnce samotného.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké ustanovení soudního řádu správního upravuje, kdo může podat žalobu vedle správního orgánu?',
#     'golden_answer': 'Žalobu může podat i ten, o jehož právech a povinnostech bylo nebo mělo být rozhodováno v řízení před správním orgánem, podle ustanovení § 98 odst. 1 s. ř. s.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaký byl vztah MUDr. Vladimíra R. k Vítu N. v dané věci?',
#     'golden_answer': 'MUDr. Vladimír R. vystupoval jako zmocněnec Víta N.',
#     'questions_type': 'factual'},
#    {'question': 'O co se žalobce domáhal žalobou?',
#     'golden_answer': 'Žalobce se domáhal určení pravomoci mezi Zeměměřickým a katastrálním inspektorátem Praha 8 a Katastrálním úřadem Praha-město.',
#     'questions_type': 'summary'}]},
#  {'qa_pairs': [{'question': 'Podle jakého paragrafu služebního zákona byl žalobce propuštěn ze služebního poměru?',
#     'golden_answer': 'Podle § 106 odst. 1 písm. d) zákona ČNR č. 186/1992 Sb., o služebním poměru příslušníků Policie České republiky.',
#     'questions_type': 'factual'},
#    {'question': 'Co konkrétně žalobce odcizil v prodejně v Ch.? ',
#     'golden_answer': 'Odcizil zubní pastu a rostlinný tuk.',
#     'questions_type': 'factual'},
#    {'question': 'Jakou pokutu žalobce zaplatil za odcizení zboží?',
#     'golden_answer': 'Zaplatil blokovou pokutu ve výši 200 Kč.',
#     'questions_type': 'factual'},
#    {'question': 'Jak Krajský soud v Plzni rozhodl o rozhodnutí žalovaného?',
#     'golden_answer': 'Krajský soud v Plzni rozhodnutí žalovaného i rozhodnutí správního orgánu I. stupně zrušil a věc vrátil žalovanému k dalšímu řízení.',
#     'questions_type': 'procedure'},
#    {'question': 'Co je základem pro úsudek o propuštění policisty ze služebního poměru podle § 106 odst. 1 písm. d)?',
#     'golden_answer': 'Základem je úsudek o obsahu a rozsahu neurčitého právního pojmu "porušení služební přísahy zvlášť závažným způsobem".',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'S čím se Nejvyšší správní soud ztotožňuje v odůvodnění svého rozhodnutí?',
#     'golden_answer': 'Nejvyšší správní soud se plně ztotožňuje s argumentací krajského soudu v odůvodnění napadeného rozsudku.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jakou hodnotu mělo odcizené zboží?',
#     'golden_answer': 'Odcizené zboží mělo hodnotu 42,80 Kč.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký argument použil žalovaný (stěžovatel) v kasační stížnosti?',
#     'golden_answer': 'Žalovaný argumentoval, že posouzení závažnosti porušení služební přísahy je v právní úvaze služebního funkcionáře a že úmyslná krádež policistou je vždy zvlášť závažné porušení.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jak Nejvyšší správní soud rozhodl o kasační stížnosti?',
#     'golden_answer': 'Nejvyšší správní soud kasační stížnost zamítl.',
#     'questions_type': 'procedure'}]},
#  {'qa_pairs': [{'question': 'Jaký soud vydal rozhodnutí, které je předmětem tohoto dokumentu?',
#     'golden_answer': 'Nejvyšší správní soud.',
#     'questions_type': 'factual'},
#    {'question': 'Jaké tři podmínky musí být kumulativně splněny pro soudní přezkum aktů správních orgánů podle ustálené judikatury Nejvyššího správního soudu?',
#     'golden_answer': '1) Jde o orgán moci výkonné, 2) tento orgán rozhoduje o právech a povinnostech fyzických a právnických osob, 3) rozhodování se děje v oblasti veřejné správy.',
#     'questions_type': 'reasoning'},
#    {'question': 'Podle jakého ustanovení školského zákona může ředitel mateřské školy rozhodnout o ukončení předškolního vzdělávání?',
#     'golden_answer': 'Podle § 35 odst. 1 školského zákona.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Jaké byly důvody pro ukončení předškolního vzdělávání žalobce a) podle dopisu ze dne 9. 12. 2009?',
#     'golden_answer': 'Špatná komunikace a nedostatečná spolupráce mezi mateřskou školou a rodiči žalobce a) a neuhrazení dlužných plateb rodičovského příspěvku za měsíce říjen a listopad.',
#     'questions_type': 'factual'},
#    {'question': 'Proč Nejvyšší správní soud zrušil usnesení Krajského soudu v Hradci Králové?',
#     'golden_answer': 'Protože dospěl k závěru, že rozhodování mateřské školy zřízené registrovanou církví o ukončení předškolního vzdělávání se odehrává v oblasti veřejné správy a správní soudy jsou příslušné k jeho přezkumu.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký typ stížnosti podali žalobci proti usnesení Krajského soudu?',
#     'golden_answer': 'Podali kasační stížnost.',
#     'questions_type': 'procedure'},
#    {'question': 'Jaké je hlavní téma tohoto rozsudku Nejvyššího správního soudu?',
#     'golden_answer': 'Přezkum rozhodnutí mateřské školy o ukončení předškolního vzdělávání a zda toto rozhodnutí podléhá správnímu soudnictví.',
#     'questions_type': 'summary'},
#    {'question': 'Jaké praktické důsledky má rozhodnutí Nejvyššího správního soudu pro rodiče, jejichž dítěti bylo ukončeno předškolní vzdělávání v církevní mateřské škole?',
#     'golden_answer': 'Mohou se proti takovému rozhodnutí odvolat ke správnímu soudu.',
#     'questions_type': 'practical'},
#    {'question': 'Jak Nejvyšší správní soud argumentuje proti názoru Krajského soudu ohledně aplikace § 165 odst. 2 školského zákona?',
#     'golden_answer': 'Nejvyšší správní soud tvrdí, že § 165 odst. 2 školského zákona neříká nic o tom, zda se rozhodování církevní mateřské školy o ukončení předškolního vzdělávání odehrává v oblasti státní (veřejné) správy, a proto nelze argumentovat a contrario.',
#     'questions_type': 'reasoning'}]},
#  {'qa_pairs': [{'question': 'Jak Nejvyšší správní soud rozhodl o rozsudku Krajského soudu v Plzni?',
#     'golden_answer': 'Nejvyšší správní soud rozsudek Krajského soudu v Plzni zrušil a věc mu vrátil k dalšímu řízení.',
#     'questions_type': 'procedure'},
#    {'question': 'Jaké daně byly dodatečně vyměřeny žalobci Finančním úřadem v Klatovech?',
#     'golden_answer': 'Byla mu dodatečně vyměřena daň z přidané hodnoty za 3. čtvrtletí 2005 ve výši 94 677 Kč a za 4. čtvrtletí 2005 ve výši 208 541 Kč.',
#     'questions_type': 'factual'},
#    {'question': 'Na základě čeho nabyl žalobce v roce 2004 majetek od Ministerstva obrany?',
#     'golden_answer': 'Žalobce nabyl majetek darováním od Ministerstva obrany.',
#     'questions_type': 'factual'},
#    {'question': 'Jak žalovaný vyložil pojem veřejné správy pro účely zákona o DPH?',
#     'golden_answer': 'Žalovaný jej vyložil tak, že pokud je činnost vykonávána na základě veřejnoprávní normy platné pro veřejnoprávní subjekt, aniž by ji stejným způsobem mohla provádět soukromá osoba, jedná se o výkon veřejné správy.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'O co opřel žalovaný kasační stížnost proti rozsudku krajského soudu?',
#     'golden_answer': 'Žalovaný opřel kasační stížnost o důvod uvedený v § 103 odst. 1 písm. a) s. ř. s., tedy nesprávné posouzení právní otázky krajským soudem.',
#     'questions_type': 'procedure'},
#    {'question': 'Jakou definici osoby povinné k dani uvádí § 5 odst. 1 zákona o DPH?',
#     'golden_answer': 'Osobou povinnou k dani je fyzická nebo právnická osoba, která samostatně uskutečňuje ekonomické činnosti.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Proč Nejvyšší správní soud zrušil rozsudek Krajského soudu v Plzni?',
#     'golden_answer': 'Protože byl založen na nesprávném posouzení právní otázky, konkrétně posouzení soustavnosti ekonomické činnosti žalobce.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaké činnosti žalobce uvádí správce daně ve zprávě o daňové kontrole jako ekonomické?',
#     'golden_answer': 'Práce v lese, těžbu a prodej dřeva, nákladní dopravu, půjčování lešení, kopírování, specializované práce pro stavby a pronájem bytů a nebytových prostor.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký je závěr Nejvyššího správního soudu ohledně povinnosti obce uplatnit daň na výstupu?',
#     'golden_answer': 'Pokud obec neprodávala movité věci v rámci své veřejnoprávní činnosti, ale jako subjekt soukromoprávních vztahů, byla povinna uplatnit daň na výstupu.',
#     'questions_type': 'summary'},
#    {'question': 'Jak se má krajský soud řídit v dalším řízení po zrušení jeho rozsudku Nejvyšším správním soudem?',
#     'golden_answer': 'Krajský soud se má řídit závazným právním názorem kasačního soudu, že předmětné převody majetku žalobce byly uskutečňovány v rámci jeho ekonomické činnosti.',
#     'questions_type': 'practical'}]},
#  {'qa_pairs': [{'question': 'O jakou daň se v tomto případě jedná?',
#     'golden_answer': 'Jedná se o daň z převodu nemovitostí.',
#     'questions_type': 'factual'},
#    {'question': 'Kdy nabyla účinnosti verze zákona č. 357/1992 Sb., o dani dědické, dani darovací a dani z převodu nemovitostí, relevantní pro toto rozhodnutí?',
#     'golden_answer': 'Účinnosti nabyla do 31. 5. 2001.',
#     'questions_type': 'factual'},
#    {'question': 'Co podléhalo osvobození od daně z převodu nemovitostí podle § 20 odst. 6 písm. e) zákona č. 357/1992 Sb.?',
#     'golden_answer': 'Vklad nemovitosti do obchodní společnosti při splnění podmínky pětileté účasti společníka na společnosti.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Proti komu směřovala kasační stížnost žalobkyně?',
#     'golden_answer': 'Proti Finančnímu ředitelství pro hlavní město Prahu.',
#     'questions_type': 'factual'},
#    {'question': 'Jak rozhodl Nejvyšší správní soud?',
#     'golden_answer': 'Věc se vrací k projednání a rozhodnutí sedmému senátu.',
#     'questions_type': 'procedure'},
#    {'question': 'Co bylo předmětem sporu mezi Milenou A. a Finančním ředitelstvím?',
#     'golden_answer': 'Spor se týkal daně z převodu nemovitostí.',
#     'questions_type': 'summary'},
#    {'question': 'Jaká podmínka musela být splněna pro úplné osvobození od daně z převodu nemovitostí při vkladu nemovitosti do obchodní společnosti?',
#     'golden_answer': 'Podmínkou byla pětiletá účast společníka na společnosti.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Kdo zastupoval žalobkyni M. A.?',
#     'golden_answer': 'Žalobkyni zastupoval JUDr. Jaroslav Novák, Ph.D., advokát.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký rozsudek Městského soudu v Praze byl napaden kasační stížností?',
#     'golden_answer': 'Byl napaden rozsudek Městského soudu v Praze ze dne 23. 3. 2007, č. j. 7 Ca 250/2005 - 57.',
#     'questions_type': 'factual'}]},
#  {'qa_pairs': [{'question': 'Podle jakého paragrafu zákona o komoditních burzách bylo žalobkyni odejmuto státní povolení?',
#     'golden_answer': 'Podle § 35 odst. 3 písm. f) zákona o komoditních burzách.',
#     'questions_type': 'factual'},
#    {'question': 'Jak Nejvyšší správní soud definuje organizování burzovních obchodů?',
#     'golden_answer': 'Jako vytváření podmínek pro soustředění nabídky a poptávky po komoditách a vytváření dalších podmínek pro uzavírání burzovních obchodů.',
#     'questions_type': 'legal_interpretation'},
#    {'question': 'Co bylo hlavním důvodem, pro který Ministerstvo zemědělství odejmulo žalobkyni státní povolení k provozování komoditní burzy?',
#     'golden_answer': 'Podle ministerstva žalobkyně neorganizovala burzovní obchody průběžně a řádně, protože v daném období byl uzavřen pouze jeden burzovní obchod.',
#     'questions_type': 'factual'},
#    {'question': 'Jaký byl závěr Nejvyššího správního soudu ohledně podmíněnosti organizování burzovních obchodů jejich uzavíráním?',
#     'golden_answer': 'Nejvyšší správní soud se neztotožnil s právním závěrem, že by organizování burzovních obchodů bylo podmíněno jejich uzavíráním.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jak Nejvyšší správní soud posoudil argumentaci Městského soudu v Praze?',
#     'golden_answer': 'Nejvyšší správní soud shledal právní závěry Městského soudu v Praze vnitřně rozporné, ale nezrušil jeho rozsudek pro nepřezkoumatelnost, protože pro posouzení věci to nebylo podstatné.',
#     'questions_type': 'reasoning'},
#    {'question': 'Jaký byl argument žalovaného ve vyjádření ke kasační stížnosti?',
#     'golden_answer': 'Žalovaný argumentoval, že organizování burzovních obchodů zahrnuje činnosti směřující k uzavírání burzovních obchodů a že organizování burzovních obchodů nelze oddělit od jejich uzavírání.',
#     'questions_type': 'summary'},
#    {'question': 'Jaký zákon zrušil zákon o burze cenných papírů a přesto s ním zákon o komoditních burzách souvisí?',
#     'golden_answer': 'Zákon o burze cenných papírů byl zrušen zákonem č. 256/2004 Sb., o podnikání na kapitálovém trhu.',
#     'questions_type': 'factual'},
#    {'question': 'Co Nejvyšší správní soud nařídil po zrušení rozsudku Městského soudu v Praze a rozhodnutí ministra zemědělství?',
#     'golden_answer': 'Nejvyšší správní soud vrátil věc žalovanému k dalšímu řízení.',
#     'questions_type': 'procedure'},
#    {'question': 'Co je cílem novely zákona o komoditních burzách provedené zákonem č. 247/2011 Sb.?',
#     'golden_answer': 'Cílem novely bylo posílit státní dozor ve vztahu ke komoditním burzám a vybavit správní orgán efektivnějšími nástroji pro reakci na selhání komoditní burzy.',
#     'questions_type': 'legal_interpretation'}]}]

# %%
formatted_questions = []
global_counter = 0
for response in extracted_questions:
    for qa_pair in response["qa_pairs"]:
        formatted_questions.append({
            "id": global_counter,
            "question": qa_pair["question"],
            "golden_answers": [qa_pair["golden_answer"]],
            "metadata": {
                "questions_type": qa_pair["questions_type"],
            }
        })
        global_counter += 1

# %%
len(formatted_questions)
# Out:
# 597

# %%
with open("nss_questions_full.jsonl", "w", encoding="utf-8") as f:
    for question in formatted_questions:
        f.write(json.dumps(question) + "\n")

# %%
questions_subset = random.sample(formatted_questions, 100)

# %%
with open("nss_questions_100_subset.jsonl", "w", encoding="utf-8") as f:
    for question in questions_subset:
        f.write(json.dumps(question) + "\n")
