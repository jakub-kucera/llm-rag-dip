# %%
old_prompt = """You are given a Czech court decision (“rozhodnutí Nejvyššího správního soudu”):

[DOCUMENT CONTENTS START]
{DOCUMENT_CONTENTS}
[DOCUMENT CONTENTS END]

Your task is to analyze the provided document and generate multiple question–answer pairs about it. The document text is in Czech, but the instructions here are in English.

**Requirements for your output:**
1. **Language:** The questions and answers you produce must be **in Czech**.
2. **Number of QA pairs:** Please produce 5–10 question–answer pairs (depending on the document’s length and complexity).
3. **Question categories:** Each question must correspond to exactly one of these categories (use whichever are relevant, but try to diversify the final set):
   - **Factual (factual)**: Basic factual details, e.g. key dates, numbers, direct quotations.
   - **Reasoning about legal argumentation (reasoning)**: How the court reasoned, references to specific paragraphs, justifications for a particular conclusion.
   - **Interpretation of law (legal_interpretation)**: Questions focusing on how the court applied or interpreted specific statutes, directives, or legal principles.
   - **Credibility / witness or party consistency (credibility)**: Questions about contradictory statements, analysis of witness credibility, or factual inconsistencies identified by the court.
   - **Process aspects (procedure)**: Chronology of steps, who decided what, whether it was an appeal, cassation complaint, etc.
   - **Summary or context (summary)**: A broader summary question about the core issues or overarching legal context.
   - **Practical consequences (practical)**: Questions focusing on the real-world effects of the ruling or instructions for further proceedings.
4. **Structure:** Output a **JSON object** with a top-level key `"qa_pairs"`, containing an **array** of objects. Each object must have these fields:
   - `"question"`: A single question in Czech.
   - `"golden_answer"`: A concise and precise answer in Czech, reflecting the correct or ideal response based on the text.
   - `"questions_type"`: One of the categories above (factual, reasoning, legal_interpretation, credibility, procedure, summary, practical).

**Example JSON output format** (do not produce ellipses "…" in the final output; this is only illustrative):
```
{{
  "qa_pairs": [
    {{
      "question": "V jakém roce podal stěžovatel první žalobu k Městskému soudu v Praze?",
      "golden_answer": "Podal ji v roce 2021.",
      "questions_type": "factual"
    }},
    {{
      "question": "Proč soud odmítl prolomit § 75 odst. 1 s. ř. s. v tomto řízení?",
      "golden_answer": "Protože stěžovatel stále mohl podat novou žádost o azyl, a tím byla zajištěna ochrana non-refoulement.",
      "questions_type": "reasoning"
    }}
  ]
}}

```

**Important**:
- Stay strictly within this JSON structure.
- **Do not** include any additional commentary, markdown formatting, or explanations outside of the JSON.
- Ensure each `"golden_answer"` is factually correct and concise, pulled from or supported by the text.

**Now**:
1. Read carefully the entire Czech court decision above (`{DOCUMENT_CONTENTS}`).
2. Produce a set of **5–10 question–answer pairs** in Czech.
3. Output only the JSON with the specified structure and fields.

Begin.
"""

# %%
old_prompt_2 = """
You are given a Czech court decision (“rozhodnutí Nejvyššího správního soudu”):

[DOCUMENT CONTENTS START]
{DOCUMENT_CONTENTS}
[DOCUMENT CONTENTS END]

Your task is to analyze the provided document and generate multiple question–answer pairs about it. The document text is in Czech, but the instructions here are in English.

**Important context:**
- We have thousands of such decisions in a large corpus.
- Each question must reference at least one **unique or specific detail** from the text (such as the spisová značka, date of the decision, or distinctive phrases or facts) so that we can retrieve the correct document among many.

**Requirements for your output:**
1. **Language:** The questions and answers you produce must be **in Czech**.
2. **Number of QA pairs:** Please produce 5–10 question–answer pairs (depending on the document’s length and complexity).
3. **Question categories:** Each question must correspond to exactly one of these categories (use whichever are relevant, but try to diversify the final set):
   - **Factual (factual)**: Basic factual details, e.g. key dates, numbers, direct quotations.
   - **Reasoning about legal argumentation (reasoning)**: How the court reasoned, references to specific paragraphs, justifications for a particular conclusion.
   - **Interpretation of law (legal_interpretation)**: Questions focusing on how the court applied or interpreted specific statutes, directives, or legal principles.
   - **Credibility / witness or party consistency (credibility)**: Questions about contradictory statements, analysis of witness credibility, or factual inconsistencies identified by the court.
   - **Process aspects (procedure)**: Chronology of steps, who decided what, whether it was an appeal, cassation complaint, etc.
   - **Summary or context (summary)**: A broader summary question about the core issues or overarching legal context.
   - **Practical consequences (practical)**: Questions focusing on the real-world effects of the ruling or instructions for further proceedings.
4. **Structure:** Output a **JSON object** with a top-level key `"qa_pairs"`, containing an **array** of objects. Each object must have these fields:
   - `"question"`: A single question in Czech. **Incorporate at least one unique detail from the decision** (e.g., the specific date, spisová značka, or other distinctive text) so that it is clear you are referencing *this* document.
   - `"golden_answer"`: A concise and precise answer in Czech, reflecting the correct or ideal response based on the text.
   - `"questions_type"`: One of the categories above (factual, reasoning, legal_interpretation, credibility, procedure, summary, practical).

**Example JSON output format** (for illustration only):

{{ "qa_pairs": [ {{ "question": "V jakém roce podal stěžovatel první žalobu k Městskému soudu v Praze v rozhodnutí ze dne 10. 5. 2022, sp. zn. 1 Azs 123/2022-45?", "golden_answer": "Podal ji v roce 2021.", "questions_type": "factual" }}, {{ "question": "Proč soud ve spisu 1 Azs 123/2022-45 z 10. 5. 2022 odmítl prolomit § 75 odst. 1 s. ř. s. v tomto řízení?", "golden_answer": "Protože stěžovatel stále mohl podat novou žádost o azyl, a tím byla zajištěna ochrana non-refoulement.", "questions_type": "reasoning" }} ] }}



**Important**:
- Stay strictly within this JSON structure.
- **Do not** include any additional commentary, markdown formatting, or explanations outside of the JSON.
- Each question must clearly reference a **unique detail** from the text.
- Ensure each `"golden_answer"` is factually correct and concise, pulled from or supported by the text.

**Now**:
1. Read carefully the entire Czech court decision above (between [DOCUMENT CONTENTS START] and [DOCUMENT CONTENTS END]).
2. Produce a set of **5–10 question–answer pairs** in Czech, referencing unique details so we can identify the correct decision among many.
3. Output only the JSON with the specified structure and fields.

Begin.
"""

# %%
prompt = """
You are given a Czech court decision (“rozhodnutí Nejvyššího správního soudu”):

[DOCUMENT CONTENTS START]
{DOCUMENT_CONTENTS}
[DOCUMENT CONTENTS END]

Your task is to:
1. Pretend this decision does not yet exist.
2. Formulate one question in Czech that a lawyer might ask regarding a real-world scenario that parallels or anticipates the content of this (as-yet-nonexistent) court decision. This question may concern matters such as the final verdict, the possibility of appealing the outcome, whether one party can claim compensation of legal expenses, or any other issue arising from the hypothetical scenario.
3. Provide a concise answer—also in Czech—that an LLM RAG system might give, assuming it has access to all historical „rozhodnutí Nejvyššího správního soudu“ and is trying to predict how such a case could be decided under Czech law.

**Output Format Requirements:**
- Return your result as a **single JSON object** with the following top-level keys:
- That element must be an object with the following keys:
  - `"question"`: The single Czech-language question posed from a lawyer’s perspective (as if the court decision does not exist yet).
  - `"golden_answer"`: A short, model-like answer (in Czech) describing how Czech courts might resolve such a scenario.
  - `"questions_type"`: For consistency with our broader system, set this value to a relevant category (e.g., `"reasoning"`, `"legal_interpretation"`, etc.).

Your final output must look like this (example structure only):

```
{{ "question": "…", "golden_answer": "…", "questions_type": "…" }}
```

**Important**:
- Do NOT add any additional commentary or formatting outside of this JSON.
- The `"question"` must be in Czech and reflect a realistic inquiry a lawyer might have about a potential court dispute (similar to what is described in the provided text).
- The `"golden_answer"` must also be in Czech, be relatively concise, and capture how such a scenario could be decided by Czech courts, drawing on similar historical precedents or legal principles.
- Use whichever `"questions_type"` fits best from our established categories (for example: `"factual"`, `"reasoning"`, `"legal_interpretation"`, `"credibility"`, `"procedure"`, `"summary"`, or `"practical"`).

Begin.
"""

# %%
# ! pip install langchain-google-genai

# %%
import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    # model="gemini-2.5-pro-exp-03-25",
    temperature=0.5,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
documents = os.listdir("../files")

# %%
documents = [doc for doc in documents if doc.endswith(".txt")]

# %%
questions = {}

# %%
# filter only documents newever than 2020
documents = [doc for doc in documents if int(doc.split('.')[0].split("_")[-1]) > 2020]
len(documents)
# Out:
# 564

# %%
# get random 100 documents
import random
documents_subset = random.sample(documents, 200)

# %%
documents_subset[:1]
# Out:
# ['4607_2024.txt']

# %%
questions
# Out:
# {'4607_2024.txt': AIMessage(content='```json\n{\n  "question": "Pokud finanční úřad zadržuje nadměrný odpočet DPH po dobu daňové kontroly, je úroková sazba stanovená jako repo sazba ČNB zvýšená o 2 procentní body v souladu s právem EU, i když daňový subjekt tvrdí, že skutečné náklady na překlenovací úvěr byly vyšší?",\n  "golden_answer": "Podle judikatury Nejvyššího správního soudu, konkrétně rozsudku 8 Afs 274/2022, je úroková sazba ve výši repo sazby ČNB zvýšené o 2 procentní body v souladu s právem EU, pokud pokrývá průměrné náklady na úvěry poskytované nefinančním podnikům. Individuální nároky na náhradu škody převyšující stanovený úrok je třeba uplatnit samostatně, ale samotná sazba je považována za vyhovující požadavkům EU.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-a8c25a2d-e37e-4ed5-b7df-8c210fd1680d-0', usage_metadata={'input_tokens': 20126, 'output_tokens': 256, 'total_tokens': 20382, 'input_token_details': {'cache_read': 0}}),
#  '4518_2023.txt': AIMessage(content='```json\n{\n  "question": "Pokud zpravodajská služba odmítne soudu poskytnout bližší informace o zdrojích utajované informace, na základě které správní orgán zrušil cizinci trvalý pobyt, protože by to ohrozilo její činnost, může soud toto rozhodnutí správního orgánu zrušit z důvodu nedostatečného prokázání skutkového stavu?",\n  "golden_answer": "Ano, soud může rozhodnutí správního orgánu zrušit, pokud mu zpravodajská služba neposkytne dostatečně konkrétní informace o zdrojích a metodách získání utajované informace, aby mohl posoudit její věrohodnost. Soud musí mít možnost ověřit věrohodnost a relevanci utajované informace, aby byla zajištěna spravedlivost řízení a vyloučena libovůle správních orgánů.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-82681edb-d682-45b2-90c2-a14bc0e311a5-0', usage_metadata={'input_tokens': 5574, 'output_tokens': 218, 'total_tokens': 5792, 'input_token_details': {'cache_read': 0}}),
#  '4357_2022.txt': AIMessage(content='```json\n{\n  "question": "Pokud byl státnímu zaměstnanci omylem vyplacen vyšší plat, než na který měl nárok, a následně byl přeřazen na jiné služební místo k jinému služebnímu úřadu, je k rozhodnutí o vrácení neoprávněně vyplacené částky příslušný soud, nebo služební orgán, a pokud služební orgán, tak který?",\n  "golden_answer": "Dle ustálené judikatury Nejvyššího správního soudu, v takovém případě je příslušný rozhodnout služební orgán, a to ten, u kterého byl státní zaměstnanec ve služebním poměru v době vzniku nároku na plat, tedy v době neoprávněné výplaty. Soud není příslušný, neboť se jedná o věc služebního poměru.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-0447babf-4eff-4ea2-8669-d690f165e520-0', usage_metadata={'input_tokens': 8969, 'output_tokens': 220, 'total_tokens': 9189, 'input_token_details': {'cache_read': 0}}),
#  '4255_2021.txt': AIMessage(content='```json\n{\n  "question": "Pokud je cizinec zaměstnán jako vědecký pracovník v České republice a jeho nezletilá dcera nemá trvalý pobyt ani povolení k zaměstnání, má dcera nárok na účast ve veřejném zdravotním pojištění v České republice na základě směrnice 2005/71/ES nebo 2011/98/EU?",\n  "golden_answer": "Ne, Nejvyšší správní soud pravděpodobně rozhodne, že směrnice 2005/71/ES a 2011/98/EU nezakládají nárok rodinných příslušníků vědeckých pracovníků nebo pracovníků ze třetích zemí na účast ve veřejném zdravotním pojištění. Tyto směrnice se vztahují primárně na samotné pracovníky, nikoliv na jejich rodinné příslušníky, pokud tito sami nesplňují definici pracovníka ze třetí země.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-3178bd04-06f7-4c6f-a9a8-ed8e052fc196-0', usage_metadata={'input_tokens': 11709, 'output_tokens': 243, 'total_tokens': 11952, 'input_token_details': {'cache_read': 0}}),
#  '4245_2021.txt': AIMessage(content='```json\n{\n  "question": "Pokud mi Ministerstvo zdravotnictví odepře nahlédnout do spisu týkajícího se mimořádného opatření, které mi ukládá povinnosti, a tvrdí, že nejsem účastníkem řízení, mohu se proti tomuto postupu bránit žalobou na ochranu před nezákonným zásahem podle § 82 s. ř. s., a to s odkazem na § 27 a § 38 správního řádu?",\n  "golden_answer": "Ne, podle judikatury Nejvyššího správního soudu (např. čj. 18 A 79/2020-34) u opatření obecné povahy, jakými jsou mimořádná opatření Ministerstva zdravotnictví, nepřichází v úvahu účastenství ve správním řízení ve smyslu § 27 správního řádu. Tím pádem nelze ani hovořit o nezákonném zásahu odepřením nahlížení do spisu z titulu účastenství dle § 38 správního řádu. Žaloba na ochranu před nezákonným zásahem by byla soudem odmítnuta.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-e5b569da-220f-4afa-bb11-8584db27c0be-0', usage_metadata={'input_tokens': 7832, 'output_tokens': 298, 'total_tokens': 8130, 'input_token_details': {'cache_read': 0}}),
#  '4252_2021.txt': AIMessage(content='```json\n{\n  "question": "Pokud provozovatel nepovolených herních zařízení argumentuje, že jeho náklady (např. mzdy zaměstnanců, daně) by měly být odečteny od vypočteného \\"výnosu\\" z nepovolené činnosti, aby se zjistila skutečná ekonomická výhoda, obstojí tato argumentace u Nejvyššího správního soudu?",\n  "golden_answer": "Ne, tato argumentace s největší pravděpodobností neobstojí. Nejvyšší správní soud se obvykle přiklání k názoru, že \\"výnos\\" z nepovolené loterie se rovná rozdílu mezi přijatými vklady a vyplacenými výhrami, a nelze jej zaměňovat se \\"ziskem\\" z podnikání. Náklady, včetně mezd a daní, se do výpočtu nezahrnují, protože by to popřelo samotný koncept neoprávněné ekonomické výhody.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-153359dc-8d09-4d07-a029-479da65dd037-0', usage_metadata={'input_tokens': 4387, 'output_tokens': 243, 'total_tokens': 4630, 'input_token_details': {'cache_read': 0}}),
#  '4237_2021.txt': AIMessage(content='```json\n{\n  "question": "Pokud zákazník objedná zboží přes e-shop během státního svátku, ale osobně si ho vyzvedne a zaplatí v kamenné prodejně s prodejní plochou nad 200 m² také během tohoto svátku, porušuje provozovatel prodejny zákaz prodeje dle zákona o prodejní době?",\n  "golden_answer": "Ne, pokud k uzavření kupní smlouvy došlo online, samotné vydání zboží a platba v prodejně během svátku nepředstavuje porušení zákazu prodeje. Rozhodující je, že smlouva byla uzavřena mimo kamennou prodejnu, a výdej zboží je pouze realizací již existující smlouvy.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-7668924e-a479-4f67-bb6c-b6c55e05d554-0', usage_metadata={'input_tokens': 22870, 'output_tokens': 178, 'total_tokens': 23048, 'input_token_details': {'cache_read': 0}}),
#  '4491_2023.txt': AIMessage(content='```json\n{\n  "question": "Klient, obchodník s elektronikou, byl obviněn z vědomé účasti na daňovém podvodu, ačkoliv správce daně neprokázal, u kterého konkrétního článku obchodního řetězce došlo k neodvedení DPH. Stačí k prokázání vědomé účasti na podvodu pouhá existence nepřímých indicií, které naznačují, že klient o podvodu musel vědět, i když nevěděl o detailech podvodného mechanismu?",\n  "golden_answer": "Ano, dle ustálené judikatury Nejvyššího správního soudu postačí k prokázání vědomé účasti na podvodu na DPH, zjistí-li správce daně řadu nepřímých indicií, které ve svém souhrnu prokazují, že se daňový subjekt podvodu na DPH účastnil a že o tom musel vědět. Správce daně nemusí prokázat, že daňový subjekt věděl o tom, u kterého článku řetězce byla identifikována chybějící daň a v jakých detailech podvodný mechanismus spočíval.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-a835922c-e673-43c3-af32-c36420d5d192-0', usage_metadata={'input_tokens': 18903, 'output_tokens': 300, 'total_tokens': 19203, 'input_token_details': {'cache_read': 0}}),
#  '4495_2023.txt': AIMessage(content='```json\n{\n  "question": "Klientovi bylo doručeno sdělení Ministerstva vnitra o nesplnění podmínek pro změnu zaměstnavatele dle § 42g odst. 9 zákona o pobytu cizinců, ale sdělení neobsahovalo poučení o možnosti podat žalobu. Jaká je lhůta pro podání žaloby v takovém případě a má klient nárok na náhradu nákladů řízení, pokud Ministerstvo vnitra následně sdělení zruší?",\n  "golden_answer": "Vzhledem k absenci poučení o opravném prostředku se třicetidenní lhůta pro podání žaloby prodlužuje na tři měsíce. Pokud Ministerstvo vnitra sdělení zruší z důvodu, že žaloba byla podána důvodně, má klient nárok na náhradu nákladů řízení dle § 60 odst. 3 s. ř. s., protože ke zrušení došlo v důsledku pozdějšího chování Ministerstva vnitra.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-8f60a7bb-a72c-484d-a136-262e3b638f23-0', usage_metadata={'input_tokens': 7549, 'output_tokens': 251, 'total_tokens': 7800, 'input_token_details': {'cache_read': 0}}),
#  '4623_2024.txt': AIMessage(content='```json\n{\n  "question": "Pokud zdravotnická dokumentace žadatelky o odškodnění za protiprávní sterilizaci chybí a žadatelka předloží svědectví a jiné indicie, které podporují její tvrzení, ale neposkytují nezvratný důkaz, jaký standard důkazu musí správní orgán požadovat, aby žádost zamítl?",\n  "golden_answer": "I když zdravotnická dokumentace chybí, správní orgán musí posoudit, zda žadatelka předestřela alespoň na první pohled hájitelné tvrzení o protiprávní sterilizaci. Pokud indicie ve svém souhrnu nepřipouštějí jiné racionální vysvětlení, než že k protiprávní sterilizaci pravděpodobně došlo, musí správní orgány považovat předpoklady pro přiznání odškodnění za naplněné, ledaže samy prokáží, že ke skutečnostem žadatelkou tvrzeným dojít nemohlo. Jinak řečeno, správní orgán nemůže žádost zamítnout jen proto, že žadatelka neposkytla nezvratný důkaz, pokud její tvrzení podporují jiné indicie.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-124213ee-133b-4944-8798-7e3e65788560-0', usage_metadata={'input_tokens': 11263, 'output_tokens': 304, 'total_tokens': 11567, 'input_token_details': {'cache_read': 0}}),
#  '4425_2023.txt': AIMessage(content='```json\n{\n  "question": "Pokud jeden ze spoluvlastníků pozemku dlouhodobě toleroval užívání cesty veřejností, ale později s tím začal nesouhlasit, a mezitím došlo ke změně vlastníků, je pro určení, zda se jedná o veřejně přístupnou účelovou komunikaci, rozhodující i stanovisko nových spoluvlastníků, kteří s veřejným užíváním souhlasí?",\n  "golden_answer": "Ne, pro vznik veřejně přístupné účelové komunikace je nutný souhlas všech spoluvlastníků. I aktivní nesouhlas jednoho ze spoluvlastníků, bez ohledu na výši jeho podílu, vylučuje konkludentní souhlas s veřejným užíváním. Stanovisko nových spoluvlastníků, kteří s užíváním souhlasí, samo o sobě nestačí, pokud dříve některý ze spoluvlastníků nesouhlasil.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-59543bb1-52c7-4796-8bce-bb697dbfa1ba-0', usage_metadata={'input_tokens': 15067, 'output_tokens': 230, 'total_tokens': 15297, 'input_token_details': {'cache_read': 0}}),
#  '4494_2023.txt': AIMessage(content='```json\n{\n  "question": "Kliente dovezl léčiva ze třetí země v režimu tranzitu a následně je prodal české firmě, která je uvedla na trh. Dopustil se klient přestupku podle zákona o léčivech, i když sám léčiva na trh neuvedl?",\n  "golden_answer": "Podle judikatury Nejvyššího správního soudu, pokud klient léčiva pouze pořídil ze třetí země v režimu tranzitu a sám je na trh neuvedl, ale prodal je subjektu, který je následně uvedl na trh, nedopustil se klient přestupku spočívajícího v dovozu léčiv bez povolení. Rozhodující je, kdo léčiva fakticky uvedl do volného oběhu.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-525fef27-370e-4ba4-b741-98da3e34bec6-0', usage_metadata={'input_tokens': 14069, 'output_tokens': 204, 'total_tokens': 14273, 'input_token_details': {'cache_read': 0}}),
#  '4366_2022.txt': AIMessage(content='```json\n{\n  "question": "Pokud Ministerstvo spravedlnosti zruší insolvenčnímu správci povolení z důvodu opakovaných pochybení, ale některá z těchto pochybení se stala před delší dobou, může se správce úspěšně bránit s argumentem, že ministerstvo jednalo příliš pozdě, i když zákon o insolvenčních správcích nestanoví konkrétní promlčecí lhůtu?",\n  "golden_answer": "I když zákon o insolvenčních správcích nestanoví pro zrušení povolení konkrétní promlčecí lhůtu, ministerstvo je limitováno obecnými zásadami správního řízení, zejména zásadou minimalizace zásahů a zásadou rychlosti. Soud bude zkoumat, zda zrušení povolení po delší době od pochybení je proporcionální a zda neohrožuje právní jistotu správce. Důležitá je závažnost a četnost pochybení v nedávné době před rozhodnutím o zrušení povolení.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-0d7d34d7-02c8-4b75-a719-0f9f2491438d-0', usage_metadata={'input_tokens': 4634, 'output_tokens': 255, 'total_tokens': 4889, 'input_token_details': {'cache_read': 0}}),
#  '4406_2022.txt': AIMessage(content='```json\n{\n  "question": "Pokud prezident republiky udělí milost osobě odsouzené za korupci, a já, jako občan, se cítím být tímto rozhodnutím dotčen na svých právech z důvodu narušení principu rovnosti a důvěry ve spravedlnost, mohu se proti tomuto rozhodnutí prezidenta republiky úspěšně bránit žalobou ve správním soudnictví?",\n  "golden_answer": "Ne, rozhodnutí prezidenta republiky o udělení milosti nepodléhá přezkumu ve správním soudnictví. Nejvyšší správní soud se již dříve vyjádřil, že prezident v takovém případě nevystupuje jako správní orgán, ale jako orgán ústavní, a jeho rozhodnutí je ústavním aktem, který správní soudy nemají pravomoc přezkoumávat. Občan se nemůže úspěšně bránit žalobou, neboť nemá subjektivní veřejné právo na potrestání pachatele.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-73089eda-c1dc-4480-b616-1e59d6601999-0', usage_metadata={'input_tokens': 4982, 'output_tokens': 253, 'total_tokens': 5235, 'input_token_details': {'cache_read': 0}}),
#  '4353_2022.txt': AIMessage(content='```json\n{\n  "question": "Pokud byl příslušník bezpečnostního sboru vyslán na denní studium civilní vysoké školy během výkonu funkce zařazené do I. kategorie a po ukončení studia se vrátil zpět k výkonu funkce v I. kategorii, započítává se doba studia do doby výkonu funkce v I. kategorii pro účely snížení věkové hranice pro nárok na starobní důchod, i když toto studium není výslovně uvedeno v rezortním seznamu jako výkon práce I. nebo II. kategorie?",\n  "golden_answer": "Ano, doba studia na civilní vysoké škole, která byla obklopena výkonem funkce zařazené do I. kategorie, se posuzuje jako výkon funkce v této kategorii pro účely snížení věkové hranice pro vznik nároku na starobní důchod dle § 174 odst. 1 písm. c) zákona č. 100/1988 Sb., a to i v případě, že studium není výslovně uvedeno v rezortním seznamu. Rozhodující je, že studium probíhalo v době zařazení do I. kategorie a po jeho ukončení se příslušník vrátil k výkonu funkce v této kategorii.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-06223d6a-57b5-4970-878c-2413b041950f-0', usage_metadata={'input_tokens': 5526, 'output_tokens': 303, 'total_tokens': 5829, 'input_token_details': {'cache_read': 0}}),
#  '4568_2024.txt': AIMessage(content='```json\n{\n  "question": "Klientovi byla udělena neuspokojivá známka z chování na vysvědčení. Podali jsme žádost o přezkum řediteli školy, který hodnocení potvrdil. Můžeme se proti tomuto potvrzení bránit žalobou u správního soudu, a pokud ano, s jakou šancí na úspěch?",\n  "golden_answer": "Podle ustálené judikatury Nejvyššího správního soudu, např. usnesení Krajského soudu v Brně čj. 62 A 79/2023-36, hodnocení chování žáka a přezkum jeho výsledků dle § 69 odst. 10 školského zákona nezasahují do práv žáka a jsou ze soudního přezkumu vyloučeny. Žaloba by byla nepřípustná.",\n  "questions_type": "legal_interpretation"\n}\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run-5755a1cb-288c-4ec8-a174-3f130bcf44c7-0', usage_metadata={'input_tokens': 3878, 'output_tokens': 223, 'total_tokens': 4101, 'input_token_details': {'cache_read': 0}})}

# %%
from time import sleep
from tqdm import tqdm

for doc in tqdm(documents_subset[16:]):
    with open(os.path.join("../files", doc), "r", encoding="utf-8") as f:
        text = f.read()
    prompt_text = prompt.format(DOCUMENT_CONTENTS=text)
    response = llm.invoke(prompt_text)
    questions[doc] = response
    sleep(4)
# Out:
# 100%|██████████| 184/184 [18:20<00:00,  5.98s/it]

# %%
import json

txt = str(response.content)
try:
    json_response = json.loads(txt)
except json.decoder.JSONDecodeError:
    if "```json" in txt:
        txt = txt.split("```json")[1].split("```")[0]
        json_response = json.loads(txt)
    else:
        raise ValueError(f"Could not parse JSON response: {txt}")
json_response
# Out:
# {'question': 'Klient pobírá invalidní důchod z mládí ze Slovenska přiznaný ještě za Československa. Nyní pracuje v České republice a platí zde sociální pojištění. Může si nárokovat přiznání invalidního důchodu i v České republice, aby se mu zohlednila doba pojištění získaná po rozdělení Československa?',
#  'golden_answer': 'Ne, podle ustálené judikatury Nejvyššího správního soudu a Smlouvy mezi Českou republikou a Slovenskou republikou o sociálním zabezpečení (čl. 33) nemá poživatel slovenského invalidního důchodu přiznaného před rozdělením ČSFR nárok na souběžný invalidní důchod v České republice, i když splňuje podmínky pro jeho přiznání, neboť by došlo k dvojímu započtení doby pojištění.',
#  'questions_type': 'legal_interpretation'}

# %%
extracted_questions = []
for file, response in questions.items():
    try:
        json_response = json.loads(str(response.content))
        json_response['file'] = file
    except json.decoder.JSONDecodeError:
        if "```json" in str(response.content):
            txt = str(response.content).split("```json")[1].split("```")[0]
            json_response = json.loads(txt)
            json_response['file'] = file
        else:
            raise ValueError(f"Could not parse JSON response: {response.content}")
    extracted_questions.append(json_response)

# %%
extracted_questions
# Out:
# [{'question': 'Pokud finanční úřad zadržuje nadměrný odpočet DPH po dobu daňové kontroly, je úroková sazba stanovená jako repo sazba ČNB zvýšená o 2 procentní body v souladu s právem EU, i když daňový subjekt tvrdí, že skutečné náklady na překlenovací úvěr byly vyšší?',
#   'golden_answer': 'Podle judikatury Nejvyššího správního soudu, konkrétně rozsudku 8 Afs 274/2022, je úroková sazba ve výši repo sazby ČNB zvýšené o 2 procentní body v souladu s právem EU, pokud pokrývá průměrné náklady na úvěry poskytované nefinančním podnikům. Individuální nároky na náhradu škody převyšující stanovený úrok je třeba uplatnit samostatně, ale samotná sazba je považována za vyhovující požadavkům EU.',
#   'questions_type': 'legal_interpretation',
#   'file': '4607_2024.txt'},
#  {'question': 'Pokud zpravodajská služba odmítne soudu poskytnout bližší informace o zdrojích utajované informace, na základě které správní orgán zrušil cizinci trvalý pobyt, protože by to ohrozilo její činnost, může soud toto rozhodnutí správního orgánu zrušit z důvodu nedostatečného prokázání skutkového stavu?',
#   'golden_answer': 'Ano, soud může rozhodnutí správního orgánu zrušit, pokud mu zpravodajská služba neposkytne dostatečně konkrétní informace o zdrojích a metodách získání utajované informace, aby mohl posoudit její věrohodnost. Soud musí mít možnost ověřit věrohodnost a relevanci utajované informace, aby byla zajištěna spravedlivost řízení a vyloučena libovůle správních orgánů.',
#   'questions_type': 'legal_interpretation',
#   'file': '4518_2023.txt'},
#  {'question': 'Pokud byl státnímu zaměstnanci omylem vyplacen vyšší plat, než na který měl nárok, a následně byl přeřazen na jiné služební místo k jinému služebnímu úřadu, je k rozhodnutí o vrácení neoprávněně vyplacené částky příslušný soud, nebo služební orgán, a pokud služební orgán, tak který?',
#   'golden_answer': 'Dle ustálené judikatury Nejvyššího správního soudu, v takovém případě je příslušný rozhodnout služební orgán, a to ten, u kterého byl státní zaměstnanec ve služebním poměru v době vzniku nároku na plat, tedy v době neoprávněné výplaty. Soud není příslušný, neboť se jedná o věc služebního poměru.',
#   'questions_type': 'legal_interpretation',
#   'file': '4357_2022.txt'},
#  {'question': 'Pokud je cizinec zaměstnán jako vědecký pracovník v České republice a jeho nezletilá dcera nemá trvalý pobyt ani povolení k zaměstnání, má dcera nárok na účast ve veřejném zdravotním pojištění v České republice na základě směrnice 2005/71/ES nebo 2011/98/EU?',
#   'golden_answer': 'Ne, Nejvyšší správní soud pravděpodobně rozhodne, že směrnice 2005/71/ES a 2011/98/EU nezakládají nárok rodinných příslušníků vědeckých pracovníků nebo pracovníků ze třetích zemí na účast ve veřejném zdravotním pojištění. Tyto směrnice se vztahují primárně na samotné pracovníky, nikoliv na jejich rodinné příslušníky, pokud tito sami nesplňují definici pracovníka ze třetí země.',
#   'questions_type': 'legal_interpretation',
#   'file': '4255_2021.txt'},
#  {'question': 'Pokud mi Ministerstvo zdravotnictví odepře nahlédnout do spisu týkajícího se mimořádného opatření, které mi ukládá povinnosti, a tvrdí, že nejsem účastníkem řízení, mohu se proti tomuto postupu bránit žalobou na ochranu před nezákonným zásahem podle § 82 s. ř. s., a to s odkazem na § 27 a § 38 správního řádu?',
#   'golden_answer': 'Ne, podle judikatury Nejvyššího správního soudu (např. čj. 18 A 79/2020-34) u opatření obecné povahy, jakými jsou mimořádná opatření Ministerstva zdravotnictví, nepřichází v úvahu účastenství ve správním řízení ve smyslu § 27 správního řádu. Tím pádem nelze ani hovořit o nezákonném zásahu odepřením nahlížení do spisu z titulu účastenství dle § 38 správního řádu. Žaloba na ochranu před nezákonným zásahem by byla soudem odmítnuta.',
#   'questions_type': 'legal_interpretation',
#   'file': '4245_2021.txt'},
#  {'question': 'Pokud provozovatel nepovolených herních zařízení argumentuje, že jeho náklady (např. mzdy zaměstnanců, daně) by měly být odečteny od vypočteného "výnosu" z nepovolené činnosti, aby se zjistila skutečná ekonomická výhoda, obstojí tato argumentace u Nejvyššího správního soudu?',
#   'golden_answer': 'Ne, tato argumentace s největší pravděpodobností neobstojí. Nejvyšší správní soud se obvykle přiklání k názoru, že "výnos" z nepovolené loterie se rovná rozdílu mezi přijatými vklady a vyplacenými výhrami, a nelze jej zaměňovat se "ziskem" z podnikání. Náklady, včetně mezd a daní, se do výpočtu nezahrnují, protože by to popřelo samotný koncept neoprávněné ekonomické výhody.',
#   'questions_type': 'legal_interpretation',
#   'file': '4252_2021.txt'},
#  {'question': 'Pokud zákazník objedná zboží přes e-shop během státního svátku, ale osobně si ho vyzvedne a zaplatí v kamenné prodejně s prodejní plochou nad 200 m² také během tohoto svátku, porušuje provozovatel prodejny zákaz prodeje dle zákona o prodejní době?',
#   'golden_answer': 'Ne, pokud k uzavření kupní smlouvy došlo online, samotné vydání zboží a platba v prodejně během svátku nepředstavuje porušení zákazu prodeje. Rozhodující je, že smlouva byla uzavřena mimo kamennou prodejnu, a výdej zboží je pouze realizací již existující smlouvy.',
#   'questions_type': 'legal_interpretation',
#   'file': '4237_2021.txt'},
#  {'question': 'Klient, obchodník s elektronikou, byl obviněn z vědomé účasti na daňovém podvodu, ačkoliv správce daně neprokázal, u kterého konkrétního článku obchodního řetězce došlo k neodvedení DPH. Stačí k prokázání vědomé účasti na podvodu pouhá existence nepřímých indicií, které naznačují, že klient o podvodu musel vědět, i když nevěděl o detailech podvodného mechanismu?',
#   'golden_answer': 'Ano, dle ustálené judikatury Nejvyššího správního soudu postačí k prokázání vědomé účasti na podvodu na DPH, zjistí-li správce daně řadu nepřímých indicií, které ve svém souhrnu prokazují, že se daňový subjekt podvodu na DPH účastnil a že o tom musel vědět. Správce daně nemusí prokázat, že daňový subjekt věděl o tom, u kterého článku řetězce byla identifikována chybějící daň a v jakých detailech podvodný mechanismus spočíval.',
#   'questions_type': 'legal_interpretation',
#   'file': '4491_2023.txt'},
#  {'question': 'Klientovi bylo doručeno sdělení Ministerstva vnitra o nesplnění podmínek pro změnu zaměstnavatele dle § 42g odst. 9 zákona o pobytu cizinců, ale sdělení neobsahovalo poučení o možnosti podat žalobu. Jaká je lhůta pro podání žaloby v takovém případě a má klient nárok na náhradu nákladů řízení, pokud Ministerstvo vnitra následně sdělení zruší?',
#   'golden_answer': 'Vzhledem k absenci poučení o opravném prostředku se třicetidenní lhůta pro podání žaloby prodlužuje na tři měsíce. Pokud Ministerstvo vnitra sdělení zruší z důvodu, že žaloba byla podána důvodně, má klient nárok na náhradu nákladů řízení dle § 60 odst. 3 s. ř. s., protože ke zrušení došlo v důsledku pozdějšího chování Ministerstva vnitra.',
#   'questions_type': 'legal_interpretation',
#   'file': '4495_2023.txt'},
#  {'question': 'Pokud zdravotnická dokumentace žadatelky o odškodnění za protiprávní sterilizaci chybí a žadatelka předloží svědectví a jiné indicie, které podporují její tvrzení, ale neposkytují nezvratný důkaz, jaký standard důkazu musí správní orgán požadovat, aby žádost zamítl?',
#   'golden_answer': 'I když zdravotnická dokumentace chybí, správní orgán musí posoudit, zda žadatelka předestřela alespoň na první pohled hájitelné tvrzení o protiprávní sterilizaci. Pokud indicie ve svém souhrnu nepřipouštějí jiné racionální vysvětlení, než že k protiprávní sterilizaci pravděpodobně došlo, musí správní orgány považovat předpoklady pro přiznání odškodnění za naplněné, ledaže samy prokáží, že ke skutečnostem žadatelkou tvrzeným dojít nemohlo. Jinak řečeno, správní orgán nemůže žádost zamítnout jen proto, že žadatelka neposkytla nezvratný důkaz, pokud její tvrzení podporují jiné indicie.',
#   'questions_type': 'legal_interpretation',
#   'file': '4623_2024.txt'},
#  {'question': 'Pokud jeden ze spoluvlastníků pozemku dlouhodobě toleroval užívání cesty veřejností, ale později s tím začal nesouhlasit, a mezitím došlo ke změně vlastníků, je pro určení, zda se jedná o veřejně přístupnou účelovou komunikaci, rozhodující i stanovisko nových spoluvlastníků, kteří s veřejným užíváním souhlasí?',
#   'golden_answer': 'Ne, pro vznik veřejně přístupné účelové komunikace je nutný souhlas všech spoluvlastníků. I aktivní nesouhlas jednoho ze spoluvlastníků, bez ohledu na výši jeho podílu, vylučuje konkludentní souhlas s veřejným užíváním. Stanovisko nových spoluvlastníků, kteří s užíváním souhlasí, samo o sobě nestačí, pokud dříve některý ze spoluvlastníků nesouhlasil.',
#   'questions_type': 'legal_interpretation',
#   'file': '4425_2023.txt'},
#  {'question': 'Kliente dovezl léčiva ze třetí země v režimu tranzitu a následně je prodal české firmě, která je uvedla na trh. Dopustil se klient přestupku podle zákona o léčivech, i když sám léčiva na trh neuvedl?',
#   'golden_answer': 'Podle judikatury Nejvyššího správního soudu, pokud klient léčiva pouze pořídil ze třetí země v režimu tranzitu a sám je na trh neuvedl, ale prodal je subjektu, který je následně uvedl na trh, nedopustil se klient přestupku spočívajícího v dovozu léčiv bez povolení. Rozhodující je, kdo léčiva fakticky uvedl do volného oběhu.',
#   'questions_type': 'legal_interpretation',
#   'file': '4494_2023.txt'},
#  {'question': 'Pokud Ministerstvo spravedlnosti zruší insolvenčnímu správci povolení z důvodu opakovaných pochybení, ale některá z těchto pochybení se stala před delší dobou, může se správce úspěšně bránit s argumentem, že ministerstvo jednalo příliš pozdě, i když zákon o insolvenčních správcích nestanoví konkrétní promlčecí lhůtu?',
#   'golden_answer': 'I když zákon o insolvenčních správcích nestanoví pro zrušení povolení konkrétní promlčecí lhůtu, ministerstvo je limitováno obecnými zásadami správního řízení, zejména zásadou minimalizace zásahů a zásadou rychlosti. Soud bude zkoumat, zda zrušení povolení po delší době od pochybení je proporcionální a zda neohrožuje právní jistotu správce. Důležitá je závažnost a četnost pochybení v nedávné době před rozhodnutím o zrušení povolení.',
#   'questions_type': 'legal_interpretation',
#   'file': '4366_2022.txt'},
#  {'question': 'Pokud prezident republiky udělí milost osobě odsouzené za korupci, a já, jako občan, se cítím být tímto rozhodnutím dotčen na svých právech z důvodu narušení principu rovnosti a důvěry ve spravedlnost, mohu se proti tomuto rozhodnutí prezidenta republiky úspěšně bránit žalobou ve správním soudnictví?',
#   'golden_answer': 'Ne, rozhodnutí prezidenta republiky o udělení milosti nepodléhá přezkumu ve správním soudnictví. Nejvyšší správní soud se již dříve vyjádřil, že prezident v takovém případě nevystupuje jako správní orgán, ale jako orgán ústavní, a jeho rozhodnutí je ústavním aktem, který správní soudy nemají pravomoc přezkoumávat. Občan se nemůže úspěšně bránit žalobou, neboť nemá subjektivní veřejné právo na potrestání pachatele.',
#   'questions_type': 'legal_interpretation',
#   'file': '4406_2022.txt'},
#  {'question': 'Pokud byl příslušník bezpečnostního sboru vyslán na denní studium civilní vysoké školy během výkonu funkce zařazené do I. kategorie a po ukončení studia se vrátil zpět k výkonu funkce v I. kategorii, započítává se doba studia do doby výkonu funkce v I. kategorii pro účely snížení věkové hranice pro nárok na starobní důchod, i když toto studium není výslovně uvedeno v rezortním seznamu jako výkon práce I. nebo II. kategorie?',
#   'golden_answer': 'Ano, doba studia na civilní vysoké škole, která byla obklopena výkonem funkce zařazené do I. kategorie, se posuzuje jako výkon funkce v této kategorii pro účely snížení věkové hranice pro vznik nároku na starobní důchod dle § 174 odst. 1 písm. c) zákona č. 100/1988 Sb., a to i v případě, že studium není výslovně uvedeno v rezortním seznamu. Rozhodující je, že studium probíhalo v době zařazení do I. kategorie a po jeho ukončení se příslušník vrátil k výkonu funkce v této kategorii.',
#   'questions_type': 'legal_interpretation',
#   'file': '4353_2022.txt'},
#  {'question': 'Klientovi byla udělena neuspokojivá známka z chování na vysvědčení. Podali jsme žádost o přezkum řediteli školy, který hodnocení potvrdil. Můžeme se proti tomuto potvrzení bránit žalobou u správního soudu, a pokud ano, s jakou šancí na úspěch?',
#   'golden_answer': 'Podle ustálené judikatury Nejvyššího správního soudu, např. usnesení Krajského soudu v Brně čj. 62 A 79/2023-36, hodnocení chování žáka a přezkum jeho výsledků dle § 69 odst. 10 školského zákona nezasahují do práv žáka a jsou ze soudního přezkumu vyloučeny. Žaloba by byla nepřípustná.',
#   'questions_type': 'legal_interpretation',
#   'file': '4568_2024.txt'},
#  {'question': 'Pokud Rada města odvolá členy kontrolního výboru z důvodu nespokojenosti s kvalitou jejich práce, i když tito členové neporušili žádné konkrétní zákonné povinnosti, je takové odvolání v souladu s českým právem a judikaturou?',
#   'golden_answer': 'Ne, odvolání členů kontrolního výboru Radou města pouze z důvodu nespokojenosti s kvalitou jejich práce, bez naplnění zákonných důvodů pro odvolání, by pravděpodobně bylo shledáno nezákonným. Judikatura Nejvyššího správního soudu zdůrazňuje, že odvolání z funkce ve veřejné správě musí být založeno na konkrétních zákonných důvodech, nikoli na subjektivním hodnocení kvality práce.',
#   'questions_type': 'legal_interpretation',
#   'file': '4415_2023.txt'},
#  {'question': 'Klient byl v zemi původu opakovaně předvoláván na policii a krátkodobě zadržován kvůli účasti na nepovolených demonstracích a šíření letáků kritizujících vládu, ačkoli nebyl nikdy formálně obviněn. Může toto jednání, i bez fyzického násilí, představovat pronásledování ve smyslu zákona o azylu a zakládat nárok na mezinárodní ochranu v České republice?',
#   'golden_answer': 'Ano, opakované předvolávání a krátkodobé zadržování z politických důvodů, i bez fyzického násilí, může dosahovat intenzity pronásledování ve smyslu zákona o azylu, pokud je toto jednání prováděno, podporováno nebo trpěno původci pronásledování a představuje závažné porušení lidských práv nebo opatření působící psychický nátlak. Soud bude posuzovat intenzitu a kumulativní dopad těchto opatření, a také zda existuje odůvodněný strach z pronásledování v případě návratu do země původu.',
#   'questions_type': 'legal_interpretation',
#   'file': '4399_2022.txt'},
#  {'question': 'Klientovi hrozí vycestování z ČR, což by znamenalo vážné narušení jeho rodinného života, ale újma v zemi původu by nedosahovala intenzity mučení nebo nelidského zacházení. Může mu být udělena doplňková ochrana dle § 14a odst. 2 písm. d) zákona o azylu, pokud by vycestování porušovalo jeho právo na rodinný život dle čl. 8 Úmluvy?',
#   'golden_answer': 'Ano, doplňková ochrana může být udělena, pokud by vycestování klienta znamenalo porušení mezinárodních závazků ČR a hrozila by mu v zemi původu vážná újma, která sice nedosahuje intenzity újmy dle § 14a odst. 2 písm. a) až c) zákona o azylu, ale přesto představuje závažný zásah do jeho práva na rodinný život ve smyslu čl. 8 Úmluvy. Soud bude posuzovat konkrétní okolnosti případu a proporcionalitu zásahu.',
#   'questions_type': 'legal_interpretation',
#   'file': '4589_2024.txt'},
#  {'question': 'Klient nahlásil na policii, že ho soused opakovaně slovně napadal a vyhrožoval mu. Policie případ odložila pro nedostatek důkazů. Může být klient stíhán za přestupek proti občanskému soužití spočívající v nepravdivém obvinění, pokud nebylo prokázáno, že si byl vědom nepravdivosti svého obvinění?',
#   'golden_answer': 'Ne, pro uznání viny za přestupek nepravdivého obvinění je nutné prokázat, že si obviněný byl vědom nepravdivosti svého tvrzení. Pouhé odložení případu pro nedostatek důkazů nestačí k prokázání viny za křivé obvinění. Soud by se měl zabývat i věrohodností svědků a důkazů.',
#   'questions_type': 'legal_interpretation',
#   'file': '4391_2022.txt'},
#  {'question': 'Pokud kandidát do Poslanecké sněmovny vede osobní kampaň propagující jeho profesní úspěchy a zkušenosti prostřednictvím billboardů během volební kampaně, ale tato kampaň není explicitně spojena s jeho politickou stranou, podléhá tato kampaň povinnosti uvádět zadavatele a zpracovatele podle § 16 odst. 6 volebního zákona?',
#   'golden_answer': 'Ano, pokud je v období volební kampaně propagován kandidát způsobem, který je obvykle poskytován za úplatu, a jsou vychvalovány jeho osobní vlastnosti a zkušenosti, jedná se zpravidla o volební kampaň ve smyslu § 16 odst. 1 volebního zákona, i když není výslovně spojena s politickou stranou. Tudíž se na ni vztahuje povinnost uvést informace o zadavateli a zpracovateli podle § 16 odst. 6 volebního zákona. Výjimkou by byly pouze případy, kdy je zcela evidentní, že se nejedná o cílenou propagaci tohoto kandidáta.',
#   'questions_type': 'legal_interpretation',
#   'file': '4572_2024.txt'},
#  {'question': 'Může se občan, který není státním zástupcem, domáhat soudní ochrany proti jmenování nejvyššího státního zástupce, pokud tvrdí, že proces jmenování byl diskriminační a znemožnil mu ucházet se o tuto funkci?',
#   'golden_answer': 'Ne, osoba, která v době jmenování nevykonává funkci státního zástupce, nemá aktivní procesní legitimaci k napadení jmenování nejvyššího státního zástupce. Nejvyšší správní soud pravděpodobně odmítne žalobu pro nedostatek aktivní legitimace, neboť pouze státní zástupce splňuje kvalifikační předpoklady pro výkon této funkce.',
#   'questions_type': 'legal_interpretation',
#   'file': '4428_2023.txt'},
#  {'question': 'Pokud vlastním budovu sousedící s nemovitou kulturní památkou, která sama není památkově chráněná, ale stavební úřad posuzuje rekonstrukci mé budovy, je orgán státní památkové péče povinen se v závazném stanovisku vyjádřit k tomu, zda stavební zásahy do mé budovy mohou snížit hodnotu samotné kulturní památky, a pokud ano, jaké podmínky musí být splněny?',
#   'golden_answer': 'Ano, orgán státní památkové péče je povinen posoudit přípustnost stavebních zásahů do sousední budovy z hlediska ochrany dané nemovité kulturní památky, zvláště pokud existuje úzká vazba mezi oběma stavbami. Pokud by zásahy mohly vést ke snížení hodnoty památky, musí stanovit podmínky pro provedení stavby.',
#   'questions_type': 'legal_interpretation',
#   'file': '4594_2024.txt'},
#  {'question': 'Pokud společnost uplatňuje odpočet na výzkum a vývoj, a finanční úřad zpochybňuje specifikaci cílů projektu a neuvedení všech odborných pracovníků v projektové dokumentaci, jak konkrétní a detailní musí být cíle projektu popsány a je nutné uvést všechny zaměstnance, kteří se na projektu podílejí, nebo pouze odborné garanty?',
#   'golden_answer': 'Cíle projektu výzkumu a vývoje musí být formulovány dostatečně jasně, aby bylo zřejmé, v čem daňový subjekt spatřuje prvek novosti, resp. prvek odstranění technické nejistoty, v čem se řešení liší od současného stavu a jaký bude jeho přínos. Projekt musí obsahovat jména všech osob, které odborně zajišťují řešení projektu, nikoli pouze odborné garanty. Neuvedení všech odborných pracovníků může vést k neuznání odpočtu.',
#   'questions_type': 'legal_interpretation',
#   'file': '4656_2025.txt'},
#  {'question': 'Klient mi bezúplatně převedl na základě jedné darovací smlouvy v jeden den několik různých balíků podílových listů, přičemž hodnota každého jednotlivého balíku nepřesáhla 5.000.000 Kč, ale celková hodnota všech balíků ano. Vzniká mi povinnost tento příjem oznámit správci daně dle § 38v zákona o daních z příjmů?',
#   'golden_answer': 'Ano, pokud bezúplatný převod několika podílových listů proběhl na základě jednoho právního titulu, v jeden den, mezi stejnými osobami a se stejným záměrem, a celková hodnota přesáhla 5.000.000 Kč, vzniká povinnost příjem oznámit správci daně, i když hodnota žádného z dílčích balíků tuto hranici nepřekročila. Důležitý je celkový nárůst majetku.',
#   'questions_type': 'legal_interpretation',
#   'file': '4538_2023.txt'},
#  {'question': 'Pokud je proti žadateli o povolení k přechodnému pobytu vedeno trestní stíhání, může imigrační úřad zamítnout jeho žádost s odkazem na ohrožení veřejného pořádku, i když dosud nebyl pravomocně odsouzen?',
#   'golden_answer': 'Ne, samotné trestní stíhání, s ohledem na presumpci neviny, nemůže být důvodem pro zamítnutí žádosti o povolení k přechodnému pobytu z důvodu ohrožení veřejného pořádku. Správní orgán však může přihlédnout k prokázanému jednání, pro které je trestní stíhání vedeno, pokud z něj lze dovodit hrozbu narušení veřejného pořádku, nikoli k samotné trestnosti tohoto jednání.',
#   'questions_type': 'legal_interpretation',
#   'file': '4636_2024.txt'},
#  {'question': 'Klient vyrábí nealkoholické nápoje a chce si zaregistrovat ochrannou známku podobnou starší ochranné známce pro pivo. Může Úřad průmyslového vlastnictví zamítnout registraci s odkazem na pravděpodobnost záměny, i když se jedná o nealkoholické nápoje a pivo?',
#   'golden_answer': 'Ano, Úřad průmyslového vlastnictví může zamítnout registraci ochranné známky pro nealkoholické nápoje, pokud je podobná starší ochranné známce pro pivo a existuje pravděpodobnost záměny na straně veřejnosti. Soudy v České republice se přiklánějí k názoru, že pivo, včetně nealkoholického, a nealkoholické nápoje jsou si podobné výrobky, a proto hrozí, že spotřebitelé by se mohli domnívat, že pocházejí od stejného výrobce.',
#   'questions_type': 'legal_interpretation',
#   'file': '4650_2024.txt'},
#  {'question': 'Pokud správní orgán prvního stupně vydá rozhodnutí o vině v přestupkovém řízení, které je následně odvolacím orgánem zrušeno pro závažné procesní vady, přerušuje toto zrušené rozhodnutí běh promlčecí doby?',
#   'golden_answer': 'Ano, i rozhodnutí o vině zrušené pro nezákonnost přerušuje běh promlčecí doby, pokud nebylo nicotné nebo ryze formální, učiněné jen ve snaze zabránit promlčení bez skutečné ambice vést řízení. Rozhodující je, zda se jednalo o skutečný projev vůle státu potrestat přestupek.',
#   'questions_type': 'legal_interpretation',
#   'file': '4488_2023.txt'},
#  {'question': 'Klientovi bylo doručeno rozhodnutí Ministerstva vnitra o jeho předání do Rumunska podle Dublinského nařízení, protože tam poprvé požádal o azyl. Ministerstvo se odvolává na § 11 odst. 2 zákona o azylu. Je k žalobě proti tomuto rozhodnutí místně příslušný soud v obvodu trvalého bydliště klienta, nebo soud v sídle Ministerstva vnitra?',
#   'golden_answer': 'Nejvyšší správní soud by pravděpodobně rozhodl, že místně příslušný je krajský soud v obvodu, kde má klient hlášený pobyt, dle § 32 odst. 3 zákona o azylu. Rozhodnutí o předání podle Dublinského nařízení je považováno za rozhodnutí ve věci mezinárodní ochrany, i když klient žádost o azyl v ČR formálně nepodal. Judikatura NSS v obdobných případech preferuje aplikaci § 32 odst. 3 zákona o azylu.',
#   'questions_type': 'legal_interpretation',
#   'file': '4275_2022.txt'},
#  {'question': 'Pokud krajský soud zamítne žalobu podanou žalobcem, má osoba zúčastněná na řízení právo podat kasační stížnost proti tomuto zamítnutí, i když se domáhá pouze zrušení procesního rozhodnutí soudu a nikoliv meritorního posouzení věci?',
#   'golden_answer': 'Ne, osoba zúčastněná na řízení nemá aktivní procesní legitimaci k podání kasační stížnosti proti rozhodnutí krajského soudu, kterým se zamítá žaloba nebo zastavuje řízení. Kasační stížnost podaná osobou zúčastněnou na řízení v takovém případě bude odmítnuta jako podání učiněné osobou k tomu zjevně neoprávněnou.',
#   'questions_type': 'legal_interpretation',
#   'file': '4484_2023.txt'},
#  {'question': 'Klient se domáhá zaevidování nadměrného odpočtu DPH a úroku na daňový účet, ale správce daně nekoná. Musí klient před podáním zásahové žaloby podat podnět podle § 38 daňového řádu, i když tvrdí, že správce daně je nečinný, nikoliv že provádí nesprávné úkony?',
#   'golden_answer': 'Ano, dle ustálené judikatury Nejvyššího správního soudu, i když se klient domáhá ochrany před nečinností správce daně v oblasti placení daní, je podnět podle § 38 daňového řádu právním prostředkem ochrany nebo nápravy ve smyslu § 85 soudního řádu správního, který musí vyčerpat před podáním zásahové žaloby. Teprve po neúspěšném podnětu se může obrátit na soud.',
#   'questions_type': 'legal_interpretation',
#   'file': '4123_2021.txt'},
#  {'question': 'Pokud správce daně zpochybní veškeré nároky na odpočet DPH na vstupu u daňového subjektu provozujícího hotel, a daňový subjekt neprokáže oprávněnost těchto odpočtů, může správce daně stanovit DPH pouze na základě dokazování daně na výstupu, nebo je povinen přistoupit ke stanovení daně podle pomůcek, například s využitím doktríny esenciálních výdajů?',
#   'golden_answer': 'Ne, správce daně není povinen přistoupit ke stanovení daně podle pomůcek, pokud má k dispozici dostatečné podklady pro stanovení daně na výstupu dokazováním, například daňové přiznání. Doktrína esenciálních výdajů se v případě DPH neuplatní, neboť nárok na odpočet daně je vázán na splnění zákonných požadavků dle § 72 odst. 1 zákona o DPH.',
#   'questions_type': 'legal_interpretation',
#   'file': '4526_2023.txt'},
#  {'question': 'Pokud státní příspěvková organizace, zřízená ministerstvem, odmítne poskytnout informace dle zákona o svobodném přístupu k informacím, a nelze určit nadřízený orgán dle § 178 správního řádu, který úřad je příslušný rozhodnout o odvolání proti tomuto rozhodnutí?',
#   'golden_answer': 'V takovém případě, pokud nelze určit nadřízený orgán státní příspěvkové organizace podle § 178 správního řádu, je příslušný rozhodnout o odvolání Úřad pro ochranu osobních údajů, jak stanoví § 20 odst. 5 zákona o svobodném přístupu k informacím.',
#   'questions_type': 'legal_interpretation',
#   'file': '4230_2021.txt'},
#  {'question': 'Pokud obec zakoupí akcie společnosti provozující autobusovou dopravu za účelem zajištění dopravní obslužnosti, považuje se tato transakce za veřejnou zakázku na dodávky ve smyslu § 14 odst. 1 zákona o zadávání veřejných zakázek, a musí tedy být zadána v zadávacím řízení?',
#   'golden_answer': 'Dle judikatury Nejvyššího správního soudu, nákup akcií nebo závodu spadá pod definici veřejné zakázky na dodávky podle § 14 odst. 1 ZZVZ, jelikož akcie a závod jsou považovány za věci ve smyslu § 489 občanského zákoníku. Absence výjimky v ZZVZ pro nabytí akcií nebo závodu znamená, že se na takové transakce vztahují pravidla pro zadávání veřejných zakázek.',
#   'questions_type': 'legal_interpretation',
#   'file': '4102_2021.txt'},
#  {'question': 'Kliente se domáhá ochrany před nezákonným zásahem policie. Policie soudu předložila úřední záznamy, které nebyly součástí správního spisu a klient se s nimi neměl možnost seznámit před soudním řízením. Může soud při rozhodování vycházet z těchto záznamů, aniž by s nimi provedl důkaz při jednání?',
#   'golden_answer': 'Ne, soud by zásadně neměl vycházet z listin předložených správním orgánem v řízení o zásahové žalobě, které nebyly součástí správního spisu a s nimiž se žalobce neměl možnost seznámit před soudním řízením, aniž by s nimi provedl důkaz při jednání a umožnil žalobci na ně reagovat. Jinak by mohlo dojít k procesní vadě řízení, která by mohla mít za následek nezákonné rozhodnutí ve věci samé.',
#   'questions_type': 'legal_interpretation',
#   'file': '4563_2024.txt'},
#  {'question': 'Klientovi bylo správcem daně vydáno povolení k nabytí elektřiny osvobozené od daně pro metalurgické procesy. Nyní, po několika letech, správce daně tvrdí, že činnost klienta nesplňuje definici metalurgického procesu a doměřuje daň. Může se klient úspěšně bránit, pokud povolení dosud nebylo zrušeno?',
#   'golden_answer': 'Ano, klient se může úspěšně bránit. Pokud správce daně nezrušil platné povolení k nabytí elektřiny osvobozené od daně, nemůže dodatečně doměřit daň, i když se později domnívá, že původní posouzení bylo chybné. Rozhodnutí o povolení má konstitutivní charakter a zakládá právo na odběr elektřiny osvobozené od daně, dokud není zrušeno.',
#   'questions_type': 'legal_interpretation',
#   'file': '4343_2022.txt'},
#  {'question': 'Klient nabízí "kulturně-výměnné programy" zahrnující stáž v zahraničí za poplatek. Pokud stáž obnáší 35-40 hodin týdně práce za kapesné, může Státní úřad inspekce práce uložit pokutu za porušení § 58 odst. 2 zákona o zaměstnanosti, i když klient tvrdí, že poplatek je za jiné služby než zprostředkování zaměstnání?',
#   'golden_answer': 'Ano, pokud faktický obsah programu spočívá převážně ve zprostředkování zaměstnání, a to i skrytě pod rouškou kulturně-výměnného programu, může Státní úřad inspekce práce uložit pokutu. Rozhodující je posouzení, zda se jedná o závislou práci dle českého práva, a zda poplatek fakticky pokrývá i zprostředkování této práce. Nejvyšší správní soud vykládá pojem zprostředkování zaměstnání extenzivně.',
#   'questions_type': 'legal_interpretation',
#   'file': '4114_2021.txt'},
#  {'question': "Pokud odborová organizace žádá o informace o platech vedoucích pracovníků veřejné vysoké školy s odůvodněním, že má podezření na nehospodárné nakládání s prostředky, ale zaměstnavatel tvrdí, že organizace u něj fakticky nepůsobí a žádost je zneužitím práva, jak soud posoudí splnění podmínky role 'společenského hlídacího psa' pro poskytnutí informací dle platového nálezu Ústavního soudu?",
#   'golden_answer': "Soud bude posuzovat, zda odborová organizace reálně plní roli dozoru veřejnosti, nikoliv její formální status nebo oprávnění působit u daného zaměstnavatele. Rozhodující bude, zda organizace hodlá s informacemi vstoupit do veřejné diskuse a přispět tak ke kontrole hospodaření s veřejnými prostředky. I kdyby organizace u zaměstnavatele nepůsobila, může být považována za 'společenského hlídacího psa ad hoc', pokud se prokáže její aktivní snaha o zapojení do veřejné debaty o dané problematice. Zneužití práva musí být prokázáno, pouhé podezření na účelovost žádosti nestačí.",
#   'questions_type': 'legal_interpretation',
#   'file': '4416_2023.txt'},
#  {'question': 'Klientovi byly zajištěny peníze na účtu Policií ČR jako náhradní hodnota za výnos z trestné činnosti. Může finanční úřad i přesto vydat zajišťovací příkaz na stejnou částku z důvodu potenciálního nedoplatku DPH, nebo se jedná o nepřípustný souběh zajišťovacích institutů?',
#   'golden_answer': 'Zajištění peněz v trestním řízení nebrání vydání zajišťovacího příkazu dle daňového řádu, pokud jsou splněny ostatní podmínky pro jeho vydání. Správce daně nemůže s jistotou předvídat, jak budou prostředky zajištěné policií využity. Nicméně, nemělo by dojít k duplicitnímu zajištění a orgán činný v trestním řízení by měl posoudit, zda je jeho zajištění stále v daném rozsahu třeba.',
#   'questions_type': 'legal_interpretation',
#   'file': '4253_2021.txt'},
#  {'question': 'Pokud plátce DPH vystavil opravný daňový doklad a doručil jej dlužníkovi v insolvenčním řízení ve lhůtě tří let od konce zdaňovacího období původního plnění, ale daňové přiznání s touto opravou podal až po uplynutí této lhůty, má plátce nárok na opravu výše daně na výstupu?',
#   'golden_answer': 'Nejvyšší správní soud se pravděpodobně přikloní k názoru, že pro nárok na opravu výše daně na výstupu podle § 44 zákona o DPH (ve znění účinném do 31. 3. 2019) postačí, pokud plátce ve lhůtě tří let vystaví opravný daňový doklad, doručí jej dlužníkovi a provede záznamy v evidenci DPH. Podání daňového přiznání v této lhůtě není nutné.',
#   'questions_type': 'legal_interpretation',
#   'file': '4175_2021.txt'},
#  {'question': 'Je advokát povinen podat kontrolní hlášení podle zákona o DPH, i když by to mohlo vést k porušení jeho povinnosti mlčenlivosti vůči klientům dle zákona o advokacii?',
#   'golden_answer': 'Ano, advokát je povinen podat kontrolní hlášení, přestože to souvisí s jeho povinností mlčenlivosti. Zákon o advokacii v § 21 odst. 5 stanoví výjimku pro povinnosti daňového subjektu, přičemž advokát je povinen zachovávat mlčenlivost pouze o povaze věci, nikoliv o identifikačních údajích klienta a hodnotě plnění. Nejvyšší správní soud se v podobných případech přiklání k názoru, že povinnost podat kontrolní hlášení nepředstavuje porušení advokátní mlčenlivosti.',
#   'questions_type': 'legal_interpretation',
#   'file': '4274_2022.txt'},
#  {'question': 'Klient neoprávněně pobýval na území ČR a následně požádal o mezinárodní ochranu. Může správní orgán zahájit řízení o správním vyhoštění i po podání této žádosti, nebo je to v rozporu se zákonem o pobytu cizinců a zákonem o azylu?',
#   'golden_answer': 'Ano, správní orgán může zahájit řízení o správním vyhoštění i po podání žádosti o mezinárodní ochranu, pokud důvod pro vyhoštění (neoprávněný pobyt) nastal před podáním žádosti. Zákon o pobytu cizinců nevylučuje souběžné vedení obou řízení, přičemž vykonatelnost rozhodnutí o vyhoštění je odložena do doby rozhodnutí o žádosti o mezinárodní ochranu.',
#   'questions_type': 'legal_interpretation',
#   'file': '4551_2024.txt'},
#  {'question': 'Pokud zadavatel v otevřeném řízení stanovil zadávací podmínku, která omezuje hospodářskou soutěž, a kvůli tomu nebyla podána žádná nabídka, může následně zadat zakázku v jednacím řízení bez uveřejnění, i když by se prokázalo, že tato zadávací podmínka odradila pouze jednoho potenciálního uchazeče?',
#   'golden_answer': 'Ne, zadavatel nemůže použít jednací řízení bez uveřejnění, pokud nepodání nabídek v původním otevřeném řízení zapříčinil svým nezákonným postupem, například nezákonným nastavením zadávacích podmínek. Pro závěr o nemožnosti použití JŘBU postačuje rozumná míra pravděpodobnosti, že z důvodu nezákonného postupu zadavatele nabídku nepodal byť jen jediný dodavatel. Důvodem nepodání nabídky nemusí být výhradně nezákonný postup zadavatele, postačí, byl-li jednou z příčin rozhodnutí dodavatele nabídku nepodat.',
#   'questions_type': 'legal_interpretation',
#   'file': '4327_2022.txt'},
#  {'question': 'Pokud již existuje platná smlouva o dodávce tepla mezi držitelem licence a zákazníkem, ale zákazník se domáhá změny výše rezervovaného tepelného výkonu s odkazem na pozdější cenové rozhodnutí ERÚ, má Energetický regulační úřad pravomoc rozhodnout o takovém návrhu na změnu smlouvy, nebo spadá tato pravomoc do kompetence civilních soudů?',
#   'golden_answer': 'Ne, Energetický regulační úřad nemá pravomoc rozhodovat o změně již existující smlouvy o dodávce tepla. Pravomoc ERÚ se omezuje na spory o uzavření smlouvy, nikoli o její změnu. Spor o změnu smlouvy, zejména pokud se týká změny výše rezervovaného tepelného výkonu, spadá do pravomoci civilních soudů v souladu s občanským zákoníkem.',
#   'questions_type': 'legal_interpretation',
#   'file': '4363_2022.txt'},
#  {'question': 'Pokud zadavatel veřejné zakázky na stavební práce uzavřel dodatek ke smlouvě navyšující cenu díla o 14 % z důvodu prodlení způsobeného přezkumem ÚOHS, a tato změna nepřesahuje limity de minimis stanovené v § 222 odst. 4 ZZVZ, ale zadávací dokumentace omezovala možnosti navýšení ceny pouze na změny právních předpisů, může poskytovatel dotace odmítnout proplatit část dotace s odůvodněním, že se jedná o podstatnou změnu závazku?',
#   'golden_answer': 'Ne, pokud změna ceny nepřesahuje limity de minimis dle § 222 odst. 4 ZZVZ a nemění celkovou povahu veřejné zakázky, nemělo by se jednat o podstatnou změnu závazku, i když zadávací dokumentace původně omezovala možnosti navýšení ceny. Soud by měl zkoumat, zda byly dodrženy limity de minimis a zda změna neovlivnila hospodářskou soutěž natolik, aby to vyžadovalo nové zadávací řízení. Zadavatel nemůže smluvně vyloučit aplikaci § 222 odst. 4 ZZVZ.',
#   'questions_type': 'legal_interpretation',
#   'file': '4583_2024.txt'},
#  {'question': 'Pokud společnost poskytuje pouze službu převzatého televizního vysílání přes internet, ale nezajišťuje samotné internetové připojení, spadá spor o neuhrazení poplatků za tuto službu do pravomoci Českého telekomunikačního úřadu nebo obecného soudu?',
#   'golden_answer': 'Ne, pokud společnost poskytuje pouze službu obsahu (převzaté televizní vysílání) a nezajišťuje i přenos signálu sítí elektronických komunikací (internetové připojení), spor o zaplacení poplatků nespadá do pravomoci ČTÚ. Příslušný je obecný soud, neboť se nejedná o službu elektronických komunikací ve smyslu § 2 odst. 3 písm. a) zákona o elektronických komunikacích.',
#   'questions_type': 'legal_interpretation',
#   'file': '4372_2022.txt'},
#  {'question': 'Pokud bylo v přestupkovém řízení pravomocně rozhodnuto o vině a trestu, ale řízení o náhradě škody se protáhlo, a mezitím uplynula promlčecí doba pro přestupek, může správní orgán ještě rozhodnout o náhradě škody v adhezním řízení, nebo je povinen řízení zastavit?',
#   'golden_answer': 'I když bylo pravomocně rozhodnuto o vině, uplynutí promlčecí doby pro přestupek brání dalšímu vedení adhezního řízení o náhradě škody. Správní orgán je povinen řízení o náhradě škody zastavit, protože adhezní řízení je závislé na řízení o přestupku a nelze jej vést mimo časový rámec pro projednání přestupku.',
#   'questions_type': 'legal_interpretation',
#   'file': '4133_2021.txt'},
#  {'question': 'Klientovi byl udělen pobyt za účelem strpění, protože neměl cestovní doklad. Nyní cestovní doklad má, ale tvrdí, že jako palestinský uprchlík nemá možnost legálního dlouhodobého pobytu v žádné jiné zemi. Může být jeho žádost o prodloužení pobytu zamítnuta pouze na základě toho, že má cestovní doklad, nebo se musí správní orgán zabývat i tím, zda existuje země, kde by mohl legálně pobývat?',
#   'golden_answer': 'Správní orgán se nemůže omezit pouze na zjištění, že cizinec disponuje cestovním dokladem. Musí se zabývat i tím, zda trvá důvod pro strpění pobytu, tedy zda cizinci ve vycestování brání překážka na jeho vůli nezávislá. Pokud cizinec prokáže, že jako uprchlík nemá možnost legálního pobytu v jiné zemi, jde stále o překážku ve vycestování a žádost o prodloužení pobytu za účelem strpění by neměla být zamítnuta pouze na základě držení cestovního dokladu.',
#   'questions_type': 'legal_interpretation',
#   'file': '4388_2022.txt'},
#  {'question': 'Klient, poskytovatel poštovních služeb bez poštovní licence, se s Českou poštou nedohodl na smlouvě o přístupu k poštovní infrastruktuře. Český telekomunikační úřad rozhodl o obsahu smlouvy. Může klient podat žalobu proti rozhodnutí ČTÚ k civilnímu soudu, nebo je příslušný správní soud?',
#   'golden_answer': 'Podle ustálené judikatury Nejvyššího správního soudu, právní vztah ze smlouvy o přístupu k poštovní infrastruktuře je vztahem soukromého práva. I když o obsahu smlouvy rozhodl ČTÚ, žaloba směřuje k úpravě soukromoprávního vztahu, a proto je příslušný civilní soud, nikoliv správní soud.',
#   'questions_type': 'legal_interpretation',
#   'file': '4429_2023.txt'},
#  {'question': 'Pokud ministerstvo spravedlnosti zjistí drobné pochybení soudního exekutora, existuje nějaká lhůta, do kdy musí exekutorovi písemně vytknout toto pochybení dle § 7a exekučního řádu, a pokud ano, jaká je tato lhůta?',
#   'golden_answer': 'Ačkoliv exekuční řád nestanoví konkrétní lhůtu pro uložení výtky, ministerstvo je limitováno základními zásadami činnosti správních orgánů, zejména zásadou rychlosti a hospodárnosti. Výtka musí být uložena v přiměřené době od zjištění pochybení, přičemž se zohledňují konkrétní okolnosti případu. Příliš dlouhá nečinnost ministerstva může vést ke zrušení výtky soudem.',
#   'questions_type': 'legal_interpretation',
#   'file': '4217_2021.txt'},
#  {'question': 'Může Ministerstvo školství zamítnout zápis soukromé základní školy do rejstříku škol a školských zařízení pouze z důvodu, že stávající státní školy v dané lokalitě mají dostatečnou kapacitu, aniž by zohlednilo alternativní vzdělávací koncepci, zájem rodičů a podporu místní samosprávy?',
#   'golden_answer': 'Ne, Ministerstvo školství nemůže zamítnout zápis soukromé školy pouze z kapacitních důvodů. Podle judikatury Nejvyššího správního soudu a Ústavního soudu je nutné zohlednit i kvalitativní aspekty, jako je alternativní vzdělávací koncepce, zájem rodičů a podpora samosprávy. Dlouhodobé záměry vzdělávání nesmí plošně znemožňovat vznik nestátních škol a je třeba je vykládat ústavně konformně, s ohledem na právo rodičů na alternativu ve vzdělávání.',
#   'questions_type': 'legal_interpretation',
#   'file': '4440_2023.txt'},
#  {'question': 'Pokud jsou sourozenci umístěni do zařízení pro děti vyžadující okamžitou pomoc, a ředitel zařízení rozhodne o jejich odděleném ubytování v různých částech zařízení z důvodu údajné nadměrné péče staršího sourozence o mladšího, může se starší sourozenec úspěšně domáhat ochrany před nezákonným zásahem, pokud s oddělením nesouhlasí a tvrdí, že péče o mladšího sourozence je pro ni přirozená a ne představuje nadměrnou zátěž?',
#   'golden_answer': 'Ano, starší sourozenec se může úspěšně domáhat ochrany před nezákonným zásahem. Soud by měl zohlednit názor staršího sourozence, zjistit, zda péče o mladšího sourozence skutečně představuje nadměrnou zátěž, a posoudit, zda oddělení sourozenců je v souladu s jejich nejlepším zájmem a zda neexistují mírnější opatření. Oddělení sourozenců by mělo být považováno za krajní řešení a mělo by být odůvodněno závažnými okolnostmi ve vývoji a vztazích sourozenců, které brání společnému umístění.',
#   'questions_type': 'legal_interpretation',
#   'file': '4634_2024.txt'},
#  {'question': 'Klient, společnost s ručením omezeným, uzavřela dohodu o smluvní pokutě s propojenou osobou. Následně si tuto pokutu, kterou zaplatila propojené osobě, uplatnila jako daňově uznatelný náklad. Může finanční úřad takové uplatnění nákladu zpochybnit s odkazem na zneužití práva, i když formálně byly splněny všechny podmínky pro daňovou uznatelnost?',
#   'golden_answer': 'Ano, finanční úřad může zpochybnit uplatnění nákladu s odkazem na zneužití práva, pokud prokáže, že i přes formální splnění podmínek zákona nebyl naplněn jeho účel a smysl a zároveň, že hlavním nebo převažujícím účelem jednání klienta bylo získání daňové výhody. Propojenost osob je relevantní okolnost, ale není definiční podmínkou zneužití práva. Důležité je ekonomické opodstatnění transakce a zda klient uměle vytvořil podmínky pro uplatnění daňové výhody.',
#   'questions_type': 'legal_interpretation',
#   'file': '4358_2022.txt'},
#  {'question': 'Pokud neúspěšný uchazeč ve výběrovém řízení na exekutorský úřad podá žalobu proti rozhodnutí ministra spravedlnosti o jmenování úspěšného uchazeče, je soud povinen se zabývat námitkami týkajícími se průběhu výběrového řízení, nebo je jeho přezkum omezen pouze na splnění zákonných požadavků jmenovaného exekutora dle § 9 a § 12 exekučního řádu?',
#   'golden_answer': 'Soud se zabývá pouze tím, zda ministr spravedlnosti postupoval v souladu se zákonem při jmenování exekutora. Ministr je vázán návrhem Exekutorské komory a pokud navržený kandidát splňuje požadavky § 9 a § 12 exekučního řádu, je povinen jej jmenovat. Soud tedy nepřezkoumává průběh výběrového řízení vedeného Exekutorskou komorou, jelikož neúspěšný uchazeč není účastníkem řízení o jmenování.',
#   'questions_type': 'legal_interpretation',
#   'file': '4472_2023.txt'},
#  {'question': 'Klient byl pokutován za správní delikt. Po právní moci rozhodnutí vstoupila v platnost nová právní úprava, která zpřísňuje definici skutkové podstaty deliktu. Může soud v řízení o žalobě proti rozhodnutí správního orgánu posoudit, zda původní jednání klienta naplňuje i novou, zpřísněnou skutkovou podstatu, a to i když správní orgán tuto okolnost nezkoumal?',
#   'golden_answer': 'Ano, soud v řízení o žalobě musí posoudit, zda je nová právní úprava pro klienta příznivější. Pokud je nová úprava účinná až po právní moci rozhodnutí správního orgánu, soud posoudí, zda jednání klienta naplňuje i novou skutkovou podstatu, i když správní orgán tuto okolnost nezkoumal. Soud tak rozhoduje v plné jurisdikci a musí zohlednit aktuální právní stav.',
#   'questions_type': 'legal_interpretation',
#   'file': '4162_2021.txt'},
#  {'question': 'Pokud krajský soud v řízení o mezinárodní ochraně ustanoví žadatelovi zástupce usnesením asistenta soudce, je toto usnesení vydáno v souladu se zákonem, neboť § 35 odst. 10 s. ř. s. svěřuje tuto pravomoc předsedovi senátu?',
#   'golden_answer': 'Podle judikatury Nejvyššího správního soudu, konkrétně usnesení rozšířeného senátu, je asistent soudce oprávněn rozhodnout o návrhu na ustanovení zástupce dle § 35 odst. 10 s. ř. s. Rozhodnutí asistenta soudce je v souladu se zákonem, protože smyslem je odbřemenění soudců a existuje možnost přezkumu rozhodnutí soudcem, například prostřednictvím námitek dle § 9 zákona o VSÚ.',
#   'questions_type': 'legal_interpretation',
#   'file': '4107_2021.txt'},
#  {'question': 'Klient byl podmíněně propuštěn z výkonu trestu odnětí svobody za majetkovou trestnou činnost. Nyní žádá o povolení k přechodnému pobytu jako rodinný příslušník občana EU. Může správní orgán zamítnout jeho žádost pouze s odkazem na jeho předchozí odsouzení a probíhající zkušební dobu, nebo musí zohlednit i jiné faktory, jako je jeho chování po propuštění a délka doby, která uplynula od spáchání trestného činu?',
#   'golden_answer': 'Správní orgán nemůže zamítnout žádost o přechodný pobyt pouze na základě předchozího odsouzení a probíhající zkušební doby. Musí individuálně posoudit, zda klient představuje aktuální a dostatečně závažné ohrožení veřejného pořádku, zohlednit jeho chování po propuštění, délku doby od spáchání trestného činu, jeho osobní vývoj a další relevantní okolnosti. Pouhé trvání zkušební doby samo o sobě nestačí k zamítnutí žádosti.',
#   'questions_type': 'legal_interpretation',
#   'file': '4523_2023.txt'},
#  {'question': 'Pokud obec již jednou rozhodla v místním referendu o vlastníkovi kanalizace, a v kampani bylo zdůrazňováno spojení tohoto vlastníka s určitým typem kanalizace (např. tlakovou), může se konat nové referendum o typu kanalizace (např. gravitační), pokud od prvního referenda neuplynulo 24 měsíců?',
#   'golden_answer': 'Ne, pokud z kontextu prvního referenda a kampaně je zřejmé, že volba vlastníka kanalizace byla fakticky i volbou typu kanalizace, nové referendum o typu kanalizace by bylo v rozporu s § 7 písm. h) zákona o místním referendu, neboť by se jednalo o referendum ve stejné věci před uplynutím 24 měsíců. Soudy by posuzovaly smysl otázky a odpovědi v předchozím referendu pohledem běžného občana a v kontextu kampaně.',
#   'questions_type': 'legal_interpretation',
#   'file': '4348_2022.txt'},
#  {'question': 'Pokud poskytovatel dotace dle § 14e odst. 1 zákona o rozpočtových pravidlech nevydá rozhodnutí, ale pouze opatření o nevyplacení dotace, a toto opatření neobsahuje všechny náležitosti správního rozhodnutí dle správního řádu, lze se proti tomuto opatření bránit žalobou u správního soudu a tvrdit jeho nicotnost z důvodu absence těchto náležitostí?',
#   'golden_answer': 'Ne, samotné opatření poskytovatele dotace o nevyplacení dotace dle § 14e odst. 1 rozpočtových pravidel se nepovažuje za rozhodnutí ve smyslu správního řádu. Až rozhodnutí o námitkách proti tomuto opatření dle § 14e odst. 3 rozpočtových pravidel má povahu rozhodnutí, které podléhá přezkumu správního soudu. Nicotnost opatření z důvodu absence náležitostí správního rozhodnutí tedy nelze úspěšně namítat.',
#   'questions_type': 'legal_interpretation',
#   'file': '4557_2024.txt'},
#  {'question': 'Pokud finanční úřad v rámci mezinárodního dožádání prověřuje konkrétní zdanitelná plnění mezi naší společností a jejím obchodním partnerem v zahraničí, a to před formálním zahájením daňové kontroly, lze to považovat za materiální zahájení daňové kontroly s dopadem na běh prekluzivní lhůty pro stanovení daně?',
#   'golden_answer': 'Ano, pokud z obsahu mezinárodního dožádání plyne, že finanční úřad prověřoval konkrétní zdanitelná plnění, o kterých panovaly pochybnosti, a nešlo pouze o „mapování terénu“, může to být posouzeno jako materiální zahájení daňové kontroly. V takovém případě se bude zkoumat, zda toto materiální zahájení daňové kontroly nenastalo před formálním zahájením a zda to nemělo vliv na uplynutí prekluzivní lhůty.',
#   'questions_type': 'legal_interpretation',
#   'file': '4520_2023.txt'},
# ...
#   'golden_answer': 'Ne, dle judikatury Nejvyššího správního soudu, mimořádné opatření omezující provoz lyžařských vleků a lanových drah musí být řádně odůvodněno, včetně zohlednění konkrétní míry rizika a posouzení, zda neexistují mírnější, ale stejně účinné prostředky k dosažení cíle, jako jsou například hygienická opatření. Pokud odůvodnění chybí nebo je nedostatečné, je opatření nepřezkoumatelné a tedy nezákonné.',
#   'questions_type': 'legal_interpretation',
#   'file': '4216_2021.txt'},
#  {'question': 'Pokud územní plán vymezuje koridor pro veřejně prospěšnou stavbu, ale umístění stavby v územním řízení vybočuje z tohoto koridoru na soukromý pozemek, je pro umístění stavby nezbytný souhlas vlastníka pozemku, i když se jedná o stavbu dopravní infrastruktury a teoreticky by mohlo dojít k vyvlastnění?',
#   'golden_answer': 'Ano, pokud umístění stavby vybočuje z koridoru vymezeného územním plánem, je souhlas vlastníka pozemku nezbytný, pokud se nejedná o plochy nezbytné k zajištění výstavby nebo řádného užívání stavby a správní orgán tuto nezbytnost řádně odůvodnil. Jinak je souhlas vlastníka dle § 184a odst. 1, 3 stavebního zákona nutný.',
#   'questions_type': 'legal_interpretation',
#   'file': '4598_2024.txt'},
#  {'question': 'Klient, vedlejší účastník územního řízení s velkým počtem účastníků, podal odvolání proti územnímu rozhodnutí. Může mu být rozhodnutí o tomto odvolání doručeno pouze veřejnou vyhláškou, nebo má nárok na individuální doručení?',
#   'golden_answer': 'Záleží na právní úpravě platné v době vydání územního rozhodnutí. Pokud platila úprava do 31. 12. 2012, doručovalo se veřejnou vyhláškou. Pokud platila úprava pozdější, která odkazuje na § 144 odst. 6 správního řádu, záleží na uvážení správního orgánu, zda doručí veřejnou vyhláškou, přičemž individuální doručení může být v odvolacím řízení opodstatněné vzhledem k procesní aktivitě odvolatele.',
#   'questions_type': 'legal_interpretation',
#   'file': '4537_2023.txt'},
#  {'question': 'Pokud soudce vedl dříve spor s finančním úřadem ohledně daně z příjmu a nyní má rozhodovat o žalobě proti rozhodnutí téhož finančního úřadu v jiné daňové věci, je to důvod pro námitku podjatosti?',
#   'golden_answer': 'Samotná skutečnost, že soudce vedl dříve spor s finančním úřadem, automaticky neznamená jeho podjatost. Je však nutné zkoumat další okolnosti, jako je povaha sporu, jeho průběh, časový odstup a chování soudce. Pokud byl spor osobní, citlivý nebo principiální a soudce vystupoval velmi aktivně, může to vést k pochybnostem o jeho nepodjatosti.',
#   'questions_type': 'legal_interpretation',
#   'file': '4235_2021.txt'},
#  {'question': 'Pokud zadavatel veřejné zakázky uzavře smlouvu krátce poté, co byl soudem vyzván k vyjádření k návrhu na předběžné opatření zakazující uzavření smlouvy, ale před rozhodnutím soudu o tomto návrhu, může mu soud uložit pořádkovou pokutu za zmaření účelu řízení, i když zadavatel na výzvu soudu řádně odpověděl?',
#   'golden_answer': 'Ne, podle judikatury Nejvyššího správního soudu, pokud zadavatel veřejné zakázky poté, co si soud vyžádal jeho vyjádření k návrhu na předběžné opatření, již smlouvu na danou zakázku uzavřel, nemůže mu za to soud uložit pořádkovou pokutu podle § 44 odst. 1 s. ř. s., i když se jedná o spěšnou reakci na výzvu soudu. Soud by měl zvážit, zda je vyžádání vyjádření v dané situaci vůbec nezbytné.',
#   'questions_type': 'legal_interpretation',
#   'file': '4276_2022.txt'},
#  {'question': 'Klient pracoval pět let jako vyšší soudní úředník před získáním magisterského titulu z práva. Nyní se chce přihlásit k justiční zkoušce. Započítává se mu do požadované tříleté právní praxe i doba výkonu funkce vyššího soudního úředníka před získáním tohoto titulu, nebo pouze praxe po jeho získání?',
#   'golden_answer': 'Podle judikatury Nejvyššího správního soudu se pro účely odborné justiční zkoušky započítává do právní praxe i doba výkonu funkce vyššího soudního úředníka před získáním magisterského titulu z práva. Rozhodující je fakt výkonu funkce, nikoliv doba po získání titulu.',
#   'questions_type': 'legal_interpretation',
#   'file': '4567_2024.txt'},
#  {'question': 'Klient úspěšně ukončil magisterské studium práv na Univerzitě Karlově a obdržel potvrzení o absolvování studia. Může být zapsán do seznamu advokátních koncipientů České advokátní komory pouze s tímto potvrzením, nebo je nutné předložit i vysokoškolský diplom?',
#   'golden_answer': 'Podle judikatury Nejvyššího správního soudu lze splnění podmínky vysokoškolského vzdělání v oboru právo prokázat i potvrzením o absolvování studia, nikoliv výhradně vysokoškolským diplomem. Česká advokátní komora by tedy měla klienta zapsat do seznamu advokátních koncipientů na základě předloženého potvrzení, pokud splňuje i ostatní zákonné podmínky.',
#   'questions_type': 'legal_interpretation',
#   'file': '4314_2022.txt'},
#  {'question': 'Pokud Finanční úřad pro Středočeský kraj vydá platební výměr a Odvolací finanční ředitelství toto rozhodnutí změní v přezkumném řízení podle § 123 odst. 5 daňového řádu, který krajský soud je místně příslušný pro řízení o žalobě proti rozhodnutí vydanému v tomto přezkumném řízení, Krajský soud v Praze (sídlo Finančního úřadu) nebo Krajský soud v Brně (sídlo Odvolacího finančního ředitelství)?',
#   'golden_answer': 'Místně příslušný je krajský soud, v jehož obvodu má sídlo správní orgán, který rozhodoval v prvním stupni v přezkumném řízení, tedy Krajský soud v Brně, kde sídlí Odvolací finanční ředitelství. Rozhodující je sídlo orgánu rozhodujícího v přezkumném řízení, nikoliv v původním řízení.',
#   'questions_type': 'legal_interpretation',
#   'file': '4554_2024.txt'},
#  {'question': 'Klientovi byla doměřena daň za rok 2010. Žalobu proti rozhodnutí finančního úřadu jsme podali v roce 2012. Bude se na běh prekluzivní lhůty pro stanovení daně vztahovat § 41 soudního řádu správního, nebo § 148 daňového řádu, a ovlivní případné stavení lhůty maximální desetiletou lhůtu pro stanovení daně?',
#   'golden_answer': 'Vzhledem k tomu, že žaloba byla podána po 31. 12. 2010, nestaví se lhůta pro stanovení daně podle § 41 s. ř. s., ale podle § 148 odst. 4 daňového řádu. Stavení lhůty dle § 148 odst. 4 daňového řádu však neprodlužuje nejdelší možnou lhůtu pro stanovení daně podle § 148 odst. 5 daňového řádu. Maximální desetiletá lhůta tedy uplyne bez ohledu na probíhající soudní řízení.',
#   'questions_type': 'legal_interpretation',
#   'file': '4543_2024.txt'},
#  {'question': 'Pokud Ministerstvo zdravotnictví zruší mimořádné opatření a následně je podán návrh na zrušení změny tohoto původního opatření, která nebyla výslovně zrušena, bude soud návrh pro bezpředmětnost odmítnut?',
#   'golden_answer': 'Ano, pokud bylo původní mimořádné opatření zrušeno, automaticky pozbývá platnosti i jeho změna, i když nebyla výslovně zrušena. Soud proto návrh na zrušení změny odmítne pro nedostatek předmětu řízení podle § 46 odst. 1 písm. a) s. ř. s.',
#   'questions_type': 'legal_interpretation',
#   'file': '4231_2021.txt'},
#  {'question': 'Pokud zástupce úřadu rozpustí shromáždění z důvodu neuposlechnutí jeho pokynů ohledně používání pochodní, ale při rozpuštění výslovně nesdělí, že pochodně jsou považovány za zbraně ve smyslu zákona o právu shromažďovacím, může soud v případném řízení o žalobě proti rozpuštění shromáždění zohlednit argumentaci úřadu, že pochodně představovaly hrozbu?',
#   'golden_answer': 'Ne, soud by měl vycházet pouze z důvodů rozpuštění shromáždění, které zástupce úřadu sdělil svolavateli a účastníkům na místě. Dodatečná argumentace úřadu, která nebyla při rozpuštění sdělena, nemůže být v řízení o žalobě zohledněna.',
#   'questions_type': 'legal_interpretation',
#   'file': '4510_2023.txt'},
#  {'question': 'Pokud stavební úřad povolí zkušební provoz zařízení pro nakládání s odpady podle stavebního zákona, ale provozovatel nemá souhlas krajského úřadu k provozování tohoto zařízení podle zákona o odpadech, může být provozovatel sankcionován za nakládání s odpady během tohoto zkušebního provozu?',
#   'golden_answer': 'Ano, i během zkušebního provozu zařízení pro nakládání s odpady je nutné mít souhlas krajského úřadu podle zákona o odpadech. Povolení zkušebního provozu podle stavebního zákona nenahrazuje tento souhlas a jeho absence může vést k sankcím za neoprávněné nakládání s odpady.',
#   'questions_type': 'legal_interpretation',
#   'file': '4125_2021.txt'},
#  {'question': 'Pokud zadavatel veřejné zakázky neuplatňuje smluvní pokuty za prodlení dodavatele s odůvodněním technologické přestávky a následně uzavře dohodu o započtení, která nezahrnuje tyto pokuty, představuje to podstatnou změnu závazku ve smyslu § 222 zákona o zadávání veřejných zakázek, i když se zadavatel nároku na smluvní pokutu formálně nevzdal a teoreticky by ji mohl uplatnit později?',
#   'golden_answer': 'Ano, dle judikatury Nejvyššího správního soudu, i faktické neuplatňování smluvních pokut s významným časovým odstupem, zejména pokud zadavatel dodavatele ujistí o neuplatňování a dohoda o započtení nezahrnuje sporné pokuty, může být posouzeno jako podstatná změna závazku, i když formálně nedošlo k prominutí dluhu. Důležitý je dopad na potenciální dodavatele a změna ekonomické rovnováhy ve prospěch vybraného dodavatele.',
#   'questions_type': 'legal_interpretation',
#   'file': '4477_2023.txt'},
#  {'question': 'Pokud Česká správa sociálního zabezpečení nevyplatila zemřelému invalidní důchod a nárok na něj přešel na jeho rodiče, kteří s ním žili v domácnosti, začíná běžet lhůta pro podání žaloby na ochranu před nezákonným zásahem až od okamžiku, kdy rodiče zjistili, že jim důchod nebyl vyplacen, nebo již dříve, například úmrtím syna?',
#   'golden_answer': 'V případě nevyplacení důchodu po smrti oprávněného osobě dle § 63 zákona o důchodovém pojištění se jedná o trvající zásah. Lhůta pro podání žaloby na ochranu před nezákonným zásahem začíná běžet každý den znovu, dokud trvá nevyplácení. Úmrtí syna neznamená konec zásahu, pokud nebyl důchod vyplacen oprávněným osobám.',
#   'questions_type': 'legal_interpretation',
#   'file': '4234_2021.txt'},
#  {'question': 'Klientovi byl nařízen exekuční příkaz na základě zajišťovacího příkazu na dosud nestanovenou DPH. Lhůta pro stanovení daně uplynula před vydáním exekučního příkazu, ale po vydání zajišťovacího příkazu. Může se klient úspěšně bránit proti exekuci s argumentem, že daň je prekludována, i když zajišťovací příkaz byl vydán před prekluzí?',
#   'golden_answer': 'Ano, dle aktuální judikatury Nejvyššího správního soudu (viz rozsudek čj. 2 Afs 338/2018-50) je správce daně povinen zkoumat, zda u zajišťované daně neuplynula lhůta pro její stanovení ke dni vydání exekučního příkazu, i když zajišťovací příkaz byl vydán dříve. Soud by měl zrušit exekuční příkaz, pokud zjistí, že daň byla prekludována před jeho vydáním.',
#   'questions_type': 'legal_interpretation',
#   'file': '4351_2022.txt'},
#  {'question': 'Pokud cizinec, držitel zaměstnanecké karty, podá oznámení o změně zaměstnavatele, které má odstranitelné vady, například chybějící dokumenty, je správní orgán povinen ho vyzvat k odstranění těchto vad a poskytnout mu k tomu přiměřenou lhůtu, i když se na řízení dle § 42g odst. 7 až 11 zákona o pobytu cizinců nevztahují ustanovení části druhé a třetí správního řádu?',
#   'golden_answer': 'Ano, správní orgán je povinen držitele zaměstnanecké karty vyzvat k odstranění odstranitelných vad oznámení o změně zaměstnavatele a stanovit mu přiměřenou lhůtu k jejich odstranění. I když se na řízení nevztahují ustanovení části druhé a třetí správního řádu, aplikuje se § 37 správního řádu prostřednictvím § 154 správního řádu a je nutné postupovat v souladu se zásadou součinnosti. Neodstranění vad v dané lhůtě pak teprve zakládá fikci, že oznámení nebylo učiněno.',
#   'questions_type': 'legal_interpretation',
#   'file': '4529_2023.txt'},
#  {'question': 'Klientka, oběť trestného činu, obdržela od policie poučení o lhůtě pro podání žádosti o peněžitou pomoc, které doslovně citovalo § 30 odst. 2 zákona o obětech trestných činů. Žádost podala poštou před uplynutím dvouleté subjektivní lhůty, ale ministerstvu byla doručena až po jejím uplynutí. Bude její žádost zamítnuta z důvodu opožděnosti?',
#   'golden_answer': 'Pokud poučení od policie neobsahovalo informaci o hmotněprávní povaze lhůty a nutnosti doručení žádosti ministerstvu před jejím uplynutím, soudy by mohly rozhodnout, že pro zachování lhůty postačilo předání žádosti k poštovní přepravě před jejím koncem. Zamítnutí žádosti by v takovém případě mohlo být v rozporu s principem právní jistoty.',
#   'questions_type': 'legal_interpretation',
#   'file': '4179_2021.txt'},
#  {'question': 'Pokud Ministerstvo kultury v přezkumném řízení zruší závazné stanovisko orgánu památkové péče, které bylo podkladem pro již pravomocné stavební povolení, je možné se proti tomuto zrušení závazného stanoviska samostatně bránit žalobou ve správním soudnictví?',
#   'golden_answer': 'Ne, úkon, jímž nadřízený orgán v přezkumném řízení zrušil závazné stanovisko, není rozhodnutím ve smyslu § 65 s. ř. s. a je ze soudního přezkumu vyloučen dle § 70 písm. a) s. ř. s. Žalobu proti takovému úkonu soud odmítne. Soudní ochrana je zajištěna až v rámci případné žaloby proti rozhodnutí o obnově stavebního řízení.',
#   'questions_type': 'legal_interpretation',
#   'file': '4139_2021.txt'},
#  {'question': 'Pokud obec pronajala zemědělskou půdu bez zveřejnění záměru na úřední desce, ale nájemce o tom nevěděl a jednal v dobré víře, může být nájemní smlouva přesto prohlášena za neplatnou v řízení o aktualizaci evidence půdy, a jaký rozsah dokazování je v takovém řízení přípustný?',
#   'golden_answer': 'Ano, i přes dobrou víru nájemce může být nájemní smlouva prohlášena za absolutně neplatnou, pokud nebyl záměr obce pronajmout pozemek zveřejněn na úřední desce. V řízení o aktualizaci evidence půdy má správní orgán povinnost posoudit platnost právního titulu k užívání pozemku, ale rozsah dokazování je omezený a odpovídá účelu řízení, tedy ověření správnosti údajů pro dotace. Správní orgán aplikuje obecné zásady správního řízení, ale s ohledem na to, jak by postupoval soud v občanském soudním řízení, přičemž se klade důraz na povinnost nájemce ověřit si splnění zákonných podmínek ze strany obce.',
#   'questions_type': 'legal_interpretation',
#   'file': '4316_2022.txt'},
#  {'question': 'Klient byl zajištěn podle zákona o pobytu cizinců a následně přezajištěn podle zákona o azylu. Znamená to, že původní rozhodnutí o zajištění automaticky zaniklo a žalobu proti němu soud zamítne pro nedostatek předmětu řízení, i když zajištění fakticky trvá?',
#   'golden_answer': 'Ne, podle judikatury Nejvyššího správního soudu (např. 8 Azs 158/2020) nelze § 125 odst. 6 zákona o pobytu cizinců aplikovat tak, aby došlo k automatickému zániku původního rozhodnutí o zajištění a tím k znemožnění soudního přezkumu jeho zákonnosti, pokud zajištění cizince fakticky trvá na základě rozhodnutí o přezajištění. Taková aplikace by byla v rozporu s právem EU, konkrétně s čl. 15 návratové směrnice a čl. 6 a 47 Listiny základních práv EU. Soud by neměl žalobu zamítnout pro nedostatek předmětu řízení.',
#   'questions_type': 'legal_interpretation',
#   'file': '4130_2021.txt'},
#  {'question': 'Klient pobírá invalidní důchod z mládí ze Slovenska přiznaný ještě za Československa. Nyní pracuje v České republice a platí zde sociální pojištění. Může si nárokovat přiznání invalidního důchodu i v České republice, aby se mu zohlednila doba pojištění získaná po rozdělení Československa?',
#   'golden_answer': 'Ne, podle ustálené judikatury Nejvyššího správního soudu a Smlouvy mezi Českou republikou a Slovenskou republikou o sociálním zabezpečení (čl. 33) nemá poživatel slovenského invalidního důchodu přiznaného před rozdělením ČSFR nárok na souběžný invalidní důchod v České republice, i když splňuje podmínky pro jeho přiznání, neboť by došlo k dvojímu započtení doby pojištění.',
#   'questions_type': 'legal_interpretation',
#   'file': '4360_2022.txt'}]

# %%
formatted_questions = []
global_counter = 0
for response in extracted_questions:
    formatted_questions.append({
            "id": global_counter,
            "question": response["question"],
            "golden_answers": [response["golden_answer"]],
            "metadata": {
                "questions_type": response["questions_type"],
                "file": response["file"],
            }
        })
    # for qa_pair in response["qa_pairs"]:
    #
    global_counter += 1

# %%
len(formatted_questions)
# Out:
# 200

# %%
formatted_questions
# Out:
# [{'id': 0,
#   'question': 'Pokud finanční úřad zadržuje nadměrný odpočet DPH po dobu daňové kontroly, je úroková sazba stanovená jako repo sazba ČNB zvýšená o 2 procentní body v souladu s právem EU, i když daňový subjekt tvrdí, že skutečné náklady na překlenovací úvěr byly vyšší?',
#   'golden_answers': ['Podle judikatury Nejvyššího správního soudu, konkrétně rozsudku 8 Afs 274/2022, je úroková sazba ve výši repo sazby ČNB zvýšené o 2 procentní body v souladu s právem EU, pokud pokrývá průměrné náklady na úvěry poskytované nefinančním podnikům. Individuální nároky na náhradu škody převyšující stanovený úrok je třeba uplatnit samostatně, ale samotná sazba je považována za vyhovující požadavkům EU.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4607_2024.txt'}},
#  {'id': 1,
#   'question': 'Pokud zpravodajská služba odmítne soudu poskytnout bližší informace o zdrojích utajované informace, na základě které správní orgán zrušil cizinci trvalý pobyt, protože by to ohrozilo její činnost, může soud toto rozhodnutí správního orgánu zrušit z důvodu nedostatečného prokázání skutkového stavu?',
#   'golden_answers': ['Ano, soud může rozhodnutí správního orgánu zrušit, pokud mu zpravodajská služba neposkytne dostatečně konkrétní informace o zdrojích a metodách získání utajované informace, aby mohl posoudit její věrohodnost. Soud musí mít možnost ověřit věrohodnost a relevanci utajované informace, aby byla zajištěna spravedlivost řízení a vyloučena libovůle správních orgánů.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4518_2023.txt'}},
#  {'id': 2,
#   'question': 'Pokud byl státnímu zaměstnanci omylem vyplacen vyšší plat, než na který měl nárok, a následně byl přeřazen na jiné služební místo k jinému služebnímu úřadu, je k rozhodnutí o vrácení neoprávněně vyplacené částky příslušný soud, nebo služební orgán, a pokud služební orgán, tak který?',
#   'golden_answers': ['Dle ustálené judikatury Nejvyššího správního soudu, v takovém případě je příslušný rozhodnout služební orgán, a to ten, u kterého byl státní zaměstnanec ve služebním poměru v době vzniku nároku na plat, tedy v době neoprávněné výplaty. Soud není příslušný, neboť se jedná o věc služebního poměru.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4357_2022.txt'}},
#  {'id': 3,
#   'question': 'Pokud je cizinec zaměstnán jako vědecký pracovník v České republice a jeho nezletilá dcera nemá trvalý pobyt ani povolení k zaměstnání, má dcera nárok na účast ve veřejném zdravotním pojištění v České republice na základě směrnice 2005/71/ES nebo 2011/98/EU?',
#   'golden_answers': ['Ne, Nejvyšší správní soud pravděpodobně rozhodne, že směrnice 2005/71/ES a 2011/98/EU nezakládají nárok rodinných příslušníků vědeckých pracovníků nebo pracovníků ze třetích zemí na účast ve veřejném zdravotním pojištění. Tyto směrnice se vztahují primárně na samotné pracovníky, nikoliv na jejich rodinné příslušníky, pokud tito sami nesplňují definici pracovníka ze třetí země.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4255_2021.txt'}},
#  {'id': 4,
#   'question': 'Pokud mi Ministerstvo zdravotnictví odepře nahlédnout do spisu týkajícího se mimořádného opatření, které mi ukládá povinnosti, a tvrdí, že nejsem účastníkem řízení, mohu se proti tomuto postupu bránit žalobou na ochranu před nezákonným zásahem podle § 82 s. ř. s., a to s odkazem na § 27 a § 38 správního řádu?',
#   'golden_answers': ['Ne, podle judikatury Nejvyššího správního soudu (např. čj. 18 A 79/2020-34) u opatření obecné povahy, jakými jsou mimořádná opatření Ministerstva zdravotnictví, nepřichází v úvahu účastenství ve správním řízení ve smyslu § 27 správního řádu. Tím pádem nelze ani hovořit o nezákonném zásahu odepřením nahlížení do spisu z titulu účastenství dle § 38 správního řádu. Žaloba na ochranu před nezákonným zásahem by byla soudem odmítnuta.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4245_2021.txt'}},
#  {'id': 5,
#   'question': 'Pokud provozovatel nepovolených herních zařízení argumentuje, že jeho náklady (např. mzdy zaměstnanců, daně) by měly být odečteny od vypočteného "výnosu" z nepovolené činnosti, aby se zjistila skutečná ekonomická výhoda, obstojí tato argumentace u Nejvyššího správního soudu?',
#   'golden_answers': ['Ne, tato argumentace s největší pravděpodobností neobstojí. Nejvyšší správní soud se obvykle přiklání k názoru, že "výnos" z nepovolené loterie se rovná rozdílu mezi přijatými vklady a vyplacenými výhrami, a nelze jej zaměňovat se "ziskem" z podnikání. Náklady, včetně mezd a daní, se do výpočtu nezahrnují, protože by to popřelo samotný koncept neoprávněné ekonomické výhody.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4252_2021.txt'}},
#  {'id': 6,
#   'question': 'Pokud zákazník objedná zboží přes e-shop během státního svátku, ale osobně si ho vyzvedne a zaplatí v kamenné prodejně s prodejní plochou nad 200 m² také během tohoto svátku, porušuje provozovatel prodejny zákaz prodeje dle zákona o prodejní době?',
#   'golden_answers': ['Ne, pokud k uzavření kupní smlouvy došlo online, samotné vydání zboží a platba v prodejně během svátku nepředstavuje porušení zákazu prodeje. Rozhodující je, že smlouva byla uzavřena mimo kamennou prodejnu, a výdej zboží je pouze realizací již existující smlouvy.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4237_2021.txt'}},
#  {'id': 7,
#   'question': 'Klient, obchodník s elektronikou, byl obviněn z vědomé účasti na daňovém podvodu, ačkoliv správce daně neprokázal, u kterého konkrétního článku obchodního řetězce došlo k neodvedení DPH. Stačí k prokázání vědomé účasti na podvodu pouhá existence nepřímých indicií, které naznačují, že klient o podvodu musel vědět, i když nevěděl o detailech podvodného mechanismu?',
#   'golden_answers': ['Ano, dle ustálené judikatury Nejvyššího správního soudu postačí k prokázání vědomé účasti na podvodu na DPH, zjistí-li správce daně řadu nepřímých indicií, které ve svém souhrnu prokazují, že se daňový subjekt podvodu na DPH účastnil a že o tom musel vědět. Správce daně nemusí prokázat, že daňový subjekt věděl o tom, u kterého článku řetězce byla identifikována chybějící daň a v jakých detailech podvodný mechanismus spočíval.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4491_2023.txt'}},
#  {'id': 8,
#   'question': 'Klientovi bylo doručeno sdělení Ministerstva vnitra o nesplnění podmínek pro změnu zaměstnavatele dle § 42g odst. 9 zákona o pobytu cizinců, ale sdělení neobsahovalo poučení o možnosti podat žalobu. Jaká je lhůta pro podání žaloby v takovém případě a má klient nárok na náhradu nákladů řízení, pokud Ministerstvo vnitra následně sdělení zruší?',
#   'golden_answers': ['Vzhledem k absenci poučení o opravném prostředku se třicetidenní lhůta pro podání žaloby prodlužuje na tři měsíce. Pokud Ministerstvo vnitra sdělení zruší z důvodu, že žaloba byla podána důvodně, má klient nárok na náhradu nákladů řízení dle § 60 odst. 3 s. ř. s., protože ke zrušení došlo v důsledku pozdějšího chování Ministerstva vnitra.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4495_2023.txt'}},
#  {'id': 9,
#   'question': 'Pokud zdravotnická dokumentace žadatelky o odškodnění za protiprávní sterilizaci chybí a žadatelka předloží svědectví a jiné indicie, které podporují její tvrzení, ale neposkytují nezvratný důkaz, jaký standard důkazu musí správní orgán požadovat, aby žádost zamítl?',
#   'golden_answers': ['I když zdravotnická dokumentace chybí, správní orgán musí posoudit, zda žadatelka předestřela alespoň na první pohled hájitelné tvrzení o protiprávní sterilizaci. Pokud indicie ve svém souhrnu nepřipouštějí jiné racionální vysvětlení, než že k protiprávní sterilizaci pravděpodobně došlo, musí správní orgány považovat předpoklady pro přiznání odškodnění za naplněné, ledaže samy prokáží, že ke skutečnostem žadatelkou tvrzeným dojít nemohlo. Jinak řečeno, správní orgán nemůže žádost zamítnout jen proto, že žadatelka neposkytla nezvratný důkaz, pokud její tvrzení podporují jiné indicie.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4623_2024.txt'}},
#  {'id': 10,
#   'question': 'Pokud jeden ze spoluvlastníků pozemku dlouhodobě toleroval užívání cesty veřejností, ale později s tím začal nesouhlasit, a mezitím došlo ke změně vlastníků, je pro určení, zda se jedná o veřejně přístupnou účelovou komunikaci, rozhodující i stanovisko nových spoluvlastníků, kteří s veřejným užíváním souhlasí?',
#   'golden_answers': ['Ne, pro vznik veřejně přístupné účelové komunikace je nutný souhlas všech spoluvlastníků. I aktivní nesouhlas jednoho ze spoluvlastníků, bez ohledu na výši jeho podílu, vylučuje konkludentní souhlas s veřejným užíváním. Stanovisko nových spoluvlastníků, kteří s užíváním souhlasí, samo o sobě nestačí, pokud dříve některý ze spoluvlastníků nesouhlasil.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4425_2023.txt'}},
#  {'id': 11,
#   'question': 'Kliente dovezl léčiva ze třetí země v režimu tranzitu a následně je prodal české firmě, která je uvedla na trh. Dopustil se klient přestupku podle zákona o léčivech, i když sám léčiva na trh neuvedl?',
#   'golden_answers': ['Podle judikatury Nejvyššího správního soudu, pokud klient léčiva pouze pořídil ze třetí země v režimu tranzitu a sám je na trh neuvedl, ale prodal je subjektu, který je následně uvedl na trh, nedopustil se klient přestupku spočívajícího v dovozu léčiv bez povolení. Rozhodující je, kdo léčiva fakticky uvedl do volného oběhu.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4494_2023.txt'}},
#  {'id': 12,
#   'question': 'Pokud Ministerstvo spravedlnosti zruší insolvenčnímu správci povolení z důvodu opakovaných pochybení, ale některá z těchto pochybení se stala před delší dobou, může se správce úspěšně bránit s argumentem, že ministerstvo jednalo příliš pozdě, i když zákon o insolvenčních správcích nestanoví konkrétní promlčecí lhůtu?',
#   'golden_answers': ['I když zákon o insolvenčních správcích nestanoví pro zrušení povolení konkrétní promlčecí lhůtu, ministerstvo je limitováno obecnými zásadami správního řízení, zejména zásadou minimalizace zásahů a zásadou rychlosti. Soud bude zkoumat, zda zrušení povolení po delší době od pochybení je proporcionální a zda neohrožuje právní jistotu správce. Důležitá je závažnost a četnost pochybení v nedávné době před rozhodnutím o zrušení povolení.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4366_2022.txt'}},
#  {'id': 13,
#   'question': 'Pokud prezident republiky udělí milost osobě odsouzené za korupci, a já, jako občan, se cítím být tímto rozhodnutím dotčen na svých právech z důvodu narušení principu rovnosti a důvěry ve spravedlnost, mohu se proti tomuto rozhodnutí prezidenta republiky úspěšně bránit žalobou ve správním soudnictví?',
#   'golden_answers': ['Ne, rozhodnutí prezidenta republiky o udělení milosti nepodléhá přezkumu ve správním soudnictví. Nejvyšší správní soud se již dříve vyjádřil, že prezident v takovém případě nevystupuje jako správní orgán, ale jako orgán ústavní, a jeho rozhodnutí je ústavním aktem, který správní soudy nemají pravomoc přezkoumávat. Občan se nemůže úspěšně bránit žalobou, neboť nemá subjektivní veřejné právo na potrestání pachatele.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4406_2022.txt'}},
#  {'id': 14,
#   'question': 'Pokud byl příslušník bezpečnostního sboru vyslán na denní studium civilní vysoké školy během výkonu funkce zařazené do I. kategorie a po ukončení studia se vrátil zpět k výkonu funkce v I. kategorii, započítává se doba studia do doby výkonu funkce v I. kategorii pro účely snížení věkové hranice pro nárok na starobní důchod, i když toto studium není výslovně uvedeno v rezortním seznamu jako výkon práce I. nebo II. kategorie?',
#   'golden_answers': ['Ano, doba studia na civilní vysoké škole, která byla obklopena výkonem funkce zařazené do I. kategorie, se posuzuje jako výkon funkce v této kategorii pro účely snížení věkové hranice pro vznik nároku na starobní důchod dle § 174 odst. 1 písm. c) zákona č. 100/1988 Sb., a to i v případě, že studium není výslovně uvedeno v rezortním seznamu. Rozhodující je, že studium probíhalo v době zařazení do I. kategorie a po jeho ukončení se příslušník vrátil k výkonu funkce v této kategorii.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4353_2022.txt'}},
#  {'id': 15,
#   'question': 'Klientovi byla udělena neuspokojivá známka z chování na vysvědčení. Podali jsme žádost o přezkum řediteli školy, který hodnocení potvrdil. Můžeme se proti tomuto potvrzení bránit žalobou u správního soudu, a pokud ano, s jakou šancí na úspěch?',
#   'golden_answers': ['Podle ustálené judikatury Nejvyššího správního soudu, např. usnesení Krajského soudu v Brně čj. 62 A 79/2023-36, hodnocení chování žáka a přezkum jeho výsledků dle § 69 odst. 10 školského zákona nezasahují do práv žáka a jsou ze soudního přezkumu vyloučeny. Žaloba by byla nepřípustná.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4568_2024.txt'}},
#  {'id': 16,
#   'question': 'Pokud Rada města odvolá členy kontrolního výboru z důvodu nespokojenosti s kvalitou jejich práce, i když tito členové neporušili žádné konkrétní zákonné povinnosti, je takové odvolání v souladu s českým právem a judikaturou?',
#   'golden_answers': ['Ne, odvolání členů kontrolního výboru Radou města pouze z důvodu nespokojenosti s kvalitou jejich práce, bez naplnění zákonných důvodů pro odvolání, by pravděpodobně bylo shledáno nezákonným. Judikatura Nejvyššího správního soudu zdůrazňuje, že odvolání z funkce ve veřejné správě musí být založeno na konkrétních zákonných důvodech, nikoli na subjektivním hodnocení kvality práce.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4415_2023.txt'}},
#  {'id': 17,
#   'question': 'Klient byl v zemi původu opakovaně předvoláván na policii a krátkodobě zadržován kvůli účasti na nepovolených demonstracích a šíření letáků kritizujících vládu, ačkoli nebyl nikdy formálně obviněn. Může toto jednání, i bez fyzického násilí, představovat pronásledování ve smyslu zákona o azylu a zakládat nárok na mezinárodní ochranu v České republice?',
#   'golden_answers': ['Ano, opakované předvolávání a krátkodobé zadržování z politických důvodů, i bez fyzického násilí, může dosahovat intenzity pronásledování ve smyslu zákona o azylu, pokud je toto jednání prováděno, podporováno nebo trpěno původci pronásledování a představuje závažné porušení lidských práv nebo opatření působící psychický nátlak. Soud bude posuzovat intenzitu a kumulativní dopad těchto opatření, a také zda existuje odůvodněný strach z pronásledování v případě návratu do země původu.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4399_2022.txt'}},
#  {'id': 18,
#   'question': 'Klientovi hrozí vycestování z ČR, což by znamenalo vážné narušení jeho rodinného života, ale újma v zemi původu by nedosahovala intenzity mučení nebo nelidského zacházení. Může mu být udělena doplňková ochrana dle § 14a odst. 2 písm. d) zákona o azylu, pokud by vycestování porušovalo jeho právo na rodinný život dle čl. 8 Úmluvy?',
#   'golden_answers': ['Ano, doplňková ochrana může být udělena, pokud by vycestování klienta znamenalo porušení mezinárodních závazků ČR a hrozila by mu v zemi původu vážná újma, která sice nedosahuje intenzity újmy dle § 14a odst. 2 písm. a) až c) zákona o azylu, ale přesto představuje závažný zásah do jeho práva na rodinný život ve smyslu čl. 8 Úmluvy. Soud bude posuzovat konkrétní okolnosti případu a proporcionalitu zásahu.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4589_2024.txt'}},
#  {'id': 19,
#   'question': 'Klient nahlásil na policii, že ho soused opakovaně slovně napadal a vyhrožoval mu. Policie případ odložila pro nedostatek důkazů. Může být klient stíhán za přestupek proti občanskému soužití spočívající v nepravdivém obvinění, pokud nebylo prokázáno, že si byl vědom nepravdivosti svého obvinění?',
#   'golden_answers': ['Ne, pro uznání viny za přestupek nepravdivého obvinění je nutné prokázat, že si obviněný byl vědom nepravdivosti svého tvrzení. Pouhé odložení případu pro nedostatek důkazů nestačí k prokázání viny za křivé obvinění. Soud by se měl zabývat i věrohodností svědků a důkazů.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4391_2022.txt'}},
#  {'id': 20,
#   'question': 'Pokud kandidát do Poslanecké sněmovny vede osobní kampaň propagující jeho profesní úspěchy a zkušenosti prostřednictvím billboardů během volební kampaně, ale tato kampaň není explicitně spojena s jeho politickou stranou, podléhá tato kampaň povinnosti uvádět zadavatele a zpracovatele podle § 16 odst. 6 volebního zákona?',
#   'golden_answers': ['Ano, pokud je v období volební kampaně propagován kandidát způsobem, který je obvykle poskytován za úplatu, a jsou vychvalovány jeho osobní vlastnosti a zkušenosti, jedná se zpravidla o volební kampaň ve smyslu § 16 odst. 1 volebního zákona, i když není výslovně spojena s politickou stranou. Tudíž se na ni vztahuje povinnost uvést informace o zadavateli a zpracovateli podle § 16 odst. 6 volebního zákona. Výjimkou by byly pouze případy, kdy je zcela evidentní, že se nejedná o cílenou propagaci tohoto kandidáta.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4572_2024.txt'}},
#  {'id': 21,
#   'question': 'Může se občan, který není státním zástupcem, domáhat soudní ochrany proti jmenování nejvyššího státního zástupce, pokud tvrdí, že proces jmenování byl diskriminační a znemožnil mu ucházet se o tuto funkci?',
#   'golden_answers': ['Ne, osoba, která v době jmenování nevykonává funkci státního zástupce, nemá aktivní procesní legitimaci k napadení jmenování nejvyššího státního zástupce. Nejvyšší správní soud pravděpodobně odmítne žalobu pro nedostatek aktivní legitimace, neboť pouze státní zástupce splňuje kvalifikační předpoklady pro výkon této funkce.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4428_2023.txt'}},
#  {'id': 22,
#   'question': 'Pokud vlastním budovu sousedící s nemovitou kulturní památkou, která sama není památkově chráněná, ale stavební úřad posuzuje rekonstrukci mé budovy, je orgán státní památkové péče povinen se v závazném stanovisku vyjádřit k tomu, zda stavební zásahy do mé budovy mohou snížit hodnotu samotné kulturní památky, a pokud ano, jaké podmínky musí být splněny?',
#   'golden_answers': ['Ano, orgán státní památkové péče je povinen posoudit přípustnost stavebních zásahů do sousední budovy z hlediska ochrany dané nemovité kulturní památky, zvláště pokud existuje úzká vazba mezi oběma stavbami. Pokud by zásahy mohly vést ke snížení hodnoty památky, musí stanovit podmínky pro provedení stavby.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4594_2024.txt'}},
#  {'id': 23,
#   'question': 'Pokud společnost uplatňuje odpočet na výzkum a vývoj, a finanční úřad zpochybňuje specifikaci cílů projektu a neuvedení všech odborných pracovníků v projektové dokumentaci, jak konkrétní a detailní musí být cíle projektu popsány a je nutné uvést všechny zaměstnance, kteří se na projektu podílejí, nebo pouze odborné garanty?',
#   'golden_answers': ['Cíle projektu výzkumu a vývoje musí být formulovány dostatečně jasně, aby bylo zřejmé, v čem daňový subjekt spatřuje prvek novosti, resp. prvek odstranění technické nejistoty, v čem se řešení liší od současného stavu a jaký bude jeho přínos. Projekt musí obsahovat jména všech osob, které odborně zajišťují řešení projektu, nikoli pouze odborné garanty. Neuvedení všech odborných pracovníků může vést k neuznání odpočtu.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4656_2025.txt'}},
#  {'id': 24,
#   'question': 'Klient mi bezúplatně převedl na základě jedné darovací smlouvy v jeden den několik různých balíků podílových listů, přičemž hodnota každého jednotlivého balíku nepřesáhla 5.000.000 Kč, ale celková hodnota všech balíků ano. Vzniká mi povinnost tento příjem oznámit správci daně dle § 38v zákona o daních z příjmů?',
#   'golden_answers': ['Ano, pokud bezúplatný převod několika podílových listů proběhl na základě jednoho právního titulu, v jeden den, mezi stejnými osobami a se stejným záměrem, a celková hodnota přesáhla 5.000.000 Kč, vzniká povinnost příjem oznámit správci daně, i když hodnota žádného z dílčích balíků tuto hranici nepřekročila. Důležitý je celkový nárůst majetku.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4538_2023.txt'}},
#  {'id': 25,
#   'question': 'Pokud je proti žadateli o povolení k přechodnému pobytu vedeno trestní stíhání, může imigrační úřad zamítnout jeho žádost s odkazem na ohrožení veřejného pořádku, i když dosud nebyl pravomocně odsouzen?',
#   'golden_answers': ['Ne, samotné trestní stíhání, s ohledem na presumpci neviny, nemůže být důvodem pro zamítnutí žádosti o povolení k přechodnému pobytu z důvodu ohrožení veřejného pořádku. Správní orgán však může přihlédnout k prokázanému jednání, pro které je trestní stíhání vedeno, pokud z něj lze dovodit hrozbu narušení veřejného pořádku, nikoli k samotné trestnosti tohoto jednání.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4636_2024.txt'}},
#  {'id': 26,
#   'question': 'Klient vyrábí nealkoholické nápoje a chce si zaregistrovat ochrannou známku podobnou starší ochranné známce pro pivo. Může Úřad průmyslového vlastnictví zamítnout registraci s odkazem na pravděpodobnost záměny, i když se jedná o nealkoholické nápoje a pivo?',
#   'golden_answers': ['Ano, Úřad průmyslového vlastnictví může zamítnout registraci ochranné známky pro nealkoholické nápoje, pokud je podobná starší ochranné známce pro pivo a existuje pravděpodobnost záměny na straně veřejnosti. Soudy v České republice se přiklánějí k názoru, že pivo, včetně nealkoholického, a nealkoholické nápoje jsou si podobné výrobky, a proto hrozí, že spotřebitelé by se mohli domnívat, že pocházejí od stejného výrobce.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4650_2024.txt'}},
#  {'id': 27,
#   'question': 'Pokud správní orgán prvního stupně vydá rozhodnutí o vině v přestupkovém řízení, které je následně odvolacím orgánem zrušeno pro závažné procesní vady, přerušuje toto zrušené rozhodnutí běh promlčecí doby?',
#   'golden_answers': ['Ano, i rozhodnutí o vině zrušené pro nezákonnost přerušuje běh promlčecí doby, pokud nebylo nicotné nebo ryze formální, učiněné jen ve snaze zabránit promlčení bez skutečné ambice vést řízení. Rozhodující je, zda se jednalo o skutečný projev vůle státu potrestat přestupek.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4488_2023.txt'}},
#  {'id': 28,
#   'question': 'Klientovi bylo doručeno rozhodnutí Ministerstva vnitra o jeho předání do Rumunska podle Dublinského nařízení, protože tam poprvé požádal o azyl. Ministerstvo se odvolává na § 11 odst. 2 zákona o azylu. Je k žalobě proti tomuto rozhodnutí místně příslušný soud v obvodu trvalého bydliště klienta, nebo soud v sídle Ministerstva vnitra?',
#   'golden_answers': ['Nejvyšší správní soud by pravděpodobně rozhodl, že místně příslušný je krajský soud v obvodu, kde má klient hlášený pobyt, dle § 32 odst. 3 zákona o azylu. Rozhodnutí o předání podle Dublinského nařízení je považováno za rozhodnutí ve věci mezinárodní ochrany, i když klient žádost o azyl v ČR formálně nepodal. Judikatura NSS v obdobných případech preferuje aplikaci § 32 odst. 3 zákona o azylu.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4275_2022.txt'}},
#  {'id': 29,
#   'question': 'Pokud krajský soud zamítne žalobu podanou žalobcem, má osoba zúčastněná na řízení právo podat kasační stížnost proti tomuto zamítnutí, i když se domáhá pouze zrušení procesního rozhodnutí soudu a nikoliv meritorního posouzení věci?',
#   'golden_answers': ['Ne, osoba zúčastněná na řízení nemá aktivní procesní legitimaci k podání kasační stížnosti proti rozhodnutí krajského soudu, kterým se zamítá žaloba nebo zastavuje řízení. Kasační stížnost podaná osobou zúčastněnou na řízení v takovém případě bude odmítnuta jako podání učiněné osobou k tomu zjevně neoprávněnou.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4484_2023.txt'}},
#  {'id': 30,
#   'question': 'Klient se domáhá zaevidování nadměrného odpočtu DPH a úroku na daňový účet, ale správce daně nekoná. Musí klient před podáním zásahové žaloby podat podnět podle § 38 daňového řádu, i když tvrdí, že správce daně je nečinný, nikoliv že provádí nesprávné úkony?',
#   'golden_answers': ['Ano, dle ustálené judikatury Nejvyššího správního soudu, i když se klient domáhá ochrany před nečinností správce daně v oblasti placení daní, je podnět podle § 38 daňového řádu právním prostředkem ochrany nebo nápravy ve smyslu § 85 soudního řádu správního, který musí vyčerpat před podáním zásahové žaloby. Teprve po neúspěšném podnětu se může obrátit na soud.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4123_2021.txt'}},
#  {'id': 31,
#   'question': 'Pokud správce daně zpochybní veškeré nároky na odpočet DPH na vstupu u daňového subjektu provozujícího hotel, a daňový subjekt neprokáže oprávněnost těchto odpočtů, může správce daně stanovit DPH pouze na základě dokazování daně na výstupu, nebo je povinen přistoupit ke stanovení daně podle pomůcek, například s využitím doktríny esenciálních výdajů?',
#   'golden_answers': ['Ne, správce daně není povinen přistoupit ke stanovení daně podle pomůcek, pokud má k dispozici dostatečné podklady pro stanovení daně na výstupu dokazováním, například daňové přiznání. Doktrína esenciálních výdajů se v případě DPH neuplatní, neboť nárok na odpočet daně je vázán na splnění zákonných požadavků dle § 72 odst. 1 zákona o DPH.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4526_2023.txt'}},
#  {'id': 32,
#   'question': 'Pokud státní příspěvková organizace, zřízená ministerstvem, odmítne poskytnout informace dle zákona o svobodném přístupu k informacím, a nelze určit nadřízený orgán dle § 178 správního řádu, který úřad je příslušný rozhodnout o odvolání proti tomuto rozhodnutí?',
#   'golden_answers': ['V takovém případě, pokud nelze určit nadřízený orgán státní příspěvkové organizace podle § 178 správního řádu, je příslušný rozhodnout o odvolání Úřad pro ochranu osobních údajů, jak stanoví § 20 odst. 5 zákona o svobodném přístupu k informacím.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4230_2021.txt'}},
#  {'id': 33,
#   'question': 'Pokud obec zakoupí akcie společnosti provozující autobusovou dopravu za účelem zajištění dopravní obslužnosti, považuje se tato transakce za veřejnou zakázku na dodávky ve smyslu § 14 odst. 1 zákona o zadávání veřejných zakázek, a musí tedy být zadána v zadávacím řízení?',
#   'golden_answers': ['Dle judikatury Nejvyššího správního soudu, nákup akcií nebo závodu spadá pod definici veřejné zakázky na dodávky podle § 14 odst. 1 ZZVZ, jelikož akcie a závod jsou považovány za věci ve smyslu § 489 občanského zákoníku. Absence výjimky v ZZVZ pro nabytí akcií nebo závodu znamená, že se na takové transakce vztahují pravidla pro zadávání veřejných zakázek.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4102_2021.txt'}},
#  {'id': 34,
#   'question': 'Kliente se domáhá ochrany před nezákonným zásahem policie. Policie soudu předložila úřední záznamy, které nebyly součástí správního spisu a klient se s nimi neměl možnost seznámit před soudním řízením. Může soud při rozhodování vycházet z těchto záznamů, aniž by s nimi provedl důkaz při jednání?',
#   'golden_answers': ['Ne, soud by zásadně neměl vycházet z listin předložených správním orgánem v řízení o zásahové žalobě, které nebyly součástí správního spisu a s nimiž se žalobce neměl možnost seznámit před soudním řízením, aniž by s nimi provedl důkaz při jednání a umožnil žalobci na ně reagovat. Jinak by mohlo dojít k procesní vadě řízení, která by mohla mít za následek nezákonné rozhodnutí ve věci samé.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4563_2024.txt'}},
#  {'id': 35,
#   'question': 'Klientovi bylo správcem daně vydáno povolení k nabytí elektřiny osvobozené od daně pro metalurgické procesy. Nyní, po několika letech, správce daně tvrdí, že činnost klienta nesplňuje definici metalurgického procesu a doměřuje daň. Může se klient úspěšně bránit, pokud povolení dosud nebylo zrušeno?',
#   'golden_answers': ['Ano, klient se může úspěšně bránit. Pokud správce daně nezrušil platné povolení k nabytí elektřiny osvobozené od daně, nemůže dodatečně doměřit daň, i když se později domnívá, že původní posouzení bylo chybné. Rozhodnutí o povolení má konstitutivní charakter a zakládá právo na odběr elektřiny osvobozené od daně, dokud není zrušeno.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4343_2022.txt'}},
#  {'id': 36,
#   'question': 'Klient nabízí "kulturně-výměnné programy" zahrnující stáž v zahraničí za poplatek. Pokud stáž obnáší 35-40 hodin týdně práce za kapesné, může Státní úřad inspekce práce uložit pokutu za porušení § 58 odst. 2 zákona o zaměstnanosti, i když klient tvrdí, že poplatek je za jiné služby než zprostředkování zaměstnání?',
#   'golden_answers': ['Ano, pokud faktický obsah programu spočívá převážně ve zprostředkování zaměstnání, a to i skrytě pod rouškou kulturně-výměnného programu, může Státní úřad inspekce práce uložit pokutu. Rozhodující je posouzení, zda se jedná o závislou práci dle českého práva, a zda poplatek fakticky pokrývá i zprostředkování této práce. Nejvyšší správní soud vykládá pojem zprostředkování zaměstnání extenzivně.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4114_2021.txt'}},
#  {'id': 37,
#   'question': "Pokud odborová organizace žádá o informace o platech vedoucích pracovníků veřejné vysoké školy s odůvodněním, že má podezření na nehospodárné nakládání s prostředky, ale zaměstnavatel tvrdí, že organizace u něj fakticky nepůsobí a žádost je zneužitím práva, jak soud posoudí splnění podmínky role 'společenského hlídacího psa' pro poskytnutí informací dle platového nálezu Ústavního soudu?",
#   'golden_answers': ["Soud bude posuzovat, zda odborová organizace reálně plní roli dozoru veřejnosti, nikoliv její formální status nebo oprávnění působit u daného zaměstnavatele. Rozhodující bude, zda organizace hodlá s informacemi vstoupit do veřejné diskuse a přispět tak ke kontrole hospodaření s veřejnými prostředky. I kdyby organizace u zaměstnavatele nepůsobila, může být považována za 'společenského hlídacího psa ad hoc', pokud se prokáže její aktivní snaha o zapojení do veřejné debaty o dané problematice. Zneužití práva musí být prokázáno, pouhé podezření na účelovost žádosti nestačí."],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4416_2023.txt'}},
#  {'id': 38,
#   'question': 'Klientovi byly zajištěny peníze na účtu Policií ČR jako náhradní hodnota za výnos z trestné činnosti. Může finanční úřad i přesto vydat zajišťovací příkaz na stejnou částku z důvodu potenciálního nedoplatku DPH, nebo se jedná o nepřípustný souběh zajišťovacích institutů?',
#   'golden_answers': ['Zajištění peněz v trestním řízení nebrání vydání zajišťovacího příkazu dle daňového řádu, pokud jsou splněny ostatní podmínky pro jeho vydání. Správce daně nemůže s jistotou předvídat, jak budou prostředky zajištěné policií využity. Nicméně, nemělo by dojít k duplicitnímu zajištění a orgán činný v trestním řízení by měl posoudit, zda je jeho zajištění stále v daném rozsahu třeba.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4253_2021.txt'}},
#  {'id': 39,
#   'question': 'Pokud plátce DPH vystavil opravný daňový doklad a doručil jej dlužníkovi v insolvenčním řízení ve lhůtě tří let od konce zdaňovacího období původního plnění, ale daňové přiznání s touto opravou podal až po uplynutí této lhůty, má plátce nárok na opravu výše daně na výstupu?',
#   'golden_answers': ['Nejvyšší správní soud se pravděpodobně přikloní k názoru, že pro nárok na opravu výše daně na výstupu podle § 44 zákona o DPH (ve znění účinném do 31. 3. 2019) postačí, pokud plátce ve lhůtě tří let vystaví opravný daňový doklad, doručí jej dlužníkovi a provede záznamy v evidenci DPH. Podání daňového přiznání v této lhůtě není nutné.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4175_2021.txt'}},
#  {'id': 40,
#   'question': 'Je advokát povinen podat kontrolní hlášení podle zákona o DPH, i když by to mohlo vést k porušení jeho povinnosti mlčenlivosti vůči klientům dle zákona o advokacii?',
#   'golden_answers': ['Ano, advokát je povinen podat kontrolní hlášení, přestože to souvisí s jeho povinností mlčenlivosti. Zákon o advokacii v § 21 odst. 5 stanoví výjimku pro povinnosti daňového subjektu, přičemž advokát je povinen zachovávat mlčenlivost pouze o povaze věci, nikoliv o identifikačních údajích klienta a hodnotě plnění. Nejvyšší správní soud se v podobných případech přiklání k názoru, že povinnost podat kontrolní hlášení nepředstavuje porušení advokátní mlčenlivosti.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4274_2022.txt'}},
#  {'id': 41,
#   'question': 'Klient neoprávněně pobýval na území ČR a následně požádal o mezinárodní ochranu. Může správní orgán zahájit řízení o správním vyhoštění i po podání této žádosti, nebo je to v rozporu se zákonem o pobytu cizinců a zákonem o azylu?',
#   'golden_answers': ['Ano, správní orgán může zahájit řízení o správním vyhoštění i po podání žádosti o mezinárodní ochranu, pokud důvod pro vyhoštění (neoprávněný pobyt) nastal před podáním žádosti. Zákon o pobytu cizinců nevylučuje souběžné vedení obou řízení, přičemž vykonatelnost rozhodnutí o vyhoštění je odložena do doby rozhodnutí o žádosti o mezinárodní ochranu.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4551_2024.txt'}},
#  {'id': 42,
#   'question': 'Pokud zadavatel v otevřeném řízení stanovil zadávací podmínku, která omezuje hospodářskou soutěž, a kvůli tomu nebyla podána žádná nabídka, může následně zadat zakázku v jednacím řízení bez uveřejnění, i když by se prokázalo, že tato zadávací podmínka odradila pouze jednoho potenciálního uchazeče?',
#   'golden_answers': ['Ne, zadavatel nemůže použít jednací řízení bez uveřejnění, pokud nepodání nabídek v původním otevřeném řízení zapříčinil svým nezákonným postupem, například nezákonným nastavením zadávacích podmínek. Pro závěr o nemožnosti použití JŘBU postačuje rozumná míra pravděpodobnosti, že z důvodu nezákonného postupu zadavatele nabídku nepodal byť jen jediný dodavatel. Důvodem nepodání nabídky nemusí být výhradně nezákonný postup zadavatele, postačí, byl-li jednou z příčin rozhodnutí dodavatele nabídku nepodat.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4327_2022.txt'}},
#  {'id': 43,
#   'question': 'Pokud již existuje platná smlouva o dodávce tepla mezi držitelem licence a zákazníkem, ale zákazník se domáhá změny výše rezervovaného tepelného výkonu s odkazem na pozdější cenové rozhodnutí ERÚ, má Energetický regulační úřad pravomoc rozhodnout o takovém návrhu na změnu smlouvy, nebo spadá tato pravomoc do kompetence civilních soudů?',
#   'golden_answers': ['Ne, Energetický regulační úřad nemá pravomoc rozhodovat o změně již existující smlouvy o dodávce tepla. Pravomoc ERÚ se omezuje na spory o uzavření smlouvy, nikoli o její změnu. Spor o změnu smlouvy, zejména pokud se týká změny výše rezervovaného tepelného výkonu, spadá do pravomoci civilních soudů v souladu s občanským zákoníkem.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4363_2022.txt'}},
#  {'id': 44,
#   'question': 'Pokud zadavatel veřejné zakázky na stavební práce uzavřel dodatek ke smlouvě navyšující cenu díla o 14 % z důvodu prodlení způsobeného přezkumem ÚOHS, a tato změna nepřesahuje limity de minimis stanovené v § 222 odst. 4 ZZVZ, ale zadávací dokumentace omezovala možnosti navýšení ceny pouze na změny právních předpisů, může poskytovatel dotace odmítnout proplatit část dotace s odůvodněním, že se jedná o podstatnou změnu závazku?',
#   'golden_answers': ['Ne, pokud změna ceny nepřesahuje limity de minimis dle § 222 odst. 4 ZZVZ a nemění celkovou povahu veřejné zakázky, nemělo by se jednat o podstatnou změnu závazku, i když zadávací dokumentace původně omezovala možnosti navýšení ceny. Soud by měl zkoumat, zda byly dodrženy limity de minimis a zda změna neovlivnila hospodářskou soutěž natolik, aby to vyžadovalo nové zadávací řízení. Zadavatel nemůže smluvně vyloučit aplikaci § 222 odst. 4 ZZVZ.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4583_2024.txt'}},
#  {'id': 45,
#   'question': 'Pokud společnost poskytuje pouze službu převzatého televizního vysílání přes internet, ale nezajišťuje samotné internetové připojení, spadá spor o neuhrazení poplatků za tuto službu do pravomoci Českého telekomunikačního úřadu nebo obecného soudu?',
#   'golden_answers': ['Ne, pokud společnost poskytuje pouze službu obsahu (převzaté televizní vysílání) a nezajišťuje i přenos signálu sítí elektronických komunikací (internetové připojení), spor o zaplacení poplatků nespadá do pravomoci ČTÚ. Příslušný je obecný soud, neboť se nejedná o službu elektronických komunikací ve smyslu § 2 odst. 3 písm. a) zákona o elektronických komunikacích.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4372_2022.txt'}},
#  {'id': 46,
#   'question': 'Pokud bylo v přestupkovém řízení pravomocně rozhodnuto o vině a trestu, ale řízení o náhradě škody se protáhlo, a mezitím uplynula promlčecí doba pro přestupek, může správní orgán ještě rozhodnout o náhradě škody v adhezním řízení, nebo je povinen řízení zastavit?',
#   'golden_answers': ['I když bylo pravomocně rozhodnuto o vině, uplynutí promlčecí doby pro přestupek brání dalšímu vedení adhezního řízení o náhradě škody. Správní orgán je povinen řízení o náhradě škody zastavit, protože adhezní řízení je závislé na řízení o přestupku a nelze jej vést mimo časový rámec pro projednání přestupku.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4133_2021.txt'}},
#  {'id': 47,
#   'question': 'Klientovi byl udělen pobyt za účelem strpění, protože neměl cestovní doklad. Nyní cestovní doklad má, ale tvrdí, že jako palestinský uprchlík nemá možnost legálního dlouhodobého pobytu v žádné jiné zemi. Může být jeho žádost o prodloužení pobytu zamítnuta pouze na základě toho, že má cestovní doklad, nebo se musí správní orgán zabývat i tím, zda existuje země, kde by mohl legálně pobývat?',
#   'golden_answers': ['Správní orgán se nemůže omezit pouze na zjištění, že cizinec disponuje cestovním dokladem. Musí se zabývat i tím, zda trvá důvod pro strpění pobytu, tedy zda cizinci ve vycestování brání překážka na jeho vůli nezávislá. Pokud cizinec prokáže, že jako uprchlík nemá možnost legálního pobytu v jiné zemi, jde stále o překážku ve vycestování a žádost o prodloužení pobytu za účelem strpění by neměla být zamítnuta pouze na základě držení cestovního dokladu.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4388_2022.txt'}},
#  {'id': 48,
#   'question': 'Klient, poskytovatel poštovních služeb bez poštovní licence, se s Českou poštou nedohodl na smlouvě o přístupu k poštovní infrastruktuře. Český telekomunikační úřad rozhodl o obsahu smlouvy. Může klient podat žalobu proti rozhodnutí ČTÚ k civilnímu soudu, nebo je příslušný správní soud?',
#   'golden_answers': ['Podle ustálené judikatury Nejvyššího správního soudu, právní vztah ze smlouvy o přístupu k poštovní infrastruktuře je vztahem soukromého práva. I když o obsahu smlouvy rozhodl ČTÚ, žaloba směřuje k úpravě soukromoprávního vztahu, a proto je příslušný civilní soud, nikoliv správní soud.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4429_2023.txt'}},
#  {'id': 49,
#   'question': 'Pokud ministerstvo spravedlnosti zjistí drobné pochybení soudního exekutora, existuje nějaká lhůta, do kdy musí exekutorovi písemně vytknout toto pochybení dle § 7a exekučního řádu, a pokud ano, jaká je tato lhůta?',
#   'golden_answers': ['Ačkoliv exekuční řád nestanoví konkrétní lhůtu pro uložení výtky, ministerstvo je limitováno základními zásadami činnosti správních orgánů, zejména zásadou rychlosti a hospodárnosti. Výtka musí být uložena v přiměřené době od zjištění pochybení, přičemž se zohledňují konkrétní okolnosti případu. Příliš dlouhá nečinnost ministerstva může vést ke zrušení výtky soudem.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4217_2021.txt'}},
#  {'id': 50,
#   'question': 'Může Ministerstvo školství zamítnout zápis soukromé základní školy do rejstříku škol a školských zařízení pouze z důvodu, že stávající státní školy v dané lokalitě mají dostatečnou kapacitu, aniž by zohlednilo alternativní vzdělávací koncepci, zájem rodičů a podporu místní samosprávy?',
#   'golden_answers': ['Ne, Ministerstvo školství nemůže zamítnout zápis soukromé školy pouze z kapacitních důvodů. Podle judikatury Nejvyššího správního soudu a Ústavního soudu je nutné zohlednit i kvalitativní aspekty, jako je alternativní vzdělávací koncepce, zájem rodičů a podpora samosprávy. Dlouhodobé záměry vzdělávání nesmí plošně znemožňovat vznik nestátních škol a je třeba je vykládat ústavně konformně, s ohledem na právo rodičů na alternativu ve vzdělávání.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4440_2023.txt'}},
#  {'id': 51,
#   'question': 'Pokud jsou sourozenci umístěni do zařízení pro děti vyžadující okamžitou pomoc, a ředitel zařízení rozhodne o jejich odděleném ubytování v různých částech zařízení z důvodu údajné nadměrné péče staršího sourozence o mladšího, může se starší sourozenec úspěšně domáhat ochrany před nezákonným zásahem, pokud s oddělením nesouhlasí a tvrdí, že péče o mladšího sourozence je pro ni přirozená a ne představuje nadměrnou zátěž?',
#   'golden_answers': ['Ano, starší sourozenec se může úspěšně domáhat ochrany před nezákonným zásahem. Soud by měl zohlednit názor staršího sourozence, zjistit, zda péče o mladšího sourozence skutečně představuje nadměrnou zátěž, a posoudit, zda oddělení sourozenců je v souladu s jejich nejlepším zájmem a zda neexistují mírnější opatření. Oddělení sourozenců by mělo být považováno za krajní řešení a mělo by být odůvodněno závažnými okolnostmi ve vývoji a vztazích sourozenců, které brání společnému umístění.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4634_2024.txt'}},
#  {'id': 52,
#   'question': 'Klient, společnost s ručením omezeným, uzavřela dohodu o smluvní pokutě s propojenou osobou. Následně si tuto pokutu, kterou zaplatila propojené osobě, uplatnila jako daňově uznatelný náklad. Může finanční úřad takové uplatnění nákladu zpochybnit s odkazem na zneužití práva, i když formálně byly splněny všechny podmínky pro daňovou uznatelnost?',
#   'golden_answers': ['Ano, finanční úřad může zpochybnit uplatnění nákladu s odkazem na zneužití práva, pokud prokáže, že i přes formální splnění podmínek zákona nebyl naplněn jeho účel a smysl a zároveň, že hlavním nebo převažujícím účelem jednání klienta bylo získání daňové výhody. Propojenost osob je relevantní okolnost, ale není definiční podmínkou zneužití práva. Důležité je ekonomické opodstatnění transakce a zda klient uměle vytvořil podmínky pro uplatnění daňové výhody.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4358_2022.txt'}},
#  {'id': 53,
#   'question': 'Pokud neúspěšný uchazeč ve výběrovém řízení na exekutorský úřad podá žalobu proti rozhodnutí ministra spravedlnosti o jmenování úspěšného uchazeče, je soud povinen se zabývat námitkami týkajícími se průběhu výběrového řízení, nebo je jeho přezkum omezen pouze na splnění zákonných požadavků jmenovaného exekutora dle § 9 a § 12 exekučního řádu?',
#   'golden_answers': ['Soud se zabývá pouze tím, zda ministr spravedlnosti postupoval v souladu se zákonem při jmenování exekutora. Ministr je vázán návrhem Exekutorské komory a pokud navržený kandidát splňuje požadavky § 9 a § 12 exekučního řádu, je povinen jej jmenovat. Soud tedy nepřezkoumává průběh výběrového řízení vedeného Exekutorskou komorou, jelikož neúspěšný uchazeč není účastníkem řízení o jmenování.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4472_2023.txt'}},
#  {'id': 54,
#   'question': 'Klient byl pokutován za správní delikt. Po právní moci rozhodnutí vstoupila v platnost nová právní úprava, která zpřísňuje definici skutkové podstaty deliktu. Může soud v řízení o žalobě proti rozhodnutí správního orgánu posoudit, zda původní jednání klienta naplňuje i novou, zpřísněnou skutkovou podstatu, a to i když správní orgán tuto okolnost nezkoumal?',
#   'golden_answers': ['Ano, soud v řízení o žalobě musí posoudit, zda je nová právní úprava pro klienta příznivější. Pokud je nová úprava účinná až po právní moci rozhodnutí správního orgánu, soud posoudí, zda jednání klienta naplňuje i novou skutkovou podstatu, i když správní orgán tuto okolnost nezkoumal. Soud tak rozhoduje v plné jurisdikci a musí zohlednit aktuální právní stav.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4162_2021.txt'}},
#  {'id': 55,
#   'question': 'Pokud krajský soud v řízení o mezinárodní ochraně ustanoví žadatelovi zástupce usnesením asistenta soudce, je toto usnesení vydáno v souladu se zákonem, neboť § 35 odst. 10 s. ř. s. svěřuje tuto pravomoc předsedovi senátu?',
#   'golden_answers': ['Podle judikatury Nejvyššího správního soudu, konkrétně usnesení rozšířeného senátu, je asistent soudce oprávněn rozhodnout o návrhu na ustanovení zástupce dle § 35 odst. 10 s. ř. s. Rozhodnutí asistenta soudce je v souladu se zákonem, protože smyslem je odbřemenění soudců a existuje možnost přezkumu rozhodnutí soudcem, například prostřednictvím námitek dle § 9 zákona o VSÚ.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4107_2021.txt'}},
#  {'id': 56,
#   'question': 'Klient byl podmíněně propuštěn z výkonu trestu odnětí svobody za majetkovou trestnou činnost. Nyní žádá o povolení k přechodnému pobytu jako rodinný příslušník občana EU. Může správní orgán zamítnout jeho žádost pouze s odkazem na jeho předchozí odsouzení a probíhající zkušební dobu, nebo musí zohlednit i jiné faktory, jako je jeho chování po propuštění a délka doby, která uplynula od spáchání trestného činu?',
#   'golden_answers': ['Správní orgán nemůže zamítnout žádost o přechodný pobyt pouze na základě předchozího odsouzení a probíhající zkušební doby. Musí individuálně posoudit, zda klient představuje aktuální a dostatečně závažné ohrožení veřejného pořádku, zohlednit jeho chování po propuštění, délku doby od spáchání trestného činu, jeho osobní vývoj a další relevantní okolnosti. Pouhé trvání zkušební doby samo o sobě nestačí k zamítnutí žádosti.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4523_2023.txt'}},
#  {'id': 57,
#   'question': 'Pokud obec již jednou rozhodla v místním referendu o vlastníkovi kanalizace, a v kampani bylo zdůrazňováno spojení tohoto vlastníka s určitým typem kanalizace (např. tlakovou), může se konat nové referendum o typu kanalizace (např. gravitační), pokud od prvního referenda neuplynulo 24 měsíců?',
#   'golden_answers': ['Ne, pokud z kontextu prvního referenda a kampaně je zřejmé, že volba vlastníka kanalizace byla fakticky i volbou typu kanalizace, nové referendum o typu kanalizace by bylo v rozporu s § 7 písm. h) zákona o místním referendu, neboť by se jednalo o referendum ve stejné věci před uplynutím 24 měsíců. Soudy by posuzovaly smysl otázky a odpovědi v předchozím referendu pohledem běžného občana a v kontextu kampaně.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4348_2022.txt'}},
#  {'id': 58,
# ...
#   'golden_answers': ['Ano, pokud umístění stavby vybočuje z koridoru vymezeného územním plánem, je souhlas vlastníka pozemku nezbytný, pokud se nejedná o plochy nezbytné k zajištění výstavby nebo řádného užívání stavby a správní orgán tuto nezbytnost řádně odůvodnil. Jinak je souhlas vlastníka dle § 184a odst. 1, 3 stavebního zákona nutný.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4598_2024.txt'}},
#  {'id': 181,
#   'question': 'Klient, vedlejší účastník územního řízení s velkým počtem účastníků, podal odvolání proti územnímu rozhodnutí. Může mu být rozhodnutí o tomto odvolání doručeno pouze veřejnou vyhláškou, nebo má nárok na individuální doručení?',
#   'golden_answers': ['Záleží na právní úpravě platné v době vydání územního rozhodnutí. Pokud platila úprava do 31. 12. 2012, doručovalo se veřejnou vyhláškou. Pokud platila úprava pozdější, která odkazuje na § 144 odst. 6 správního řádu, záleží na uvážení správního orgánu, zda doručí veřejnou vyhláškou, přičemž individuální doručení může být v odvolacím řízení opodstatněné vzhledem k procesní aktivitě odvolatele.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4537_2023.txt'}},
#  {'id': 182,
#   'question': 'Pokud soudce vedl dříve spor s finančním úřadem ohledně daně z příjmu a nyní má rozhodovat o žalobě proti rozhodnutí téhož finančního úřadu v jiné daňové věci, je to důvod pro námitku podjatosti?',
#   'golden_answers': ['Samotná skutečnost, že soudce vedl dříve spor s finančním úřadem, automaticky neznamená jeho podjatost. Je však nutné zkoumat další okolnosti, jako je povaha sporu, jeho průběh, časový odstup a chování soudce. Pokud byl spor osobní, citlivý nebo principiální a soudce vystupoval velmi aktivně, může to vést k pochybnostem o jeho nepodjatosti.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4235_2021.txt'}},
#  {'id': 183,
#   'question': 'Pokud zadavatel veřejné zakázky uzavře smlouvu krátce poté, co byl soudem vyzván k vyjádření k návrhu na předběžné opatření zakazující uzavření smlouvy, ale před rozhodnutím soudu o tomto návrhu, může mu soud uložit pořádkovou pokutu za zmaření účelu řízení, i když zadavatel na výzvu soudu řádně odpověděl?',
#   'golden_answers': ['Ne, podle judikatury Nejvyššího správního soudu, pokud zadavatel veřejné zakázky poté, co si soud vyžádal jeho vyjádření k návrhu na předběžné opatření, již smlouvu na danou zakázku uzavřel, nemůže mu za to soud uložit pořádkovou pokutu podle § 44 odst. 1 s. ř. s., i když se jedná o spěšnou reakci na výzvu soudu. Soud by měl zvážit, zda je vyžádání vyjádření v dané situaci vůbec nezbytné.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4276_2022.txt'}},
#  {'id': 184,
#   'question': 'Klient pracoval pět let jako vyšší soudní úředník před získáním magisterského titulu z práva. Nyní se chce přihlásit k justiční zkoušce. Započítává se mu do požadované tříleté právní praxe i doba výkonu funkce vyššího soudního úředníka před získáním tohoto titulu, nebo pouze praxe po jeho získání?',
#   'golden_answers': ['Podle judikatury Nejvyššího správního soudu se pro účely odborné justiční zkoušky započítává do právní praxe i doba výkonu funkce vyššího soudního úředníka před získáním magisterského titulu z práva. Rozhodující je fakt výkonu funkce, nikoliv doba po získání titulu.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4567_2024.txt'}},
#  {'id': 185,
#   'question': 'Klient úspěšně ukončil magisterské studium práv na Univerzitě Karlově a obdržel potvrzení o absolvování studia. Může být zapsán do seznamu advokátních koncipientů České advokátní komory pouze s tímto potvrzením, nebo je nutné předložit i vysokoškolský diplom?',
#   'golden_answers': ['Podle judikatury Nejvyššího správního soudu lze splnění podmínky vysokoškolského vzdělání v oboru právo prokázat i potvrzením o absolvování studia, nikoliv výhradně vysokoškolským diplomem. Česká advokátní komora by tedy měla klienta zapsat do seznamu advokátních koncipientů na základě předloženého potvrzení, pokud splňuje i ostatní zákonné podmínky.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4314_2022.txt'}},
#  {'id': 186,
#   'question': 'Pokud Finanční úřad pro Středočeský kraj vydá platební výměr a Odvolací finanční ředitelství toto rozhodnutí změní v přezkumném řízení podle § 123 odst. 5 daňového řádu, který krajský soud je místně příslušný pro řízení o žalobě proti rozhodnutí vydanému v tomto přezkumném řízení, Krajský soud v Praze (sídlo Finančního úřadu) nebo Krajský soud v Brně (sídlo Odvolacího finančního ředitelství)?',
#   'golden_answers': ['Místně příslušný je krajský soud, v jehož obvodu má sídlo správní orgán, který rozhodoval v prvním stupni v přezkumném řízení, tedy Krajský soud v Brně, kde sídlí Odvolací finanční ředitelství. Rozhodující je sídlo orgánu rozhodujícího v přezkumném řízení, nikoliv v původním řízení.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4554_2024.txt'}},
#  {'id': 187,
#   'question': 'Klientovi byla doměřena daň za rok 2010. Žalobu proti rozhodnutí finančního úřadu jsme podali v roce 2012. Bude se na běh prekluzivní lhůty pro stanovení daně vztahovat § 41 soudního řádu správního, nebo § 148 daňového řádu, a ovlivní případné stavení lhůty maximální desetiletou lhůtu pro stanovení daně?',
#   'golden_answers': ['Vzhledem k tomu, že žaloba byla podána po 31. 12. 2010, nestaví se lhůta pro stanovení daně podle § 41 s. ř. s., ale podle § 148 odst. 4 daňového řádu. Stavení lhůty dle § 148 odst. 4 daňového řádu však neprodlužuje nejdelší možnou lhůtu pro stanovení daně podle § 148 odst. 5 daňového řádu. Maximální desetiletá lhůta tedy uplyne bez ohledu na probíhající soudní řízení.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4543_2024.txt'}},
#  {'id': 188,
#   'question': 'Pokud Ministerstvo zdravotnictví zruší mimořádné opatření a následně je podán návrh na zrušení změny tohoto původního opatření, která nebyla výslovně zrušena, bude soud návrh pro bezpředmětnost odmítnut?',
#   'golden_answers': ['Ano, pokud bylo původní mimořádné opatření zrušeno, automaticky pozbývá platnosti i jeho změna, i když nebyla výslovně zrušena. Soud proto návrh na zrušení změny odmítne pro nedostatek předmětu řízení podle § 46 odst. 1 písm. a) s. ř. s.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4231_2021.txt'}},
#  {'id': 189,
#   'question': 'Pokud zástupce úřadu rozpustí shromáždění z důvodu neuposlechnutí jeho pokynů ohledně používání pochodní, ale při rozpuštění výslovně nesdělí, že pochodně jsou považovány za zbraně ve smyslu zákona o právu shromažďovacím, může soud v případném řízení o žalobě proti rozpuštění shromáždění zohlednit argumentaci úřadu, že pochodně představovaly hrozbu?',
#   'golden_answers': ['Ne, soud by měl vycházet pouze z důvodů rozpuštění shromáždění, které zástupce úřadu sdělil svolavateli a účastníkům na místě. Dodatečná argumentace úřadu, která nebyla při rozpuštění sdělena, nemůže být v řízení o žalobě zohledněna.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4510_2023.txt'}},
#  {'id': 190,
#   'question': 'Pokud stavební úřad povolí zkušební provoz zařízení pro nakládání s odpady podle stavebního zákona, ale provozovatel nemá souhlas krajského úřadu k provozování tohoto zařízení podle zákona o odpadech, může být provozovatel sankcionován za nakládání s odpady během tohoto zkušebního provozu?',
#   'golden_answers': ['Ano, i během zkušebního provozu zařízení pro nakládání s odpady je nutné mít souhlas krajského úřadu podle zákona o odpadech. Povolení zkušebního provozu podle stavebního zákona nenahrazuje tento souhlas a jeho absence může vést k sankcím za neoprávněné nakládání s odpady.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4125_2021.txt'}},
#  {'id': 191,
#   'question': 'Pokud zadavatel veřejné zakázky neuplatňuje smluvní pokuty za prodlení dodavatele s odůvodněním technologické přestávky a následně uzavře dohodu o započtení, která nezahrnuje tyto pokuty, představuje to podstatnou změnu závazku ve smyslu § 222 zákona o zadávání veřejných zakázek, i když se zadavatel nároku na smluvní pokutu formálně nevzdal a teoreticky by ji mohl uplatnit později?',
#   'golden_answers': ['Ano, dle judikatury Nejvyššího správního soudu, i faktické neuplatňování smluvních pokut s významným časovým odstupem, zejména pokud zadavatel dodavatele ujistí o neuplatňování a dohoda o započtení nezahrnuje sporné pokuty, může být posouzeno jako podstatná změna závazku, i když formálně nedošlo k prominutí dluhu. Důležitý je dopad na potenciální dodavatele a změna ekonomické rovnováhy ve prospěch vybraného dodavatele.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4477_2023.txt'}},
#  {'id': 192,
#   'question': 'Pokud Česká správa sociálního zabezpečení nevyplatila zemřelému invalidní důchod a nárok na něj přešel na jeho rodiče, kteří s ním žili v domácnosti, začíná běžet lhůta pro podání žaloby na ochranu před nezákonným zásahem až od okamžiku, kdy rodiče zjistili, že jim důchod nebyl vyplacen, nebo již dříve, například úmrtím syna?',
#   'golden_answers': ['V případě nevyplacení důchodu po smrti oprávněného osobě dle § 63 zákona o důchodovém pojištění se jedná o trvající zásah. Lhůta pro podání žaloby na ochranu před nezákonným zásahem začíná běžet každý den znovu, dokud trvá nevyplácení. Úmrtí syna neznamená konec zásahu, pokud nebyl důchod vyplacen oprávněným osobám.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4234_2021.txt'}},
#  {'id': 193,
#   'question': 'Klientovi byl nařízen exekuční příkaz na základě zajišťovacího příkazu na dosud nestanovenou DPH. Lhůta pro stanovení daně uplynula před vydáním exekučního příkazu, ale po vydání zajišťovacího příkazu. Může se klient úspěšně bránit proti exekuci s argumentem, že daň je prekludována, i když zajišťovací příkaz byl vydán před prekluzí?',
#   'golden_answers': ['Ano, dle aktuální judikatury Nejvyššího správního soudu (viz rozsudek čj. 2 Afs 338/2018-50) je správce daně povinen zkoumat, zda u zajišťované daně neuplynula lhůta pro její stanovení ke dni vydání exekučního příkazu, i když zajišťovací příkaz byl vydán dříve. Soud by měl zrušit exekuční příkaz, pokud zjistí, že daň byla prekludována před jeho vydáním.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4351_2022.txt'}},
#  {'id': 194,
#   'question': 'Pokud cizinec, držitel zaměstnanecké karty, podá oznámení o změně zaměstnavatele, které má odstranitelné vady, například chybějící dokumenty, je správní orgán povinen ho vyzvat k odstranění těchto vad a poskytnout mu k tomu přiměřenou lhůtu, i když se na řízení dle § 42g odst. 7 až 11 zákona o pobytu cizinců nevztahují ustanovení části druhé a třetí správního řádu?',
#   'golden_answers': ['Ano, správní orgán je povinen držitele zaměstnanecké karty vyzvat k odstranění odstranitelných vad oznámení o změně zaměstnavatele a stanovit mu přiměřenou lhůtu k jejich odstranění. I když se na řízení nevztahují ustanovení části druhé a třetí správního řádu, aplikuje se § 37 správního řádu prostřednictvím § 154 správního řádu a je nutné postupovat v souladu se zásadou součinnosti. Neodstranění vad v dané lhůtě pak teprve zakládá fikci, že oznámení nebylo učiněno.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4529_2023.txt'}},
#  {'id': 195,
#   'question': 'Klientka, oběť trestného činu, obdržela od policie poučení o lhůtě pro podání žádosti o peněžitou pomoc, které doslovně citovalo § 30 odst. 2 zákona o obětech trestných činů. Žádost podala poštou před uplynutím dvouleté subjektivní lhůty, ale ministerstvu byla doručena až po jejím uplynutí. Bude její žádost zamítnuta z důvodu opožděnosti?',
#   'golden_answers': ['Pokud poučení od policie neobsahovalo informaci o hmotněprávní povaze lhůty a nutnosti doručení žádosti ministerstvu před jejím uplynutím, soudy by mohly rozhodnout, že pro zachování lhůty postačilo předání žádosti k poštovní přepravě před jejím koncem. Zamítnutí žádosti by v takovém případě mohlo být v rozporu s principem právní jistoty.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4179_2021.txt'}},
#  {'id': 196,
#   'question': 'Pokud Ministerstvo kultury v přezkumném řízení zruší závazné stanovisko orgánu památkové péče, které bylo podkladem pro již pravomocné stavební povolení, je možné se proti tomuto zrušení závazného stanoviska samostatně bránit žalobou ve správním soudnictví?',
#   'golden_answers': ['Ne, úkon, jímž nadřízený orgán v přezkumném řízení zrušil závazné stanovisko, není rozhodnutím ve smyslu § 65 s. ř. s. a je ze soudního přezkumu vyloučen dle § 70 písm. a) s. ř. s. Žalobu proti takovému úkonu soud odmítne. Soudní ochrana je zajištěna až v rámci případné žaloby proti rozhodnutí o obnově stavebního řízení.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4139_2021.txt'}},
#  {'id': 197,
#   'question': 'Pokud obec pronajala zemědělskou půdu bez zveřejnění záměru na úřední desce, ale nájemce o tom nevěděl a jednal v dobré víře, může být nájemní smlouva přesto prohlášena za neplatnou v řízení o aktualizaci evidence půdy, a jaký rozsah dokazování je v takovém řízení přípustný?',
#   'golden_answers': ['Ano, i přes dobrou víru nájemce může být nájemní smlouva prohlášena za absolutně neplatnou, pokud nebyl záměr obce pronajmout pozemek zveřejněn na úřední desce. V řízení o aktualizaci evidence půdy má správní orgán povinnost posoudit platnost právního titulu k užívání pozemku, ale rozsah dokazování je omezený a odpovídá účelu řízení, tedy ověření správnosti údajů pro dotace. Správní orgán aplikuje obecné zásady správního řízení, ale s ohledem na to, jak by postupoval soud v občanském soudním řízení, přičemž se klade důraz na povinnost nájemce ověřit si splnění zákonných podmínek ze strany obce.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4316_2022.txt'}},
#  {'id': 198,
#   'question': 'Klient byl zajištěn podle zákona o pobytu cizinců a následně přezajištěn podle zákona o azylu. Znamená to, že původní rozhodnutí o zajištění automaticky zaniklo a žalobu proti němu soud zamítne pro nedostatek předmětu řízení, i když zajištění fakticky trvá?',
#   'golden_answers': ['Ne, podle judikatury Nejvyššího správního soudu (např. 8 Azs 158/2020) nelze § 125 odst. 6 zákona o pobytu cizinců aplikovat tak, aby došlo k automatickému zániku původního rozhodnutí o zajištění a tím k znemožnění soudního přezkumu jeho zákonnosti, pokud zajištění cizince fakticky trvá na základě rozhodnutí o přezajištění. Taková aplikace by byla v rozporu s právem EU, konkrétně s čl. 15 návratové směrnice a čl. 6 a 47 Listiny základních práv EU. Soud by neměl žalobu zamítnout pro nedostatek předmětu řízení.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4130_2021.txt'}},
#  {'id': 199,
#   'question': 'Klient pobírá invalidní důchod z mládí ze Slovenska přiznaný ještě za Československa. Nyní pracuje v České republice a platí zde sociální pojištění. Může si nárokovat přiznání invalidního důchodu i v České republice, aby se mu zohlednila doba pojištění získaná po rozdělení Československa?',
#   'golden_answers': ['Ne, podle ustálené judikatury Nejvyššího správního soudu a Smlouvy mezi Českou republikou a Slovenskou republikou o sociálním zabezpečení (čl. 33) nemá poživatel slovenského invalidního důchodu přiznaného před rozdělením ČSFR nárok na souběžný invalidní důchod v České republice, i když splňuje podmínky pro jeho přiznání, neboť by došlo k dvojímu započtení doby pojištění.'],
#   'metadata': {'questions_type': 'legal_interpretation',
#    'file': '4360_2022.txt'}}]

# %%
with open("../nss_questions_v2_full.jsonl", "w", encoding="utf-8") as f:
    for question in formatted_questions:
        f.write(json.dumps(question) + "\n")

# %%
questions_subset = random.sample(formatted_questions, 100)

# %%
with open("nss_questions_v2_100_subset.jsonl", "w", encoding="utf-8") as f:
    for question in questions_subset:
        f.write(json.dumps(question) + "\n")
